# %%
from pathlib import Path

#from ConvergenceAnalysis import *
from DataAnalysisClass import *

# %%
single = ['aug-cc-pVDZ', 'aug-cc-pVTZ', 'aug-cc-pVQZ', 'aug-cc-pV5Z', 'aug-cc-pV6Z']
single_polarized = ['aug-cc-pCVDZ', 'aug-cc-pCVTZ', 'aug-cc-pCVQZ']
double = ['d-aug-cc-pVDZ', 'd-aug-cc-pVTZ', 'd-aug-cc-pVQZ', 'd-aug-cc-pV5Z', 'd-aug-cc-pV6Z']
double_polarized = ['d-aug-cc-pCVDZ', 'd-aug-cc-pCVTZ', 'd-aug-cc-pCVQZ']
all_basis_sets = single + single_polarized + double + double_polarized

# %%
pal2 = sns.color_palette("coolwarm_r", 4).as_hex()
p2 = [pal2[1], pal2[0], pal2[2], pal2[3]]
pal = sns.color_palette(p2)
p1 = [pal2[1], pal2[2], pal2[0], pal2[3]]
simple_pal = sns.color_palette(p1)
sns.set_style('darkgrid')

# %%
database_path = Path('/home/ahurta92/data/august')
paper_path = Path('response_paper_figures')

# %%
import glob

# glob for .mol files in august molecules directory
mols = glob.glob('/home/ahurta92/data/august/molecules/*.mol')
mols = [mol.split('/')[-1].split('.')[0] for mol in mols]

# %%
# remove LiH_s from mols
mols.remove('LiH_s')

# %%
august_database = PolarizabilityData(mols, 'hf', 'dipole', all_basis_sets, database_path, overwrite=True)
# Out:
# energy_df
# NH2Cl hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/NH2Cl/moldft.calc_info.json'
# Did not find the new mra data for NH2Cl
# Trying FrequencyData
# NaLi hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/NaLi/moldft.calc_info.json'
# Did not find the new mra data for NaLi
# Trying FrequencyData
# F2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/F2/moldft.calc_info.json'
# Did not find the new mra data for F2
# Trying FrequencyData
# HNS hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/HNS/moldft.calc_info.json'
# Did not find the new mra data for HNS
# Trying FrequencyData
# N2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/N2/moldft.calc_info.json'
# Did not find the new mra data for N2
# Trying FrequencyData
# HCHO hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/HCHO/moldft.calc_info.json'
# Did not find the new mra data for HCHO
# Trying FrequencyData
# SF2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/SF2/moldft.calc_info.json'
# Did not find the new mra data for SF2
# Trying FrequencyData
# LiH hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/LiH/moldft.calc_info.json'
# Did not find the new mra data for LiH
# Trying FrequencyData
# Na2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/Na2/moldft.calc_info.json'
# Did not find the new mra data for Na2
# Trying FrequencyData
# SiO hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/SiO/moldft.calc_info.json'
# Did not find the new mra data for SiO
# Trying FrequencyData
# Mg hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/Mg/moldft.calc_info.json'
# Did not find the new mra data for Mg
# Trying FrequencyData
# BH2Cl hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/BH2Cl/moldft.calc_info.json'
# Did not find the new mra data for BH2Cl
# Trying FrequencyData
# SH2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/SH2/moldft.calc_info.json'
# Did not find the new mra data for SH2
# Trying FrequencyData
# P2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/P2/moldft.calc_info.json'
# Did not find the new mra data for P2
# Trying FrequencyData
# HOCl hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/HOCl/moldft.calc_info.json'
# Did not find the new mra data for HOCl
# Trying FrequencyData
# N2H4 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/N2H4/moldft.calc_info.json'
# Did not find the new mra data for N2H4
# Trying FrequencyData
# NaCl hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/NaCl/moldft.calc_info.json'
# Did not find the new mra data for NaCl
# Trying FrequencyData
# HCCCl hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/HCCCl/moldft.calc_info.json'
# Did not find the new mra data for HCCCl
# Trying FrequencyData
# SiH3F hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/SiH3F/moldft.calc_info.json'
# Did not find the new mra data for SiH3F
# Trying FrequencyData
# HCl hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/HCl/moldft.calc_info.json'
# Did not find the new mra data for HCl
# Trying FrequencyData
# P2H4 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/P2H4/moldft.calc_info.json'
# Did not find the new mra data for P2H4
# Trying FrequencyData
# HCN hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/HCN/moldft.calc_info.json'
# Did not find the new mra data for HCN
# Trying FrequencyData
# H2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/H2/moldft.calc_info.json'
# Did not find the new mra data for H2
# Trying FrequencyData
# Mg2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/Mg2/moldft.calc_info.json'
# Did not find the new mra data for Mg2
# Trying FrequencyData
# CSO hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/CSO/moldft.calc_info.json'
# Did not find the new mra data for CSO
# Trying FrequencyData
# PH3O hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/PH3O/moldft.calc_info.json'
# Did not find the new mra data for PH3O
# Trying FrequencyData
# FNO hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/FNO/moldft.calc_info.json'
# Did not find the new mra data for FNO
# Trying FrequencyData
# S2H2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/S2H2/moldft.calc_info.json'
# Did not find the new mra data for S2H2
# Trying FrequencyData
# CH3OH hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/CH3OH/moldft.calc_info.json'
# Did not find the new mra data for CH3OH
# Trying FrequencyData
# NH3O hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/NH3O/moldft.calc_info.json'
# Did not find the new mra data for NH3O
# Trying FrequencyData
# BF hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/BF/moldft.calc_info.json'
# Did not find the new mra data for BF
# Trying FrequencyData
# OCl2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/OCl2/moldft.calc_info.json'
# Did not find the new mra data for OCl2
# Trying FrequencyData
# HBS hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/HBS/moldft.calc_info.json'
# Did not find the new mra data for HBS
# Trying FrequencyData
# C2H2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/C2H2/moldft.calc_info.json'
# Did not find the new mra data for C2H2
# Trying FrequencyData
# HF hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/HF/moldft.calc_info.json'
# Did not find the new mra data for HF
# Trying FrequencyData
# SO2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/SO2/moldft.calc_info.json'
# Did not find the new mra data for SO2
# Trying FrequencyData
# Cl2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/Cl2/moldft.calc_info.json'
# Did not find the new mra data for Cl2
# Trying FrequencyData
# Ar hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/Ar/moldft.calc_info.json'
# Did not find the new mra data for Ar
# Trying FrequencyData
# PH3 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/PH3/moldft.calc_info.json'
# Did not find the new mra data for PH3
# Trying FrequencyData
# NH3 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/NH3/moldft.calc_info.json'
# Did not find the new mra data for NH3
# Trying FrequencyData
# CH2BH hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/CH2BH/moldft.calc_info.json'
# Did not find the new mra data for CH2BH
# Trying FrequencyData
# HCCF hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/HCCF/moldft.calc_info.json'
# Did not find the new mra data for HCCF
# Trying FrequencyData
# CH2NH hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/CH2NH/moldft.calc_info.json'
# Did not find the new mra data for CH2NH
# Trying FrequencyData
# SCl2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/SCl2/moldft.calc_info.json'
# Did not find the new mra data for SCl2
# Trying FrequencyData
# CH3SH hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/CH3SH/moldft.calc_info.json'
# Did not find the new mra data for CH3SH
# Trying FrequencyData
# CH3Cl hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/CH3Cl/moldft.calc_info.json'
# Did not find the new mra data for CH3Cl
# Trying FrequencyData
# BeH2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/BeH2/moldft.calc_info.json'
# Did not find the new mra data for BeH2
# Trying FrequencyData
# LiCl hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/LiCl/moldft.calc_info.json'
# Did not find the new mra data for LiCl
# Trying FrequencyData
# HCHS hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/HCHS/moldft.calc_info.json'
# Did not find the new mra data for HCHS
# Trying FrequencyData
# NaH hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/NaH/moldft.calc_info.json'
# Did not find the new mra data for NaH
# Trying FrequencyData
# Ne hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/Ne/moldft.calc_info.json'
# Did not find the new mra data for Ne
# Trying FrequencyData
# BH3 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/BH3/moldft.calc_info.json'
# Did not find the new mra data for BH3
# Trying FrequencyData
# C2H4 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/C2H4/moldft.calc_info.json'
# Did not find the new mra data for C2H4
# Trying FrequencyData
# ClCN hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/ClCN/moldft.calc_info.json'
# Did not find the new mra data for ClCN
# Trying FrequencyData
# OF2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/OF2/moldft.calc_info.json'
# Did not find the new mra data for OF2
# Trying FrequencyData
# CH4 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/CH4/moldft.calc_info.json'
# Did not find the new mra data for CH4
# Trying FrequencyData
# BH2F hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/BH2F/moldft.calc_info.json'
# Did not find the new mra data for BH2F
# Trying FrequencyData
# HCONH2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/HCONH2/moldft.calc_info.json'
# Did not find the new mra data for HCONH2
# Trying FrequencyData
# LiCN hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/LiCN/moldft.calc_info.json'
# Did not find the new mra data for LiCN
# Trying FrequencyData
# Be hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/Be/moldft.calc_info.json'
# Did not find the new mra data for Be
# Trying FrequencyData
# CH3BH2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/CH3BH2/moldft.calc_info.json'
# Did not find the new mra data for CH3BH2
# Trying FrequencyData
# NOCl hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/NOCl/moldft.calc_info.json'
# Did not find the new mra data for NOCl
# Trying FrequencyData
# CS hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/CS/moldft.calc_info.json'
# Did not find the new mra data for CS
# Trying FrequencyData
# He hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/He/moldft.calc_info.json'
# Did not find the new mra data for He
# Trying FrequencyData
# SiH4 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/SiH4/moldft.calc_info.json'
# Did not find the new mra data for SiH4
# Trying FrequencyData
# CO hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/CO/moldft.calc_info.json'
# Did not find the new mra data for CO
# Trying FrequencyData
# O3 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/O3/moldft.calc_info.json'
# Did not find the new mra data for O3
# Trying FrequencyData
# BHF2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/BHF2/moldft.calc_info.json'
# Did not find the new mra data for BHF2
# Trying FrequencyData
# NaCN hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/NaCN/moldft.calc_info.json'
# Did not find the new mra data for NaCN
# Trying FrequencyData
# CH3F hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/CH3F/moldft.calc_info.json'
# Did not find the new mra data for CH3F
# Trying FrequencyData
# C6H6 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/C6H6/moldft.calc_info.json'
# Did not find the new mra data for C6H6
# Trying FrequencyData
# Li2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/Li2/moldft.calc_info.json'
# Did not find the new mra data for Li2
# Trying FrequencyData
# FCN hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/FCN/moldft.calc_info.json'
# Did not find the new mra data for FCN
# Trying FrequencyData
# CH3NH2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/CH3NH2/moldft.calc_info.json'
# Did not find the new mra data for CH3NH2
# Trying FrequencyData
# SiH3Cl hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/SiH3Cl/moldft.calc_info.json'
# Did not find the new mra data for SiH3Cl
# Trying FrequencyData
# NH2F hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/NH2F/moldft.calc_info.json'
# Did not find the new mra data for NH2F
# Trying FrequencyData
# CO2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/CO2/moldft.calc_info.json'
# Did not find the new mra data for CO2
# Trying FrequencyData
# HCP hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/HCP/moldft.calc_info.json'
# Did not find the new mra data for HCP
# Trying FrequencyData
# NH2OH hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/NH2OH/moldft.calc_info.json'
# Did not find the new mra data for NH2OH
# Trying FrequencyData
# N2H2 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/N2H2/moldft.calc_info.json'
# Did not find the new mra data for N2H2
# Trying FrequencyData
# HNO hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/HNO/moldft.calc_info.json'
# Did not find the new mra data for HNO
# Trying FrequencyData
# ClF hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/ClF/moldft.calc_info.json'
# Did not find the new mra data for ClF
# Trying FrequencyData
# LiBH4 hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/LiBH4/moldft.calc_info.json'
# Did not find the new mra data for LiBH4
# Trying FrequencyData
# HNC hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/HNC/moldft.calc_info.json'
# Did not find the new mra data for HNC
# Trying FrequencyData
# H2O hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/H2O/moldft.calc_info.json'
# Did not find the new mra data for H2O
# Trying FrequencyData
# HCOOH hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/HCOOH/moldft.calc_info.json'
# Did not find the new mra data for HCOOH
# Trying FrequencyData
# HOF hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/HOF/moldft.calc_info.json'
# Did not find the new mra data for HOF
# Trying FrequencyData
# HBO hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/HBO/moldft.calc_info.json'
# Did not find the new mra data for HBO
# Trying FrequencyData
# HOOH hf dipole /home/ahurta92/data/august
# [Errno 2] No such file or directory: '/home/ahurta92/data/august/hf/HOOH/moldft.calc_info.json'
# Did not find the new mra data for HOOH
# Trying FrequencyData
# DaltonRunner base_dir:  /home/ahurta92/data/august
# DaltonRunner dal_dir:  /home/ahurta92/data/august/dalton
# /home/ahurta92/data/august/molecules/NH2Cl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NH2Cl/dipole/freq_NH2Cl-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/NaLi.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NaLi/dipole/freq_NaLi-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/F2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/F2/dipole/freq_F2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/HNS.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HNS/dipole/freq_HNS-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/N2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/N2/dipole/freq_N2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/HCHO.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCHO/dipole/freq_HCHO-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/SF2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SF2/dipole/freq_SF2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/LiH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/LiH/dipole/freq_LiH-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/Na2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/Na2/dipole/freq_Na2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/SiO.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SiO/dipole/freq_SiO-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/Mg.mol
# output_file: /home/ahurta92/data/august/dalton/hf/Mg/dipole/freq_Mg-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/BH2Cl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/BH2Cl/dipole/freq_BH2Cl-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/SH2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SH2/dipole/freq_SH2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/P2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/P2/dipole/freq_P2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/HOCl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HOCl/dipole/freq_HOCl-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/N2H4.mol
# output_file: /home/ahurta92/data/august/dalton/hf/N2H4/dipole/freq_N2H4-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/NaCl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NaCl/dipole/freq_NaCl-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/HCCCl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCCCl/dipole/freq_HCCCl-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/SiH3F.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SiH3F/dipole/freq_SiH3F-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/HCl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCl/dipole/freq_HCl-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/P2H4.mol
# output_file: /home/ahurta92/data/august/dalton/hf/P2H4/dipole/freq_P2H4-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/HCN.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCN/dipole/freq_HCN-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/H2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/H2/dipole/freq_H2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/Mg2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/Mg2/dipole/freq_Mg2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/CSO.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CSO/dipole/freq_CSO-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/PH3O.mol
# output_file: /home/ahurta92/data/august/dalton/hf/PH3O/dipole/freq_PH3O-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/FNO.mol
# output_file: /home/ahurta92/data/august/dalton/hf/FNO/dipole/freq_FNO-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/S2H2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/S2H2/dipole/freq_S2H2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/CH3OH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH3OH/dipole/freq_CH3OH-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/NH3O.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NH3O/dipole/freq_NH3O-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/BF.mol
# output_file: /home/ahurta92/data/august/dalton/hf/BF/dipole/freq_BF-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/OCl2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/OCl2/dipole/freq_OCl2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/HBS.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HBS/dipole/freq_HBS-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/C2H2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/C2H2/dipole/freq_C2H2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/HF.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HF/dipole/freq_HF-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/SO2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SO2/dipole/freq_SO2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/Cl2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/Cl2/dipole/freq_Cl2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/Ar.mol
# output_file: /home/ahurta92/data/august/dalton/hf/Ar/dipole/freq_Ar-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/PH3.mol
# output_file: /home/ahurta92/data/august/dalton/hf/PH3/dipole/freq_PH3-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/NH3.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NH3/dipole/freq_NH3-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/CH2BH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH2BH/dipole/freq_CH2BH-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/HCCF.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCCF/dipole/freq_HCCF-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/CH2NH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH2NH/dipole/freq_CH2NH-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/SCl2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SCl2/dipole/freq_SCl2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/CH3SH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH3SH/dipole/freq_CH3SH-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/CH3Cl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH3Cl/dipole/freq_CH3Cl-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/BeH2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/BeH2/dipole/freq_BeH2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/LiCl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/LiCl/dipole/freq_LiCl-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/HCHS.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCHS/dipole/freq_HCHS-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/NaH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NaH/dipole/freq_NaH-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/Ne.mol
# output_file: /home/ahurta92/data/august/dalton/hf/Ne/dipole/freq_Ne-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/BH3.mol
# output_file: /home/ahurta92/data/august/dalton/hf/BH3/dipole/freq_BH3-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/C2H4.mol
# output_file: /home/ahurta92/data/august/dalton/hf/C2H4/dipole/freq_C2H4-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/ClCN.mol
# output_file: /home/ahurta92/data/august/dalton/hf/ClCN/dipole/freq_ClCN-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/OF2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/OF2/dipole/freq_OF2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/CH4.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH4/dipole/freq_CH4-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/BH2F.mol
# output_file: /home/ahurta92/data/august/dalton/hf/BH2F/dipole/freq_BH2F-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/HCONH2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCONH2/dipole/freq_HCONH2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/LiCN.mol
# output_file: /home/ahurta92/data/august/dalton/hf/LiCN/dipole/freq_LiCN-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/Be.mol
# output_file: /home/ahurta92/data/august/dalton/hf/Be/dipole/freq_Be-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/CH3BH2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH3BH2/dipole/freq_CH3BH2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/NOCl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NOCl/dipole/freq_NOCl-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/CS.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CS/dipole/freq_CS-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/He.mol
# output_file: /home/ahurta92/data/august/dalton/hf/He/dipole/freq_He-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/SiH4.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SiH4/dipole/freq_SiH4-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/CO.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CO/dipole/freq_CO-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/O3.mol
# output_file: /home/ahurta92/data/august/dalton/hf/O3/dipole/freq_O3-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/BHF2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/BHF2/dipole/freq_BHF2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/NaCN.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NaCN/dipole/freq_NaCN-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/CH3F.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH3F/dipole/freq_CH3F-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/C6H6.mol
# output_file: /home/ahurta92/data/august/dalton/hf/C6H6/dipole/freq_C6H6-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/Li2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/Li2/dipole/freq_Li2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/FCN.mol
# output_file: /home/ahurta92/data/august/dalton/hf/FCN/dipole/freq_FCN-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/CH3NH2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH3NH2/dipole/freq_CH3NH2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/SiH3Cl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SiH3Cl/dipole/freq_SiH3Cl-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/NH2F.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NH2F/dipole/freq_NH2F-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/CO2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CO2/dipole/freq_CO2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/HCP.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCP/dipole/freq_HCP-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/NH2OH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NH2OH/dipole/freq_NH2OH-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/N2H2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/N2H2/dipole/freq_N2H2-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/HNO.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HNO/dipole/freq_HNO-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/ClF.mol
# output_file: /home/ahurta92/data/august/dalton/hf/ClF/dipole/freq_ClF-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/LiBH4.mol
# output_file: /home/ahurta92/data/august/dalton/hf/LiBH4/dipole/freq_LiBH4-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/HNC.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HNC/dipole/freq_HNC-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/H2O.mol
# output_file: /home/ahurta92/data/august/dalton/hf/H2O/dipole/freq_H2O-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/HCOOH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCOOH/dipole/freq_HCOOH-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/HOF.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HOF/dipole/freq_HOF-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/HBO.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HBO/dipole/freq_HBO-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/HOOH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HOOH/dipole/freq_HOOH-aug-cc-pVDZ.out
# /home/ahurta92/data/august/molecules/NH2Cl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NH2Cl/dipole/freq_NH2Cl-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/NaLi.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NaLi/dipole/freq_NaLi-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/F2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/F2/dipole/freq_F2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/HNS.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HNS/dipole/freq_HNS-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/N2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/N2/dipole/freq_N2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/HCHO.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCHO/dipole/freq_HCHO-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/SF2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SF2/dipole/freq_SF2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/LiH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/LiH/dipole/freq_LiH-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/Na2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/Na2/dipole/freq_Na2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/SiO.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SiO/dipole/freq_SiO-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/Mg.mol
# output_file: /home/ahurta92/data/august/dalton/hf/Mg/dipole/freq_Mg-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/BH2Cl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/BH2Cl/dipole/freq_BH2Cl-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/SH2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SH2/dipole/freq_SH2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/P2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/P2/dipole/freq_P2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/HOCl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HOCl/dipole/freq_HOCl-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/N2H4.mol
# output_file: /home/ahurta92/data/august/dalton/hf/N2H4/dipole/freq_N2H4-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/NaCl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NaCl/dipole/freq_NaCl-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/HCCCl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCCCl/dipole/freq_HCCCl-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/SiH3F.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SiH3F/dipole/freq_SiH3F-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/HCl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCl/dipole/freq_HCl-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/P2H4.mol
# output_file: /home/ahurta92/data/august/dalton/hf/P2H4/dipole/freq_P2H4-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/HCN.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCN/dipole/freq_HCN-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/H2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/H2/dipole/freq_H2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/Mg2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/Mg2/dipole/freq_Mg2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/CSO.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CSO/dipole/freq_CSO-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/PH3O.mol
# output_file: /home/ahurta92/data/august/dalton/hf/PH3O/dipole/freq_PH3O-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/FNO.mol
# output_file: /home/ahurta92/data/august/dalton/hf/FNO/dipole/freq_FNO-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/S2H2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/S2H2/dipole/freq_S2H2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/CH3OH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH3OH/dipole/freq_CH3OH-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/NH3O.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NH3O/dipole/freq_NH3O-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/BF.mol
# output_file: /home/ahurta92/data/august/dalton/hf/BF/dipole/freq_BF-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/OCl2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/OCl2/dipole/freq_OCl2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/HBS.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HBS/dipole/freq_HBS-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/C2H2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/C2H2/dipole/freq_C2H2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/HF.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HF/dipole/freq_HF-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/SO2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SO2/dipole/freq_SO2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/Cl2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/Cl2/dipole/freq_Cl2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/Ar.mol
# output_file: /home/ahurta92/data/august/dalton/hf/Ar/dipole/freq_Ar-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/PH3.mol
# output_file: /home/ahurta92/data/august/dalton/hf/PH3/dipole/freq_PH3-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/NH3.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NH3/dipole/freq_NH3-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/CH2BH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH2BH/dipole/freq_CH2BH-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/HCCF.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCCF/dipole/freq_HCCF-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/CH2NH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH2NH/dipole/freq_CH2NH-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/SCl2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SCl2/dipole/freq_SCl2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/CH3SH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH3SH/dipole/freq_CH3SH-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/CH3Cl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH3Cl/dipole/freq_CH3Cl-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/BeH2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/BeH2/dipole/freq_BeH2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/LiCl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/LiCl/dipole/freq_LiCl-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/HCHS.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCHS/dipole/freq_HCHS-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/NaH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NaH/dipole/freq_NaH-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/Ne.mol
# output_file: /home/ahurta92/data/august/dalton/hf/Ne/dipole/freq_Ne-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/BH3.mol
# output_file: /home/ahurta92/data/august/dalton/hf/BH3/dipole/freq_BH3-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/C2H4.mol
# output_file: /home/ahurta92/data/august/dalton/hf/C2H4/dipole/freq_C2H4-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/ClCN.mol
# output_file: /home/ahurta92/data/august/dalton/hf/ClCN/dipole/freq_ClCN-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/OF2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/OF2/dipole/freq_OF2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/CH4.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH4/dipole/freq_CH4-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/BH2F.mol
# output_file: /home/ahurta92/data/august/dalton/hf/BH2F/dipole/freq_BH2F-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/HCONH2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCONH2/dipole/freq_HCONH2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/LiCN.mol
# output_file: /home/ahurta92/data/august/dalton/hf/LiCN/dipole/freq_LiCN-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/Be.mol
# output_file: /home/ahurta92/data/august/dalton/hf/Be/dipole/freq_Be-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/CH3BH2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH3BH2/dipole/freq_CH3BH2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/NOCl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NOCl/dipole/freq_NOCl-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/CS.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CS/dipole/freq_CS-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/He.mol
# output_file: /home/ahurta92/data/august/dalton/hf/He/dipole/freq_He-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/SiH4.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SiH4/dipole/freq_SiH4-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/CO.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CO/dipole/freq_CO-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/O3.mol
# output_file: /home/ahurta92/data/august/dalton/hf/O3/dipole/freq_O3-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/BHF2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/BHF2/dipole/freq_BHF2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/NaCN.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NaCN/dipole/freq_NaCN-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/CH3F.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH3F/dipole/freq_CH3F-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/C6H6.mol
# output_file: /home/ahurta92/data/august/dalton/hf/C6H6/dipole/freq_C6H6-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/Li2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/Li2/dipole/freq_Li2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/FCN.mol
# output_file: /home/ahurta92/data/august/dalton/hf/FCN/dipole/freq_FCN-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/CH3NH2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH3NH2/dipole/freq_CH3NH2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/SiH3Cl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SiH3Cl/dipole/freq_SiH3Cl-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/NH2F.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NH2F/dipole/freq_NH2F-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/CO2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CO2/dipole/freq_CO2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/HCP.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCP/dipole/freq_HCP-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/NH2OH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NH2OH/dipole/freq_NH2OH-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/N2H2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/N2H2/dipole/freq_N2H2-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/HNO.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HNO/dipole/freq_HNO-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/ClF.mol
# output_file: /home/ahurta92/data/august/dalton/hf/ClF/dipole/freq_ClF-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/LiBH4.mol
# output_file: /home/ahurta92/data/august/dalton/hf/LiBH4/dipole/freq_LiBH4-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/HNC.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HNC/dipole/freq_HNC-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/H2O.mol
# output_file: /home/ahurta92/data/august/dalton/hf/H2O/dipole/freq_H2O-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/HCOOH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCOOH/dipole/freq_HCOOH-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/HOF.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HOF/dipole/freq_HOF-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/HBO.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HBO/dipole/freq_HBO-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/HOOH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HOOH/dipole/freq_HOOH-aug-cc-pVTZ.out
# /home/ahurta92/data/august/molecules/NH2Cl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NH2Cl/dipole/freq_NH2Cl-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/NaLi.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NaLi/dipole/freq_NaLi-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/F2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/F2/dipole/freq_F2-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/HNS.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HNS/dipole/freq_HNS-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/N2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/N2/dipole/freq_N2-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/HCHO.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCHO/dipole/freq_HCHO-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/SF2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SF2/dipole/freq_SF2-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/LiH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/LiH/dipole/freq_LiH-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/Na2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/Na2/dipole/freq_Na2-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/SiO.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SiO/dipole/freq_SiO-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/Mg.mol
# output_file: /home/ahurta92/data/august/dalton/hf/Mg/dipole/freq_Mg-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/BH2Cl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/BH2Cl/dipole/freq_BH2Cl-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/SH2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SH2/dipole/freq_SH2-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/P2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/P2/dipole/freq_P2-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/HOCl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HOCl/dipole/freq_HOCl-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/N2H4.mol
# output_file: /home/ahurta92/data/august/dalton/hf/N2H4/dipole/freq_N2H4-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/NaCl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NaCl/dipole/freq_NaCl-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/HCCCl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCCCl/dipole/freq_HCCCl-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/SiH3F.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SiH3F/dipole/freq_SiH3F-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/HCl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCl/dipole/freq_HCl-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/P2H4.mol
# output_file: /home/ahurta92/data/august/dalton/hf/P2H4/dipole/freq_P2H4-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/HCN.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCN/dipole/freq_HCN-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/H2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/H2/dipole/freq_H2-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/Mg2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/Mg2/dipole/freq_Mg2-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/CSO.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CSO/dipole/freq_CSO-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/PH3O.mol
# output_file: /home/ahurta92/data/august/dalton/hf/PH3O/dipole/freq_PH3O-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/FNO.mol
# output_file: /home/ahurta92/data/august/dalton/hf/FNO/dipole/freq_FNO-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/S2H2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/S2H2/dipole/freq_S2H2-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/CH3OH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH3OH/dipole/freq_CH3OH-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/NH3O.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NH3O/dipole/freq_NH3O-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/BF.mol
# output_file: /home/ahurta92/data/august/dalton/hf/BF/dipole/freq_BF-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/OCl2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/OCl2/dipole/freq_OCl2-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/HBS.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HBS/dipole/freq_HBS-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/C2H2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/C2H2/dipole/freq_C2H2-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/HF.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HF/dipole/freq_HF-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/SO2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SO2/dipole/freq_SO2-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/Cl2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/Cl2/dipole/freq_Cl2-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/Ar.mol
# output_file: /home/ahurta92/data/august/dalton/hf/Ar/dipole/freq_Ar-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/PH3.mol
# output_file: /home/ahurta92/data/august/dalton/hf/PH3/dipole/freq_PH3-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/NH3.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NH3/dipole/freq_NH3-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/CH2BH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH2BH/dipole/freq_CH2BH-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/HCCF.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCCF/dipole/freq_HCCF-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/CH2NH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH2NH/dipole/freq_CH2NH-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/SCl2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/SCl2/dipole/freq_SCl2-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/CH3SH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH3SH/dipole/freq_CH3SH-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/CH3Cl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/CH3Cl/dipole/freq_CH3Cl-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/BeH2.mol
# output_file: /home/ahurta92/data/august/dalton/hf/BeH2/dipole/freq_BeH2-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/LiCl.mol
# output_file: /home/ahurta92/data/august/dalton/hf/LiCl/dipole/freq_LiCl-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/HCHS.mol
# output_file: /home/ahurta92/data/august/dalton/hf/HCHS/dipole/freq_HCHS-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/NaH.mol
# output_file: /home/ahurta92/data/august/dalton/hf/NaH/dipole/freq_NaH-aug-cc-pVQZ.out
# /home/ahurta92/data/august/molecules/Ne.mol
# ...
# cannot reshape array of size 0 into shape (3,3) SiH3Cl d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) SiH3Cl d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) SiH3Cl d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) SiH3Cl d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) SiH3Cl d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) SiH3Cl d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2F aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2F aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2F aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2F aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2F aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2F aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2F aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2F aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2F aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2F d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2F d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2F d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2F d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2F d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2F d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2F d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2F d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2F d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) CO2 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) CO2 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) CO2 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) CO2 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) CO2 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) CO2 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) CO2 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) CO2 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) CO2 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) CO2 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) CO2 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) CO2 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) CO2 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) CO2 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) CO2 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) CO2 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) CO2 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) CO2 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCP aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCP aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCP aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCP aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCP aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCP aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCP aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCP aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCP aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCP d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCP d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCP d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCP d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCP d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCP d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCP d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCP d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCP d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2OH aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2OH aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2OH aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2OH aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2OH aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2OH aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2OH aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2OH aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2OH aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2OH d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2OH d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2OH d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2OH d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2OH d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2OH d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2OH d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2OH d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) NH2OH d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) N2H2 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) N2H2 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) N2H2 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) N2H2 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) N2H2 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) N2H2 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) N2H2 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) N2H2 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) N2H2 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) N2H2 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) N2H2 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) N2H2 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) N2H2 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) N2H2 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) N2H2 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) N2H2 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) N2H2 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) N2H2 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNO aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNO aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNO aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNO aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNO aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNO aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNO aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNO aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNO aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNO d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNO d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNO d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNO d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNO d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNO d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNO d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNO d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNO d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) ClF aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) ClF aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) ClF aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) ClF aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) ClF aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) ClF aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) ClF aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) ClF aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) ClF aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) ClF d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) ClF d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) ClF d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) ClF d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) ClF d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) ClF d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) ClF d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) ClF d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) ClF d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) LiBH4 d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNC aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNC aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNC aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNC aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNC aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNC aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNC aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNC aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNC aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNC d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNC d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNC d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNC d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNC d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNC d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNC d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNC d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HNC d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCOOH aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCOOH aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCOOH aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCOOH aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCOOH aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCOOH aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCOOH aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCOOH aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCOOH aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCOOH d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCOOH d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCOOH d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCOOH d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCOOH d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCOOH d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCOOH d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCOOH d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HCOOH d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HOF aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HOF aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HOF aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HOF aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HOF aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HOF aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HOF aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HOF aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HOF aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HOF d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HOF d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HOF d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HOF d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HOF d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HOF d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HOF d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HOF d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HOF d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HBO aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HBO aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HBO aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HBO aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HBO aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HBO aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HBO aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HBO aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HBO aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HBO d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HBO d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HBO d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HBO d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HBO d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HBO d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HBO d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HBO d-aug-cc-pV6Z
# cannot reshape array of size 0 into shape (3,3) HBO d-aug-cc-pV6Z
# Could not initialize alpha_eigen
# eigen_diff
# cannot handle a non-unique multi-index!
# Could not initialize eigen_diff
# iso_data
# Could not initialize iso_data

# %%
august_database.save_dfs()
polar_data = august_database.iso_data.copy()
# Out:
# 'NoneType' object has no attribute 'copy'
# Could not save eigen_diff

# %%
august_database.energy_df.basis.unique()
# Out:
# array(['MRA', 'aug-cc-pVDZ', 'aug-cc-pVTZ', 'aug-cc-pVQZ', 'aug-cc-pV5Z',
#        'aug-cc-pV6Z', 'aug-cc-pCVDZ', 'aug-cc-pCVTZ', 'aug-cc-pCVQZ',
#        'd-aug-cc-pVDZ', 'd-aug-cc-pVTZ', 'd-aug-cc-pVQZ', 'd-aug-cc-pV5Z',
#        'd-aug-cc-pV6Z', 'd-aug-cc-pCVDZ', 'd-aug-cc-pCVTZ',
#        'd-aug-cc-pCVQZ'], dtype=object)

# %%
class MRAComparedBasisDF(pd.DataFrame):
    def __init__(self, polar_data, index, values: list, PercentError: bool, *args, **kwargs):
        # Use the special_parameter to modify the DataFrame or perform additional initialization
        basis_data = polar_data.query('basis!="MRA"').copy()
        basis_data = basis_data.set_index(index)

        for value in values:
            basis_data[f'{value}MRA'] = polar_data.query('basis=="MRA"').set_index(index)[
                value]
            if PercentError:
                basis_data[f'{value}E'] = ((basis_data[value] - basis_data[f'{value}MRA']) / basis_data[f'{value}MRA'] * 100)
            else:
                basis_data[f'{value}E'] = (basis_data[value] - basis_data[f'{value}MRA'])
        basis_data = basis_data.reset_index()
        # create a column of percent error in alpha
        basis_data = make_detailed_df(basis_data)
        super().__init__(basis_data, *args, **kwargs)


basis_data = MRAComparedBasisDF(polar_data, ['molecule', 'omega'], ['alpha', 'gamma'], True)
basis_data
# Out:
# ['D', 'T', 'Q', '5', '6']
#       molecule  omega          basis      alpha      gamma   alphaMRA  \
# 0        NH2Cl      0    aug-cc-pVDZ  24.800048  12.340561  25.978063
# 1        NH2Cl      1    aug-cc-pVDZ  24.814924  12.356587  25.994977
# 2        NH2Cl      2    aug-cc-pVDZ  24.859753  12.404995  26.045737
# 3        NH2Cl      3    aug-cc-pVDZ  24.935151  12.486799  26.131067
# 4        NH2Cl      4    aug-cc-pVDZ  25.042193  12.603777  26.252403
# ...        ...    ...            ...        ...        ...        ...
# 12811     HOOH      4  d-aug-cc-pV6Z  14.557781   9.197190  14.562407
# 12812     HOOH      5  d-aug-cc-pV6Z  14.637270   9.301981  14.642040
# 12813     HOOH      6  d-aug-cc-pV6Z  14.736426   9.433393  14.741137
# 12814     HOOH      7  d-aug-cc-pV6Z  14.856592   9.593652  14.861393
# 12815     HOOH      8  d-aug-cc-pV6Z  14.999500   9.785616  15.004430
#
#          alphaE   gammaMRA    gammaE augmentation polarization  mol_system  \
# 0     -4.534652  11.913106  3.588107          aug            V  Second-row
# 1     -4.539541  11.928273  3.590745          aug            V  Second-row
# 2     -4.553467  11.973083  3.607364          aug            V  Second-row
# 3     -4.576603  12.048642  3.636568          aug            V  Second-row
# 4     -4.609904  12.156879  3.676094          aug            V  Second-row
# ...         ...        ...       ...          ...          ...         ...
# 12811 -0.031763   9.209097 -0.129296        d-aug            V   First-row
# 12812 -0.032579   9.314205 -0.131249        d-aug            V   First-row
# 12813 -0.031954   9.445753 -0.130859        d-aug            V   First-row
# 12814 -0.032309   9.606048 -0.129052        d-aug            V   First-row
# 12815 -0.032859   9.798800 -0.134542        d-aug            V   First-row
#
#       valence           Type
# 0           D    aug-cc-pVnZ
# 1           D    aug-cc-pVnZ
# 2           D    aug-cc-pVnZ
# 3           D    aug-cc-pVnZ
# 4           D    aug-cc-pVnZ
# ...       ...            ...
# 12811       6  d-aug-cc-pVnZ
# 12812       6  d-aug-cc-pVnZ
# 12813       6  d-aug-cc-pVnZ
# 12814       6  d-aug-cc-pVnZ
# 12815       6  d-aug-cc-pVnZ
#
# [12816 rows x 14 columns]

# %%
num_mols=len(basis_data.molecule.unique())
print(f'Number of molecules: {num_mols}')
# Out:
# Number of molecules: 89

# %%
basis_data.query("molecule=='Ne' and omega == 0")
# Out:
#      molecule  omega           basis     alpha         gamma  alphaMRA  \
# 7200       Ne      0     aug-cc-pVDZ  1.831917  1.037834e-10  2.376665
# 7209       Ne      0     aug-cc-pVTZ  2.193942  9.475649e-09  2.376665
# 7218       Ne      0     aug-cc-pVQZ  2.328988  4.053901e-10  2.376665
# 7227       Ne      0     aug-cc-pV5Z  2.363141  4.392022e-11  2.376665
# 7236       Ne      0    aug-cc-pCVDZ  1.833719  1.107388e-08  2.376665
# 7245       Ne      0    aug-cc-pCVTZ  2.196285  2.965012e-10  2.376665
# 7254       Ne      0    aug-cc-pCVQZ  2.329381  1.808563e-10  2.376665
# 7263       Ne      0   d-aug-cc-pVDZ  2.353456  4.872000e-08  2.376665
# 7272       Ne      0   d-aug-cc-pVTZ  2.374675  5.898482e-09  2.376665
# 7281       Ne      0   d-aug-cc-pVQZ  2.379506  9.930217e-09  2.376665
# 7290       Ne      0   d-aug-cc-pV5Z  2.377062  5.478823e-10  2.376665
# 7299       Ne      0  d-aug-cc-pCVDZ  2.354698  9.996448e-13  2.376665
# 7308       Ne      0  d-aug-cc-pCVTZ  2.377554  7.961387e-09  2.376665
# 7317       Ne      0  d-aug-cc-pCVQZ  2.379728  4.384371e-09  2.376665
# 7326       Ne      0     aug-cc-pV6Z  2.369781  4.448812e-10  2.376665
# 7335       Ne      0   d-aug-cc-pV6Z  2.376423  3.873179e-09  2.376665
#
#          alphaE  gammaMRA     gammaE augmentation polarization mol_system  \
# 7200 -22.920675  0.000012 -99.999110          aug            V  First-row
# 7209  -7.688216  0.000012 -99.918734          aug            V  First-row
# 7218  -2.006046  0.000012 -99.996523          aug            V  First-row
# 7227  -0.569018  0.000012 -99.999623          aug            V  First-row
# 7236 -22.844866  0.000012 -99.905027          aug           CV  First-row
# 7245  -7.589612  0.000012 -99.997457          aug           CV  First-row
# 7254  -1.989510  0.000012 -99.998449          aug           CV  First-row
# 7263  -0.976521  0.000012 -99.582162        d-aug            V  First-row
# 7272  -0.083729  0.000012 -99.949413        d-aug            V  First-row
# 7281   0.119558  0.000012 -99.914835        d-aug            V  First-row
# 7290   0.016708  0.000012 -99.995301        d-aug            V  First-row
# 7299  -0.924255  0.000012 -99.999991        d-aug           CV  First-row
# 7308   0.037430  0.000012 -99.931721        d-aug           CV  First-row
# 7317   0.128900  0.000012 -99.962398        d-aug           CV  First-row
# 7326  -0.289650  0.000012 -99.996185          aug            V  First-row
# 7335  -0.010173  0.000012 -99.966782        d-aug            V  First-row
#
#      valence            Type
# 7200       D     aug-cc-pVnZ
# 7209       T     aug-cc-pVnZ
# 7218       Q     aug-cc-pVnZ
# 7227       5     aug-cc-pVnZ
# 7236       D    aug-cc-pCVnZ
# 7245       T    aug-cc-pCVnZ
# 7254       Q    aug-cc-pCVnZ
# 7263       D   d-aug-cc-pVnZ
# 7272       T   d-aug-cc-pVnZ
# 7281       Q   d-aug-cc-pVnZ
# 7290       5   d-aug-cc-pVnZ
# 7299       D  d-aug-cc-pCVnZ
# 7308       T  d-aug-cc-pCVnZ
# 7317       Q  d-aug-cc-pCVnZ
# 7326       6     aug-cc-pVnZ
# 7335       6   d-aug-cc-pVnZ

# %%
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter

Type_map = {"aug-cc-pVnZ": "sn", "aug-cc-pCVnZ": "sCn", "d-aug-cc-pVnZ": "dn",
            "d-aug-cc-pCVnZ": "dCn"}
aspect_ratio = .5
vlevel = ['D', 'T', 'Q', '5']
plot_data = basis_data.query('valence.isin(@vlevel) and omega==0').copy()
# remove unused categories from valence
plot_data.valence = plot_data.valence.cat.remove_unused_categories()
with sns.plotting_context('paper', font_scale=1.00):
    g = sns.catplot(col='valence', x='Type', y='alphaE', hue='mol_system',
                    data=plot_data, kind='strip', dodge=True, jitter=True,
                    s=15, palette='colorblind', height=4, aspect=aspect_ratio, sharey=True,
                    alpha=0.5,
                    sharex=False)
    # adjust the title to read D=$\zeta$D, T=$\zeta$T, etc.
    g.set_titles('{col_name}Z')
    g.set_xlabels('')

    g.set_xticklabels([Type_map[label.get_text()] for label in g.axes.flat[0].get_xticklabels()])
    v = 0
    for ax in g.axes.flat:
        # draw horizontal line at .05%
        # get the valence level from the title
        c = vlevel[v]
        v += 1
        print(c)
        xl = ['aug', 'aug+core', 'd-aug', 'd-aug+core']
        xl = ['s-n', 's-Cn', 'd-n', 'd-Cn']
        xl = ['sn', 'sCn', 'dn', 'dCn']
        ax.set_xticklabels(xl)

        ax.set_yscale('symlog', linthresh=1e-1)
        ax.axhline(y=.05, linestyle='--', color='orange')
        ax.axhline(y=-.05, linestyle='--', color='orange')
        # for the symlog scale to regular notation with no decimal places for the y axis
        ax.yaxis.set_major_formatter(ScalarFormatter())
        ax.yaxis.set_major_formatter(FormatStrFormatter('%2g'))

        # make the y limits symmetrical for each plot using the max absolute value
        max_lim = max(abs(ax.get_ylim()[0]), abs(ax.get_ylim()[1]))
        ax.set_ylim(-30, 30)

        ax.set_ylabel(r'$\alpha$ Error (%)')
        # rotate the xlabels
        for label in ax.get_xticklabels():
            label.set_rotation(0)
            #label.set_horizontalalignment('right')
        # create vertical lines to separate basis sets
        for i in range(1, len(plot_data.Type.unique())):
            ax.axvline(i - .5, linestyle='-.', color='k', linewidth=.5, alpha=.8)
        for i in range(1, 5):
            ax.axvspan((i - 1) - .5, i - .5, 1e-3, facecolor=pal[i - 1], alpha=0.1)

        # remove the legend title

# remove legend and create a new legend in 3 column format outside the plot
g._legend.remove()
g.fig.legend(loc='center', bbox_to_anchor=(0.5, 1.05), ncol=3, fancybox=True, fontsize=10)
g.fig.tight_layout()
# Out:
# D
# T
# Q
# 5

# %%
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
Type_map = {"aug-cc-pVnZ": "sn", "aug-cc-pCVnZ": "sCn", "d-aug-cc-pVnZ": "dn",
            "d-aug-cc-pCVnZ": "dCn"}
vlevel = ['D', 'T', 'Q', '5']
plot_data = basis_data.query('valence.isin(@vlevel) and omega==0').copy()

height = 3.0
aspect_ratio = 1.05
palette = 'colorblind'
kind = 'strip'
dodge = True
jitter = .05
alpha = 0.8
s = 10

# remove unused categories from valencej
plot_data.valence = plot_data.valence.cat.remove_unused_categories()
with sns.plotting_context('paper', font_scale=1.25):
    g = sns.catplot(x='valence', col='Type', y='alphaE', hue='mol_system',
                    data=plot_data,
                    kind=kind, dodge=jitter, jitter=jitter,
                    palette=palette, height=height, aspect=aspect_ratio, sharey=True,
                     alpha=0.7, s=s
                    )
    g.set_ylabels(r'$\alpha$ Error (%)')
    g.set_titles(row_template='{row_name}Z', col_template='{col_name}')
    g.set_xlabels('')
    
    

    types=['aug-cc-pVnZ','aug-cc-pCVnZ','d-aug-cc-pVnZ','d-aug-cc-pCVnZ']
    for i ,ax in enumerate(g.axes.flat):
        ax.axhline(y=.00, linestyle='--', color='black', linewidth=.35)
        ax.set_yscale('symlog', linthresh=1e-1)
        ax.yaxis.set_major_formatter(ScalarFormatter())
        ax.set_ylim(-30, 30)
        ax.axhline(y=.02, linestyle='--', color='red', linewidth=.50)
        ax.axhline(y=-.02, linestyle='--', color='red', linewidth=.50)
        if i>=4: 
            t=types[i]
            inset_ax=inset_axes(ax,width="90%",height="40%",loc="lower center")
            vs=['D','T','Q','5']
            inset_data=plot_data.query('valence.isin(@vs)').copy()
            inset_data.valence = inset_data.valence.cat.remove_unused_categories()
            inset_data=inset_data.query('Type==@t')
            sns.stripplot(data=inset_data,x='valence',y='alphaE',hue='mol_system',ax=inset_ax,legend=False,dodge=True,jitter=.1,alpha=.7,s=2.5,palette='colorblind')
            inset_ax.set_ylabel('')
            inset_ax.set_xlabel('')
            # remove tick marks from x axis
            inset_ax.set_xticks([])
            inset_ax.axhline(y=.02, linestyle='--', color='red', linewidth=.50)
            inset_ax.axhline(y=-.02, linestyle='--', color='red', linewidth=.50)
            
            inset_ax.set_yscale('symlog', linthresh=1e-1)
            inset_ax.yaxis.set_major_formatter(ScalarFormatter())

            # draw red box around the inset
            #inset_ax.add_patch(plt.Rectangle((1.5, -0.25), 2, 0.5, fill=False, edgecolor='black', lw=1,))
            
            # draw red box around the data in regular plot
            #ax.add_patch(plt.Rectangle((1.5, -2.0), 2, 4.0, fill=True, edgecolor='black', lw=1,facecolor='grey',alpha=.10))
    
        #ax.axhline(y=-.02, linestyle='--', color='black', linewidth=.35)
        # rotate the xlabels

# remove legend and create a new legend in 3 column format outside the plot
g._legend.remove()
g.fig.tight_layout()
g.fig.legend(loc='center', bbox_to_anchor=(0.5, 1.015), ncol=3, fancybox=True, fontsize=10)
#g.fig.savefig(paper_path.joinpath('gamma_error.png'), dpi=600, bbox_inches='tight')
g.fig.savefig(paper_path.joinpath('alpha_error.png'), dpi=600, bbox_inches='tight')

# %%
jitter = .05
alpha = 0.8
vlevel = ['D', 'T', 'Q', '5']
plot_data = basis_data.query('valence.isin(@vlevel) and omega==0 & gamma > 1e-3').copy()
# remove unused categories from valence
plot_data.valence = plot_data.valence.cat.remove_unused_categories()
aspect_ratio =1.05 
with sns.plotting_context('paper', font_scale=1.00):
    g = sns.catplot(x='valence', col='Type', y='gammaE', hue='mol_system',
                    data=plot_data,
                    kind=kind, dodge=jitter, jitter=jitter,
                    palette=palette, height=height, aspect=aspect_ratio, sharey=True,
                    alpha=alpha, s=s
                    )
    # adjust the title to read D=$\zeta$D, T=$\zeta$T, etc.
    g.set_titles(row_template='{row_name}Z', col_template='{col_name}')

    g.set_ylabels(r'$\gamma$ Error (%)')
    g.set_xlabels('')
    for i, ax in enumerate(g.axes.flat):
        ax.axhline(y=0, linestyle='--', color='black', linewidth=.35)
        ax.set_ylim(-500, 500)
        ax.axhline(y=.2, linestyle='--', color='red', linewidth=.50)
        ax.axhline(y=-.2, linestyle='--', color='red', linewidth=.50)
        ax.set_yscale('symlog', linthresh=1)
        ax.yaxis.set_major_formatter(ScalarFormatter())

g._legend.remove()
g.fig.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=3, fancybox=True, fontsize=10)
g.fig.tight_layout()
g.fig.savefig(paper_path.joinpath('gamma_error.png'), dpi=600, bbox_inches='tight')

# %%
vlevel = ['D', 'T', 'Q', '5']
basis_e_data = MRAComparedBasisDF(august_database.energy_df, ['molecule'], ['energy'], False)
plot_data = basis_e_data.query('valence.isin(@vlevel)').copy()
# remove unused categories from valence
# remove unused categories from valence
plot_data.valence = plot_data.valence.cat.remove_unused_categories()
with sns.plotting_context('paper', font_scale=1.00):
    g = sns.catplot(x='valence', col='Type', y='energyE', hue='mol_system',
                    data=plot_data,
                    kind=kind, dodge=jitter, jitter=jitter,
                    palette=palette, height=height, aspect=aspect_ratio, sharey=True,
                    alpha=0.7, s=s
                    )
    # adjust the title to read D=$\zeta$D, T=$\zeta$T, etc.
    g.set_titles(row_template='{row_name}Z', col_template='{col_name}')

    g.set_xlabels('')
    g.set_ylabels(r'Energy Error (a.u.)')
    for i, ax in enumerate(g.axes.flat):
        #ax.axhline(y=.02, linestyle='--', color='black', linewidth=.35)
        ax.axhline(y=-.00, linestyle='--', color='black', linewidth=.35)
g._legend.remove()
g.fig.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=3, fancybox=True, fontsize=10)
g.fig.tight_layout()
g.fig.savefig(paper_path.joinpath('energy_error.png'), dpi=600, bbox_inches='tight')
# Out:
# ['D', 'T', 'Q', '5', '6']

# %%
# Now make a plot of the frequency dependence of the error

vlevel = ['D', 'T', 'Q', '5']
plot_data = basis_data.query('valence.isin(@vlevel)').copy()
# remove unused categories from valence
plot_data.valence = plot_data.valence.cat.remove_unused_categories()
aspect_ratio = 1.2
with sns.plotting_context('paper', font_scale=1.00):
    g = sns.catplot(row='valence', col='Type',
                    x='omega',
                    y='alphaE', hue='mol_system',
                    data=plot_data, kind='strip',
                    dodge=True, jitter=False,
                    palette='colorblind',
                    height=1.5, aspect=aspect_ratio, sharex=True, sharey='row',
                    alpha=alpha,
                    s=5,
                    margin_titles=True,
                    )

    # adjust the title to read D=$\zeta$D, T=$\zeta$T, etc.
    g.set_titles(col_template='{col_name}', row_template='{row_name}Z')

    g.set_xlabels('Frequency')
    for ax in g.axes.flat:
        # draw horizontal line at .05%rue
        #ax.set_yscale('symlog', linthresh=1e-1)
        ax.axhline(y=.02, linestyle='--', color='black', linewidth=.35)
        ax.axhline(y=-.02, linestyle='--', color='black', linewidth=.35)
        # for the symlog scale to regular notation with no decimal places for the y axis

        # make the y limits symmetrical for each plot using the max absolute value
        max_lim = max(abs(ax.get_ylim()[0]), abs(ax.get_ylim()[1]))
        #ax.set_ylim(-max_lim, max_lim)
        # remove the y axis label if not the first column
        if ax.get_subplotspec().colspan.start != 0:
            ax.set_ylabel('')
        else:
            ax.set_ylabel(r'$\alpha$ Error (%)')

        #ax.set_ylabel(r'$\alpha$ Error (%)')
        # rotate the xlabels
        for label in ax.get_xticklabels():
            label.set_horizontalalignment('right')

        # create vertical lines to separate basis sets
        for i in range(1, len(plot_data.omega.unique())):
            ax.axvline(i - .5, linestyle='-.', color='k', linewidth=.5, alpha=0.5)

# remove legend and create a new legend in 3 column format outside the plot
g._legend.remove()
# rename legend title
#g._legend.set_title('Subset')
g.fig.tight_layout()
g.fig.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05), ncol=3, fancybox=True, fontsize=10)
g.fig.savefig(paper_path.joinpath('alpha_freq_error.png'), dpi=600, bbox_inches='tight')

# %%
# query molecules with alphaE.abs()>.2 in singly augmented 5Z basis
plot_data = basis_data.query('valence=="5" and augmentation=="aug" and alphaE.abs()>.2').copy()
mol5 = plot_data.molecule.unique()

# %%
# query molecules with alphaE.abs()>.2 in singly augmented 5Z basis
plot_data = basis_data.query('valence=="Q" and Type=="d-aug-cc-pVnZ" and alphaE.abs()>.25').copy()
daug_outliers = plot_data.molecule.unique()
plot_data = basis_data.query('valence=="Q" and Type=="aug-cc-pVnZ" and alphaE.abs()>.6').copy()
aug_outliers = plot_data.molecule.unique()

# %%
vlevel = ['Q']
plot_data = (basis_data.query('valence.isin(@vlevel) & molecule.isin(@aug_outliers)')
             .copy())
# remove unused categories from valence
plot_data.valence = plot_data.valence.cat.remove_unused_categories()
facet_kws = {'margin_titles': True, 'sharey': False, 'sharex': True}

with sns.plotting_context('paper', font_scale=1.05):
    g = sns.relplot(col='molecule',
                    col_wrap=3,
                    x='omega',
                    y='alphaE',
                    hue='Type',
                    style='Type',
                    data=plot_data, kind='line',
                    palette='colorblind', height=2.0, aspect=1.2,
                    markers=True,
                    ms=5,
                    facet_kws=facet_kws)
    # adjust the title to read D=$\zeta$D, T=$\zeta$T, etc.

    g.set_xlabels('Frequency')
    ax_titles = ['aug-cc-pVQZ', 'aug-cc-pCVQZ', 'd-aug-cc-pVQZ', 'd-aug-cc-pCVQZ']
    g.set_titles(col_template='{col_name}')
    for i, ax in enumerate(g.axes.flat):
        # draw horizontal line at .05%rue
        #ax.set_yscale('symlog', linthresh=1e-2)
        max_lim = max(abs(ax.get_ylim()[0]), abs(ax.get_ylim()[1]))
        ax.set_ylim(-max_lim, max_lim)
        ax.axhline(y=.02, linestyle='--', color='black', linewidth=.35)
        ax.axhline(y=-.02, linestyle='--', color='black', linewidth=.35)
        # for the symlog scale to regular notation with no decimal places for the y axis

        if i % 3 == 0:
            ax.set_ylabel(r'$\alpha$ Error (%)')
        else:
            ax.set_ylabel('')
        # rotate the xlabels
        for label in ax.get_xticklabels():
            label.set_horizontalalignment('right')

g.fig.tight_layout()
g._legend.remove()
g.fig.legend(loc='upper center', bbox_to_anchor=(0.5, 1.060), fancybox=False, ncol=4)
g.fig.savefig(paper_path.joinpath('frequency_dependent_iso_error.png'), dpi=600,
              bbox_inches='tight')

# %%
ij_basis_data = MRAComparedBasisDF(august_database.alpha_eigen, ['molecule', 'ij', 'omega'], ['alpha'], True)
selection = ['SF2', 'Na2', 'NaCl', 'BH2Cl', 'HF', ]
vlevel = ['Q']
plot_data = (ij_basis_data.query('valence.isin(@vlevel) & molecule.isin(@selection)')
             .copy())
# remove unused categories from valence
plot_data.valence = plot_data.valence.cat.remove_unused_categories()
facet_kws = {'margin_titles': True, 'sharey': "row", 'sharex': True}

with sns.plotting_context('paper', font_scale=1.00):
    g = sns.relplot(row='molecule',
                    x='omega',
                    y='alphaE',
                    hue='Type',
                    col='ij',
                    data=plot_data, kind='line',
                    palette='colorblind',
                    height=2.0, aspect=1.2,
                    markers=True,
                    style='Type',
                    ms=7,
                    facet_kws=facet_kws)
    # adjust the title to read D=$\zeta$D, T=$\zeta$T, etc.
    g.set_xlabels('Frequency')
    ax_titles = ['aug-cc-pVQZ', 'aug-cc-pCVQZ', 'd-aug-cc-pVQZ', 'd-aug-cc-pCVQZ']
    g.set_titles(col_template='{col_name}', row_template='{row_name}')
    for i, ax in enumerate(g.axes.flat):
        # draw horizontal line at .05%rue
        #ax.set_yscale('symlog', linthresh=1e-2)
        #ax.axhline(y=.02, linestyle='--', color='black',linewidth=.35)
        #ax.axhline(y=-.02, linestyle='--', color='black',linewidth=.35)
        max_lim = max(abs(ax.get_ylim()[0]), abs(ax.get_ylim()[1]))
        ax.set_ylim(-max_lim, max_lim)
        # for the symlog scale to regular notation with no decimal places for the y axis

        if i % 3 == 0:
            ax.set_ylabel(r'$\alpha$ Error (%)')
        else:
            ax.set_ylabel('')
        # rotate the xlabels
        for label in ax.get_xticklabels():
            label.set_horizontalalignment('right')

g.fig.tight_layout()
g._legend.remove()
g.fig.legend(loc='upper center', bbox_to_anchor=(0.5, 1.025), fancybox=True, ncol=4)
g.fig.savefig(paper_path.joinpath('frequency_dependent_component_error.png'), dpi=600,
              bbox_inches='tight')
# Out:
# ['D', 'T', 'Q', '5', '6']

# %%
ij_basis_data = MRAComparedBasisDF(august_database.alpha_eigen, ['molecule', 'ij', 'omega'], ['alpha'], True)
ij_basis_data
# Out:
# ['D', 'T', 'Q', '5', '6']
#       molecule  ij  omega          basis      alpha   alphaMRA    alphaE  \
# 0        NH2Cl  xx      0    aug-cc-pVDZ  20.384307  21.692139 -6.029056
# 1        NH2Cl  yy      0    aug-cc-pVDZ  20.996341  22.330470 -5.974476
# 2        NH2Cl  zz      0    aug-cc-pVDZ  33.019497  33.911581 -2.630619
# 3        NH2Cl  xx      1    aug-cc-pVDZ  20.394315  21.704507 -6.036499
# 4        NH2Cl  yy      1    aug-cc-pVDZ  21.005366  22.341780 -5.981679
# ...        ...  ..    ...            ...        ...        ...       ...
# 33394     HOOH  yy      7  d-aug-cc-pV6Z  12.180094  12.180836 -0.006091
# 33395     HOOH  zz      7  d-aug-cc-pV6Z  21.225413  21.238564 -0.061921
# 33396     HOOH  xx      8  d-aug-cc-pV6Z  11.242943  11.243240 -0.002638
# 33397     HOOH  yy      8  d-aug-cc-pV6Z  12.258726  12.259365 -0.005209
# 33398     HOOH  zz      8  d-aug-cc-pV6Z  21.496830  21.510685 -0.064413
#
#       augmentation polarization  mol_system valence           Type
# 0              aug            V  Second-row       D    aug-cc-pVnZ
# 1              aug            V  Second-row       D    aug-cc-pVnZ
# 2              aug            V  Second-row       D    aug-cc-pVnZ
# 3              aug            V  Second-row       D    aug-cc-pVnZ
# 4              aug            V  Second-row       D    aug-cc-pVnZ
# ...            ...          ...         ...     ...            ...
# 33394        d-aug            V   First-row       6  d-aug-cc-pVnZ
# 33395        d-aug            V   First-row       6  d-aug-cc-pVnZ
# 33396        d-aug            V   First-row       6  d-aug-cc-pVnZ
# 33397        d-aug            V   First-row       6  d-aug-cc-pVnZ
# 33398        d-aug            V   First-row       6  d-aug-cc-pVnZ
#
# [33399 rows x 12 columns]

# %%
# save as csv 
csv_dir_path = Path('/home/ahurta92/dev/QuantumResponsePro/examples/data_apps/csv')
ij_basis_data.to_csv(csv_dir_path.joinpath('alpha_ij.csv'))

# %%
# query molecules with alphaE.abs()>.2 in singly augmented 5Z basis
plot_data = basis_data.query('valence=="Q" and gammaE.abs()>4.0 & gamma>1e-2').copy()
gamma_outliers = plot_data.molecule.unique()
gamma_outliers.tolist()
# Out:
# ['SiO', 'SH2', 'NaCl', 'HF', 'NH3', 'BeH2', 'LiCl', 'NaH', 'H2O']

# %%
facet_kw = {'sharey': "row", 'sharex': True, "margin_titles": True}
ms = ['First-row', 'Fluorine']
type = ['aug-cc-pVnZ', 'd-aug-cc-pVnZ']
vlevels = ['D', 'T', 'Q', '5']

p_data = ij_basis_data.query('molecule.isin(@gamma_outliers) and mol_system.isin'
                             '(@ms) & Type.isin(@type) ').copy()
p_data = p_data.query('valence.isin(@vlevels) and omega==0').copy()
#p_data.Type = p_data.Type.cat.remove_unused_categories()

# plot valence vs alpha error with component hue for each molecule
with sns.plotting_context('paper', font_scale=1.0, ):
    facet_kw = {'sharey': "row", 'sharex': True, "margin_titles": True}
    g = sns.relplot(row='molecule',
                    x='valence', y='alphaE', col='ij',
                    hue='Type',
                    style='Type',
                    kind='line',
                    data=p_data,
                    markers=True,
                    dashes=True,
                    palette="colorblind",
                    height=1.5, aspect=1.2, facet_kws=facet_kw, ms=5, alpha=.8)
    # adjust the title to read D=$\zeta$D, T=$\zeta$T, etc.

    g.set_titles(col_template='{col_name}')
    g.set_ylabels(r'$\alpha_{ij}$ Error (%)')
    g.margin_titles = True
    g.set_titles(col_template='{col_name}', row_template='{row_name}')
    g.set_xlabels('')

    for ax in g.axes.flat:
        ax.axhline(y=-.00, linestyle='--', color='black', linewidth=.5)

g.fig.tight_layout()
g._legend.remove()

g.fig.legend(loc='upper center', bbox_to_anchor=(0.5, 1.025), fancybox=True, ncol=4, fontsize=8)
g.savefig(paper_path.joinpath('first_and_fluorine_component_error.png'), dpi=600)

# %%
gamma_outliers = plot_data.molecule.unique()
gamma_outliers.tolist()

gamma_outliers = gamma_outliers.tolist() + ['SF2']

selected = ['SiO', 'NaCl', 'SH2', 'NaH']

ms = ['Second-row']
p_data = ij_basis_data.query('molecule.isin(@selected) and mol_system.isin'
                             '(@ms) and omega==0').copy()
#remove 
facet_kw = {'sharey': "row", 'sharex': True, "margin_titles": True}
# plot valence vs alpha error with component hue for each moleculek
with sns.plotting_context('paper', font_scale=1.0, ):
    g = sns.relplot(row='molecule',
                    x='valence', y='alphaE', col='ij',
                    hue='Type',
                    style='Type',
                    kind='line',
                    data=p_data,
                    palette="colorblind",
                    markers=True,
                    dashes=True,
                    height=1.5, aspect=1.2, facet_kws=facet_kw, ms=5, alpha=.8)
    # adjust the title to read D=$\zeta$D, T=$\zeta$T, etc.
    g.set_titles(col_template='{col_name}')
    g.set_ylabels(r'$\alpha_{ij}$ Error (%)')
    g.set_titles(col_template='{col_name}', row_template='{row_name}')
    g.set_xlabels('')

    for ax in g.axes.flat:
        ax.axhline(y=.0, linestyle='--', color='black', linewidth=.5)

g.fig.tight_layout()
g._legend.remove()
g.fig.legend(loc='upper center', bbox_to_anchor=(0.5, 1.025), fancybox=True, ncol=4, fontsize=8)
g.savefig(paper_path.joinpath('component_error.png'), dpi=600)

# %%
basis_e_data = MRAComparedBasisDF(august_database.energy_df, ['molecule'], ['energy'], False)
len(basis_e_data.molecule.unique())
# Out:
# ['D', 'T', 'Q', '5', '6']
# 89

# %%
daug_outliers = (basis_e_data.query('valence=="Q" & basis=="d-aug-cc-pVQZ" ').sort_values
                 ('energyE',
                  ascending=False).head(20)).molecule.unique()
daugC_outliers = (basis_e_data.query('valence=="Q" & basis=="d-aug-cc-pCVQZ"').sort_values
                  ('energyE',
                   ascending=False).head(20)).molecule.unique()
e_outliers = daug_outliers.tolist() + daugC_outliers.tolist()
e_outliers = (basis_e_data.query("molecule.isin(@e_outliers) & valence=='Q' & "
                                 "augmentation=='d-aug'")
              )
# remove any values less with abs less than 0.02
e_outliers = e_outliers.query('energyE.abs()>.002').sort_values('energyE', ascending=True)

with sns.plotting_context('paper', font_scale=1.00):
    #g = sns.FacetGrid(data=e_outliers, col='polarization', hue='mol_system', sharey=True,
    #                  sharex=False, aspect=2.0, height
    #                  =10, col_order=['V', 'CV'])
    #g.map(sns.barplot, 'molecule', 'eE', 'basis',  alpha=.9)
    ## adjust title to read d-aug-cc-pVQZ
    # color the bars based on molecules mol_system typeo
    g = sns.catplot(x='molecule', y='energyE',
                    hue='mol_system',
                    col='polarization', col_order=['V', 'CV'],
                    data=e_outliers, dodge=False,
                    alpha=.9, palette='colorblind', fill=True, height=3, aspect=1.4, kind='bar',
                    sharex=False
                    )
    g.set_titles('d-aug-cc-p{col_name}QZ')
    g.set_xlabels('')
    g.set_ylabels('Energy Error (a.u.)')
    # rotate the xticks
    for ax in g.axes.flat:
        for label in ax.get_xticklabels():
            label.set_rotation(90)
            label.set_horizontalalignment('center')
    # remove legend title
    # create a new legend in 3 column format outside the plot
    # using only a single legend only using the second axis
    g.fig.savefig(paper_path.joinpath('energy_error_outliers.png'), dpi=600, bbox_inches='tight')

# %%
basis_data['absolute_alphaE'] = basis_data.alphaE.abs()

daug_outliers = (basis_data.query('valence=="Q" & basis=="d-aug-cc-pVQZ" & omega==0').sort_values
                 ('absolute_alphaE',
                  ascending=False).head(20)).molecule.unique()
daugC_outliers = (basis_data.query('valence=="Q" & basis=="d-aug-cc-pCVQZ" & omega==0').sort_values
                  ('absolute_alphaE',
                   ascending=False).head(20)).molecule.unique()

a_outliers = daug_outliers.tolist() + daugC_outliers.tolist()

a_outliers = (basis_data.query("molecule.isin(@a_outliers) & valence=='Q' & augmentation=='d-aug' ")
              .sort_values
              ('alphaE', ascending=True)
              .sort_values('alphaE'))
# remove any values less with abs less than 0.02
a_outliers = a_outliers.query('alphaE.abs()>.02')

with sns.plotting_context('paper', font_scale=1.00):
    #g = sns.FacetGrid(data=e_outliers, col='polarization', hue='mol_system', sharey=True,
    #                  sharex=False, aspect=2.0, height
    #                  =10, col_order=['V', 'CV'])
    #g.map(sns.barplot, 'molecule', 'eE', 'basis',  alpha=.9)
    ## adjust title to read d-aug-cc-pVQZ
    # color the bars based on molecules mol_system typeo
    g = sns.catplot(x='molecule', y='alphaE',
                    hue='mol_system',
                    col='polarization', col_order=['V', 'CV'],
                    data=a_outliers, dodge=False,
                    alpha=.9, palette='colorblind', fill=True, height=3, aspect=1.4, kind='bar'
                    , sharey=False,
                    sharex=False
                    )
    g.set_titles('d-aug-cc-p{col_name}QZ')
    g.set_xlabels('')
    g.set_ylabels(r'$\alpha$ Error (%)')
    # rotate the xticks
    for ax in g.axes.flat:
        for label in ax.get_xticklabels():
            label.set_rotation(90)
            label.set_horizontalalignment('center')
        # add a horizontal line at 0.02 and -0.02
        ax.axhline(y=.02, linestyle='--', color='orange')
        ax.axhline(y=-.02, linestyle='--', color='orange')
        # symlog scale
    # remove legend title
    # create a new legend in 3 column format outside the plot
    # using only a single legend only using the second axis
    g.fig.savefig(paper_path.joinpath('alpha_error_outliers.png'), dpi=600, bbox_inches='tight')

# %%
basis_data
data = pd.DataFrame()
# for each frequency
for omega in basis_data.omega.unique():
    # filter data for frequency
    omega_data = basis_data.query('omega==@omega')
    # create the column for eE by first setting index to basis and molecule
    omega_data = omega_data.set_index(['basis', 'molecule'])
    # create a column of MRA energy data for each molecule omega pair
    omega_data['eE'] = basis_e_data.set_index(['basis', 'molecule'])['energyE']
    # reset index
    omega_data = omega_data.reset_index()
    # concat to full data
    data = pd.concat([data, omega_data])

bdata = data.copy()

# %%
data.query('molecule=="Ne"')
# Out:
#               basis molecule  omega     alpha         gamma  alphaMRA  \
# 800     aug-cc-pVDZ       Ne      0  1.831917  1.037834e-10  2.376665
# 801     aug-cc-pVTZ       Ne      0  2.193942  9.475649e-09  2.376665
# 802     aug-cc-pVQZ       Ne      0  2.328988  4.053901e-10  2.376665
# 803     aug-cc-pV5Z       Ne      0  2.363141  4.392022e-11  2.376665
# 804    aug-cc-pCVDZ       Ne      0  1.833719  1.107388e-08  2.376665
# ..              ...      ...    ...       ...           ...       ...
# 811  d-aug-cc-pCVDZ       Ne      8  2.695708  0.000000e+00  2.736448
# 812  d-aug-cc-pCVTZ       Ne      8  2.732382  1.389046e-08  2.736448
# 813  d-aug-cc-pCVQZ       Ne      8  2.738320  6.157720e-09  2.736448
# 814     aug-cc-pV6Z       Ne      8  2.716927  1.296214e-09  2.736448
# 815   d-aug-cc-pV6Z       Ne      8  2.736237  5.361671e-09  2.736448
#
#         alphaE  gammaMRA      gammaE augmentation polarization mol_system  \
# 800 -22.920675  0.000012  -99.999110          aug            V  First-row
# 801  -7.688216  0.000012  -99.918734          aug            V  First-row
# 802  -2.006046  0.000012  -99.996523          aug            V  First-row
# 803  -0.569018  0.000012  -99.999623          aug            V  First-row
# 804 -22.844866  0.000012  -99.905027          aug           CV  First-row
# ..         ...       ...         ...          ...          ...        ...
# 811  -1.488779  0.000103 -100.000000        d-aug           CV  First-row
# 812  -0.148574  0.000103  -99.986543        d-aug           CV  First-row
# 813   0.068413  0.000103  -99.994034        d-aug           CV  First-row
# 814  -0.713364  0.000103  -99.998744          aug            V  First-row
# 815  -0.007703  0.000103  -99.994806        d-aug            V  First-row
#
#     valence            Type  absolute_alphaE        eE
# 800       D     aug-cc-pVnZ        22.920675  0.050745
# 801       T     aug-cc-pVnZ         7.688216  0.013822
# 802       Q     aug-cc-pVnZ         2.006046  0.003339
# 803       5     aug-cc-pVnZ         0.569018  0.000310
# 804       D    aug-cc-pCVnZ        22.844866  0.050651
# ..      ...             ...              ...       ...
# 811       D  d-aug-cc-pCVnZ         1.488779  0.050636
# 812       T  d-aug-cc-pCVnZ         0.148574  0.013691
# 813       Q  d-aug-cc-pCVnZ         0.068413  0.003231
# 814       6     aug-cc-pVnZ         0.713364  0.000033
# 815       6   d-aug-cc-pVnZ         0.007703  0.000032
#
# [144 rows x 16 columns]

# %%
basis_data
# Out:
#       molecule  omega          basis      alpha      gamma   alphaMRA  \
# 0        NH2Cl      0    aug-cc-pVDZ  24.800048  12.340561  25.978063
# 1        NH2Cl      1    aug-cc-pVDZ  24.814924  12.356587  25.994977
# 2        NH2Cl      2    aug-cc-pVDZ  24.859753  12.404995  26.045737
# 3        NH2Cl      3    aug-cc-pVDZ  24.935151  12.486799  26.131067
# 4        NH2Cl      4    aug-cc-pVDZ  25.042193  12.603777  26.252403
# ...        ...    ...            ...        ...        ...        ...
# 12811     HOOH      4  d-aug-cc-pV6Z  14.557781   9.197190  14.562407
# 12812     HOOH      5  d-aug-cc-pV6Z  14.637270   9.301981  14.642040
# 12813     HOOH      6  d-aug-cc-pV6Z  14.736426   9.433393  14.741137
# 12814     HOOH      7  d-aug-cc-pV6Z  14.856592   9.593652  14.861393
# 12815     HOOH      8  d-aug-cc-pV6Z  14.999500   9.785616  15.004430
#
#          alphaE   gammaMRA    gammaE augmentation polarization  mol_system  \
# 0     -4.534652  11.913106  3.588107          aug            V  Second-row
# 1     -4.539541  11.928273  3.590745          aug            V  Second-row
# 2     -4.553467  11.973083  3.607364          aug            V  Second-row
# 3     -4.576603  12.048642  3.636568          aug            V  Second-row
# 4     -4.609904  12.156879  3.676094          aug            V  Second-row
# ...         ...        ...       ...          ...          ...         ...
# 12811 -0.031763   9.209097 -0.129296        d-aug            V   First-row
# 12812 -0.032579   9.314205 -0.131249        d-aug            V   First-row
# 12813 -0.031954   9.445753 -0.130859        d-aug            V   First-row
# 12814 -0.032309   9.606048 -0.129052        d-aug            V   First-row
# 12815 -0.032859   9.798800 -0.134542        d-aug            V   First-row
#
#       valence           Type  absolute_alphaE
# 0           D    aug-cc-pVnZ         4.534652
# 1           D    aug-cc-pVnZ         4.539541
# 2           D    aug-cc-pVnZ         4.553467
# 3           D    aug-cc-pVnZ         4.576603
# 4           D    aug-cc-pVnZ         4.609904
# ...       ...            ...              ...
# 12811       6  d-aug-cc-pVnZ         0.031763
# 12812       6  d-aug-cc-pVnZ         0.032579
# 12813       6  d-aug-cc-pVnZ         0.031954
# 12814       6  d-aug-cc-pVnZ         0.032309
# 12815       6  d-aug-cc-pVnZ         0.032859
#
# [12816 rows x 15 columns]

# %%
# for each basis set get the alphaE statistics and place them in a dataframe

iso_stats = pd.DataFrame()
for basis in basis_data.basis.unique():
    # filter data for basis
    subset = basis_data.query('basis==@basis & omega==0')
    # remove nan values row
    # get the mean and std of alphaE
    d = subset.describe()['alphaE']
    d.name = basis
    # concat to the full dataframe
    iso_stats = pd.concat([iso_stats, d], axis=1)
iso_stats = iso_stats.T

# %%
# write a function which does the above for a given omega and alphaE or gammaE
def basis_stats(iso_type, omega):
    iso_stats = pd.DataFrame()
    for basis in basis_data.basis.unique():
        # filter data for basis
        subset = basis_data.query('basis==@basis & omega==@omega')
        # remove nan values row
        if iso_type == 'gammaE':
            # drop any values with gammaE.abs() < 1e-3
            subset = subset.query('gamma.abs()>1e-3')
        # concat to the full dataframe
        # get the mean and std of alphaE
        d = subset.describe()[iso_type]
        d.name = basis
        iso_stats = pd.concat([iso_stats, d], axis=1)
    iso_stats = iso_stats.T
    # remove the 6Z basis set
    iso_stats = iso_stats.drop('aug-cc-pV6Z', axis=0)
    iso_stats = iso_stats.drop('d-aug-cc-pV6Z', axis=0)
    return iso_stats


# write a function which does the above for a given omega and alphaE or gammaE
def basis_e_stats():
    iso_stats = pd.DataFrame()
    for basis in basis_e_data.basis.unique():
        # filter data for basis
        subset = basis_e_data.query('basis==@basis')
        # remove nan values row
        # get the mean and std of alphaE
        d = subset.describe()['energyE']
        d.name = basis
        # concat to the full dataframe
        iso_stats = pd.concat([iso_stats, d], axis=1)
    iso_stats = iso_stats.T
    # remove the 6Z basis set
    iso_stats = iso_stats.drop('aug-cc-pV6Z', axis=0)
    iso_stats = iso_stats.drop('d-aug-cc-pV6Z', axis=0)
    return iso_stats


def get_iso_mols(iso_type, omega):
    iso_stats = pd.DataFrame()
    for basis in basis_data.basis.unique():
        # filter data for basis
        subset = basis_data.query('basis==@basis & omega==@omega')
        # remove nan values row
        if iso_type == 'gammaE':
            # drop any values with gammaE.abs() < 1e-3
            subset = subset.query('gamma.abs()>1e-3')
        # concat to the full dataframe
        mols = pd.Series(subset.dropna().molecule.unique())
        mols.name = basis
        iso_stats = pd.concat([iso_stats, mols], axis=1)
    iso_stats = iso_stats.T
    # remove the 6Z basis set
    iso_stats = iso_stats.drop('aug-cc-pV6Z', axis=0)
    iso_stats = iso_stats.drop('d-aug-cc-pV6Z', axis=0)
    return iso_stats.T

# %%
# Get the basis set statistics 
e_stats = basis_e_stats()
iso_0 = basis_stats('alphaE', 0)
gamma_0 = basis_stats('gammaE', 0)

gamma_mols = get_iso_mols('gammaE', 0)
alpha_mols = get_iso_mols('alphaE', 0)

# %%
iso_0
# new order of rows
DZ = ['aug-cc-pVDZ', 'aug-cc-pCVDZ', 'd-aug-cc-pVDZ', 'd-aug-cc-pCVDZ']
TZ = ['aug-cc-pVTZ', 'aug-cc-pCVTZ', 'd-aug-cc-pVTZ', 'd-aug-cc-pCVTZ']
QZ = ['aug-cc-pVQZ', 'aug-cc-pCVQZ', 'd-aug-cc-pVQZ', 'd-aug-cc-pCVQZ']
fiveZ = ['aug-cc-pV5Z', 'd-aug-cc-pV5Z']
new_order = DZ + TZ + QZ + fiveZ
iso_0 = iso_0.reindex(new_order)
gamma_0 = gamma_0.reindex(new_order)
e_stats = e_stats.reindex(new_order)
iso_0
# Out:
#                 count      mean       std        min       25%       50%  \
# aug-cc-pVDZ      89.0 -2.893764  3.160194 -22.920675 -3.799930 -2.294844
# aug-cc-pCVDZ     89.0 -2.873301  3.107162 -22.844866 -3.750305 -2.268691
# d-aug-cc-pVDZ    89.0 -0.244912  0.665161  -2.495443 -0.628313 -0.186275
# d-aug-cc-pCVDZ   89.0 -0.252221  0.562127  -1.853298 -0.574826 -0.232299
# aug-cc-pVTZ      89.0 -0.684110  1.029067  -7.688216 -0.942641 -0.434133
# aug-cc-pCVTZ     89.0 -0.623961  0.953695  -7.589612 -0.827255 -0.380718
# d-aug-cc-pVTZ    89.0 -0.034592  0.318195  -1.385189 -0.169265  0.037742
# d-aug-cc-pCVTZ   89.0  0.024795  0.101463  -0.407200 -0.018231  0.034535
# aug-cc-pVQZ      89.0 -0.158394  0.335921  -2.006046 -0.224229 -0.109483
# aug-cc-pCVQZ     89.0 -0.114159  0.241798  -1.989510 -0.124863 -0.052325
# d-aug-cc-pVQZ    89.0 -0.032517  0.227372  -1.067660 -0.093388  0.009753
# d-aug-cc-pCVQZ   89.0  0.008901  0.030112  -0.110681 -0.001151  0.011329
# aug-cc-pV5Z      74.0 -0.092662  0.106169  -0.569018 -0.124766 -0.061678
# d-aug-cc-pV5Z    72.0 -0.011049  0.027493  -0.106640 -0.025416 -0.005867
#
#                      75%       max
# aug-cc-pVDZ    -1.108672  0.980188
# aug-cc-pCVDZ   -1.251247  1.002283
# d-aug-cc-pVDZ   0.063976  1.826203
# d-aug-cc-pCVDZ -0.006803  1.535388
# aug-cc-pVTZ    -0.196709  1.137163
# aug-cc-pCVTZ   -0.162146  0.225359
# d-aug-cc-pVTZ   0.072651  1.451943
# d-aug-cc-pCVTZ  0.064156  0.402988
# aug-cc-pVQZ    -0.025541  1.102012
# aug-cc-pCVQZ   -0.017913  0.042646
# d-aug-cc-pVQZ   0.021807  1.114202
# d-aug-cc-pCVQZ  0.020344  0.128900
# aug-cc-pV5Z    -0.021635  0.029991
# d-aug-cc-pV5Z   0.004520  0.074545

# %%
basis_data.query("molecule=='Ne'")
# Out:
#      molecule  omega          basis     alpha         gamma  alphaMRA  \
# 7200       Ne      0    aug-cc-pVDZ  1.831917  1.037834e-10  2.376665
# 7201       Ne      1    aug-cc-pVDZ  1.834578  1.093023e-10  2.381148
# 7202       Ne      2    aug-cc-pVDZ  1.842658  1.275773e-10  2.394759
# 7203       Ne      3    aug-cc-pVDZ  1.856461  1.636978e-10  2.418011
# 7204       Ne      4    aug-cc-pVDZ  1.876532  2.193649e-10  2.451841
# ...       ...    ...            ...       ...           ...       ...
# 7339       Ne      4  d-aug-cc-pV6Z  2.451615  4.252714e-09  2.451841
# 7340       Ne      5  d-aug-cc-pV6Z  2.497502  4.470842e-09  2.497724
# 7341       Ne      6  d-aug-cc-pV6Z  2.557664  4.737046e-09  2.557867
# 7342       Ne      7  d-aug-cc-pV6Z  2.635486  5.041498e-09  2.635669
# 7343       Ne      8  d-aug-cc-pV6Z  2.736237  5.361671e-09  2.736448
#
#          alphaE  gammaMRA     gammaE augmentation polarization mol_system  \
# 7200 -22.920675  0.000012 -99.999110          aug            V  First-row
# 7201 -22.954073  0.000019 -99.999410          aug            V  First-row
# 7202 -23.054565  0.000013 -99.999009          aug            V  First-row
# 7203 -23.223653  0.000013 -99.998780          aug            V  First-row
# 7204 -23.464373  0.000011 -99.998021          aug            V  First-row
# ...         ...       ...        ...          ...          ...        ...
# 7339  -0.009211  0.000011 -99.961629        d-aug            V  First-row
# 7340  -0.008892  0.000033 -99.986430        d-aug            V  First-row
# 7341  -0.007930  0.000006 -99.916497        d-aug            V  First-row
# 7342  -0.006952  0.000009 -99.942500        d-aug            V  First-row
# 7343  -0.007703  0.000103 -99.994806        d-aug            V  First-row
#
#      valence           Type  absolute_alphaE
# 7200       D    aug-cc-pVnZ        22.920675
# 7201       D    aug-cc-pVnZ        22.954073
# 7202       D    aug-cc-pVnZ        23.054565
# 7203       D    aug-cc-pVnZ        23.223653
# 7204       D    aug-cc-pVnZ        23.464373
# ...      ...            ...              ...
# 7339       6  d-aug-cc-pVnZ         0.009211
# 7340       6  d-aug-cc-pVnZ         0.008892
# 7341       6  d-aug-cc-pVnZ         0.007930
# 7342       6  d-aug-cc-pVnZ         0.006952
# 7343       6  d-aug-cc-pVnZ         0.007703
#
# [144 rows x 15 columns]

# %%
def diff_mol_subset(df):
    # get the molecules in the dataframe
    mols = basis_data.molecule.unique()
    full_set = set(mols)
    # get the difference between the full set and the subset
    diff = full_set.difference(mols)
    diff_mols = pd.DataFrame()
    for basis in df.columns:
        basis_mols = set(df[basis])
        # compute the difference between the full set and the basis set
        basis_difference = full_set.difference(basis_mols)
        basis_difference = list(basis_difference)

        # if basis difference is not empty then add it to the dataframe
        if len(basis_difference) > 0:
            d = pd.Series(basis_difference, name=basis).T

            diff_mols = pd.concat([diff_mols, d], axis=1)
            # return the difference
    not_available = diff_mols.T.drop_duplicates().T
    not_available = not_available.applymap(lambda x: '\\ce{' + str(x) + '}', na_action='ignore')
    # sort the values of each column alphabetically
    not_available = not_available.apply(lambda x: x.sort_values().values)
    # sort the columns by value
    # sort the columns by the values in the first row
    return not_available


polar_na = diff_mol_subset(alpha_mols)

# concat to the full dataframe
# Out:
# /tmp/ipykernel_61682/4153832959.py:21: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   not_available = not_available.applymap(lambda x: '\\ce{' + str(x) + '}', na_action='ignore')

# %%
gamma_na = diff_mol_subset(gamma_mols)
# Out:
# /tmp/ipykernel_61682/4153832959.py:21: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   not_available = not_available.applymap(lambda x: '\\ce{' + str(x) + '}', na_action='ignore')

# %%
# make a latex table not_available
polar_na.to_latex(paper_path.joinpath('not_available.tex'), na_rep='-'
                  )

# %%
polar_na
# Out:
#    aug-cc-pV5Z d-aug-cc-pV5Z
# 0    \ce{BeH2}     \ce{BeH2}
# 1      \ce{Be}       \ce{Be}
# 2    \ce{C6H6}     \ce{C6H6}
# 3     \ce{Li2}   \ce{CH3BH2}
# 4   \ce{LiBH4}    \ce{CH3SH}
# 5    \ce{LiCN}      \ce{Li2}
# 6    \ce{LiCl}    \ce{LiBH4}
# 7     \ce{LiH}     \ce{LiCN}
# 8     \ce{Mg2}     \ce{LiCl}
# 9      \ce{Mg}      \ce{LiH}
# 10    \ce{Na2}      \ce{Mg2}
# 11   \ce{NaCN}       \ce{Mg}
# 12   \ce{NaCl}      \ce{Na2}
# 13    \ce{NaH}     \ce{NaCN}
# 14   \ce{NaLi}     \ce{NaCl}
# 15         NaN      \ce{NaH}
# 16         NaN     \ce{NaLi}

# %%
# apply a symlog color map to the all columns except count
import matplotlib.cm as cm
import matplotlib.colors as mcolors


def background_with_norm(s, vmax=1e-1):
    linthresh = 2e-3
    linscale = .10
    cmap = cm.bwr
    norm = mcolors.SymLogNorm(linthresh=linthresh, linscale=linscale, base=10, vmin=-vmax,
                              vmax=vmax)
    return ['background-color: {:s}'.format(mcolors.to_hex(c.flatten())) for c in
            cmap(norm(s.values))]


def __style_summary(df, fmt="{:.2e}", vmax=20):
    # only vmax on everything but first column

    vmax = df.iloc[:, 1:].abs().max().max()
    print(vmax)
    bnorm = lambda x: background_with_norm(x, vmax)
    df = df.T

    new_idx = {}
    for i in df.index:
        if i[-1] == '%':
            new_idx[i] = i[:-1] + '\\' + i[-1]
        else:
            new_idx[i] = i
    df.rename(index=new_idx, inplace=True)
    df = df.T

    # Define the maximum data value (in absolute terms) for normalization
    #styled_df = df.style.apply(bnorm, subset=df.columns[1:])
    # Apply the formatting to every column except first one
    styled_df = df.style.format(fmt, subset=df.columns[1:])
    # for the first column (count) use integer formatting
    # set the data type to int first
    styled_df = styled_df.format("{:.0f}", subset=df.columns[0])
    #make the background the first column to be white

    #styled_df = styled_df.format(fmt)
    return styled_df

# make a latex table of the statistics

# %%
style_iso = __style_summary(iso_0, fmt="{:.2e}", vmax=20)
# format the count column to be an integer
style_iso.to_latex(paper_path.joinpath('alphaE_stats.tex'),
                   hrules=True,
                   convert_css=True,
                   multicol_align='|c|',
                   siunitx=True,
                   )
# Out:
# 22.920675321283575

# %%
gamma_0 = basis_stats('gammaE', 0)

style_gamma = __style_summary(gamma_0, fmt="{:.2e}", vmax=20)
# format the count column to be an integer
style_gamma.to_latex(paper_path.joinpath('gammaE_stats.tex'),
                     hrules=True,
                     convert_css=True,
                     multicol_align='|c|',
                     siunitx=True,
                     )
# Out:
# 75.45567956559864

# %%
style_iso = __style_summary(e_stats, fmt="{:.2e}", vmax=.05)
# format the count column to be an integer
style_iso.to_latex(paper_path.joinpath('energy_stats.tex'),
                   hrules=True,
                   convert_css=True,
                   multicol_align='|c|',
                   siunitx=True,
                   )
# Out:
# 0.12118313413088799

# %%
mra_data = august_database.iso_data.query('basis=="MRA"').copy()

# %%
molecule_subset = basis_data.query('basis=="aug-cc-pVDZ" & omega==0')[
    ['molecule', 'mol_system']].drop_duplicates()

# %%
molecule_subset
# Out:
#       molecule  mol_system
# 0        NH2Cl  Second-row
# 144       NaLi  Second-row
# 288         F2    Fluorine
# 432        HNS  Second-row
# 576         N2   First-row
# ...        ...         ...
# 12096      H2O   First-row
# 12240    HCOOH   First-row
# 12384      HOF    Fluorine
# 12528      HBO   First-row
# 12672     HOOH   First-row
#
# [89 rows x 2 columns]

# %%
molecule_subset.sort_values('mol_system', inplace=True)
# get the first three colors of the colorblind palette
pal = sns.color_palette('colorblind', n_colors=3)
# make a barplot of the number of molecules in each system
mol_only = molecule_subset['molecule']
# make a table of the number of molecules in each system columns
# being first row, fluorine, and second row
mol_table = pd.DataFrame()

first_row = molecule_subset[molecule_subset['mol_system'] == 'First-row']['molecule'].unique()
fluorine = molecule_subset[molecule_subset['mol_system'] == 'Fluorine']['molecule'].unique()
second_row = molecule_subset[molecule_subset['mol_system'] == 'Second-row']['molecule'].unique()
first_row = pd.Series(first_row, name='First-row')
fluorine = pd.Series(fluorine, name='Fluorine')
second_row = pd.Series(second_row, name='Second-row')
mol_table = pd.concat([first_row, fluorine, second_row], axis=1)
# sort the values of each column alphabetically

# replace nan values with -
mol_table = mol_table.fillna('-')
mol_table = mol_table.applymap(lambda x: '\\ce{' + str(x) + '}', na_action='ignore')
print(mol_table)
# color the columns with the colorblind palette 
# map the colors to the columns just based on the index
# make pal lighter by 50%
pal = sns.color_palette('muted', n_colors=3)
# blend the colors with white


# make a dictionary of the colors
colormap = dict(zip(mol_table.columns, pal.as_hex()))
# map colorblind colormap to the columns
mol_only = molecule_subset['molecule']
# make mol only into a table 9 x 10 
mol_only_numpy=mol_only.to_numpy()
mol_only_numpy=np.append(mol_only_numpy,'-')
mol_df = pd.DataFrame(mol_only_numpy.reshape((10, 9)))
# add one to each index and column to make the numbers run from 1 to 9
mol_df.index += 1
mol_df.columns += 1

ms = molecule_subset.molecule
# surround the values with \ce{} to make them chemical formulas
ms = ms.apply(lambda x: '\\ce{' + str(x) + '}')
# make a dictionary of the colors
mol_dict = dict(zip(ms, molecule_subset.mol_system))

mol_color = {mol: colormap[mol_dict[mol]] for mol in ms}
mol_color['\\ce{-}']= 'FFFFFF'
# apply the colors to the dataframe based on mol_color dictionary

mol_df = mol_df.applymap(lambda x: '\\ce{' + str(x) + '}')
mol_df = mol_df.style.apply(lambda x: [f'background-color: {mol_color[v]}' for v in x],
                            axis=1)
# before printing surround the values with \ce{} to make them chemical formulas
# write the dataframe to a latex table
mol_df.to_latex(paper_path.joinpath('molecule_table.tex'),
                multicol_align='|c|',
                hrules=True,
                convert_css=True,
                )
# Out:
#       First-row   Fluorine   Second-row
# 0     \ce{HOOH}    \ce{F2}     \ce{ClF}
# 1     \ce{C6H6}   \ce{HOF}    \ce{NOCl}
# 2    \ce{CH3OH}  \ce{BH2F}    \ce{SiH4}
# 3     \ce{NH3O}  \ce{HCCF}     \ce{HCP}
# 4       \ce{O3}   \ce{FCN}  \ce{SiH3Cl}
# 5     \ce{C2H2}    \ce{HF}      \ce{CS}
# 6       \ce{CO}  \ce{BHF2}    \ce{NaCN}
# 7       \ce{He}    \ce{BF}   \ce{NH2Cl}
# 8      \ce{NH3}  \ce{NH2F}     \ce{NaH}
# 9    \ce{CH2BH}   \ce{OF2}    \ce{NaLi}
# 10   \ce{CH2NH}   \ce{FNO}     \ce{HNS}
# 11     \ce{HBO}  \ce{CH3F}     \ce{SF2}
# 12  \ce{CH3BH2}     \ce{-}     \ce{Na2}
# 13    \ce{BeH2}     \ce{-}     \ce{SiO}
# 14      \ce{Be}     \ce{-}      \ce{Mg}
# 15    \ce{LiCN}     \ce{-}   \ce{BH2Cl}
# 16  \ce{HCONH2}     \ce{-}     \ce{SH2}
# 17      \ce{Ne}     \ce{-}      \ce{P2}
# 18     \ce{BH3}     \ce{-}    \ce{HOCl}
# 19    \ce{C2H4}     \ce{-}    \ce{NaCl}
# 20     \ce{Li2}     \ce{-}   \ce{HCCCl}
# 21      \ce{H2}     \ce{-}   \ce{SiH3F}
# 22     \ce{CH4}     \ce{-}     \ce{HCl}
# 23    \ce{N2H2}     \ce{-}    \ce{P2H4}
# 24   \ce{NH2OH}     \ce{-}     \ce{Mg2}
# 25   \ce{LiBH4}     \ce{-}     \ce{CSO}
# 26     \ce{HNC}     \ce{-}    \ce{PH3O}
# 27     \ce{LiH}     \ce{-}    \ce{S2H2}
# 28    \ce{N2H4}     \ce{-}    \ce{OCl2}
# 29     \ce{CO2}     \ce{-}     \ce{HBS}
# 30     \ce{HCN}     \ce{-}     \ce{SO2}
# 31     \ce{H2O}     \ce{-}     \ce{Cl2}
# 32      \ce{N2}     \ce{-}      \ce{Ar}
# 33   \ce{HCOOH}     \ce{-}     \ce{PH3}
# 34  \ce{CH3NH2}     \ce{-}    \ce{SCl2}
# 35    \ce{HCHO}     \ce{-}   \ce{CH3Cl}
# 36     \ce{HNO}     \ce{-}    \ce{LiCl}
# 37       \ce{-}     \ce{-}    \ce{HCHS}
# 38       \ce{-}     \ce{-}    \ce{ClCN}
# 39       \ce{-}     \ce{-}   \ce{CH3SH}
# /tmp/ipykernel_61682/2686291146.py:21: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   mol_table = mol_table.applymap(lambda x: '\\ce{' + str(x) + '}', na_action='ignore')
# /tmp/ipykernel_61682/2686291146.py:52: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   mol_df = mol_df.applymap(lambda x: '\\ce{' + str(x) + '}')

# %%
molecule_subset.sort_values('mol_system')
# Out:
#       molecule  mol_system
# 12672     HOOH   First-row
# 7920       CH4   First-row
# 11376     N2H2   First-row
# 11232    NH2OH   First-row
# 11808    LiBH4   First-row
# ...        ...         ...
# 1296       SiO  Second-row
# 1440        Mg  Second-row
# 1584     BH2Cl  Second-row
# 2016      HOCl  Second-row
# 6336     CH3SH  Second-row
#
# [89 rows x 2 columns]
