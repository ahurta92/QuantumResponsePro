# %%
from ConvergenceAnalysis import *

# %%
fd_data
# Out:
#   Molecule         FD
# 0       He   1.322234
# 1       Be  45.616381
# 2       Ne   2.376747
# 3       Mg  81.593730
# 4       Ar  10.758002
# 5       N2  15.030438
# 6       F2  14.642223
# 7     NaCl  28.700184
# 8     LiCl  24.532474
# 9       CO  14.466840

# %%
def process_data(base_path):
    base_high = base_path.joinpath('high-high')
    base_low = base_path.joinpath('low-low')

    mols = fd_data['Molecule'].to_list()
    low_data = get_database_residuals_z(mols, base_low)
    high_data = get_database_residuals_z(mols, base_high)
    # add column to low_data and high_data indicating low or high called ground state
    low_data['Ground Protocol'] = 'Low'
    high_data['Ground Protocol'] = 'High'
    # combine dataframe
    data = pd.concat([low_data, high_data])

    # concatenate the protocol and ground state columns to make a new column
    data['Response Protocol'] = data['Protocol'].astype(str)
    # if protocol is 'High' or 'Low' then set it to 'H' or 'L' 
    data.loc[data['Response Protocol'] == 'High', 'Protocol'] = 'High'
    data.loc[data['Response Protocol'] == 'Medium', 'Protocol'] = 'Low'
    data.loc[data['Response Protocol'] == 'Guess', 'Protocol'] = 'Guess'
    return data

# %%
data_path=Path('/home/ahurta92/data')
#november_absolute_path = Path('/home/ahurta92/data/november_absolute_kain/')

fd_compare2 = data_path/ Path('fd_compare2')
fd_compare_data = process_data(fd_compare2)
#november_absolute_data = process_data(november_absolute_path)

paper_path = Path('response_paper_figures')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 data_path=Path('/home/ahurta92/data')
#       2 #november_absolute_path = Path('/home/ahurta92/data/november_absolute_kain/')
# ----> 4 fd_compare2 = data_path/fd_compare2
#       5 fd_compare_data = process_data(fd_compare2)
#       6 #november_absolute_data = process_data(november_absolute_path)
#
# NameError: name 'fd_compare2' is not defined

# %%
november_absolute_data
# Out:
#    Protocol        rz            dz     znorm        MRA         FD
# 0     Guess  0.002094  1.733394e-03  0.747547   1.322123   1.322234  \
# 1       Low  0.000022  1.634942e-05  0.747965   1.322250   1.322234
# 2     Guess  0.001980  2.060990e-03  2.637628  45.621170  45.616381
# 3       Low  0.000296  7.492834e-06  2.637670  45.618338  45.616381
# 4     Guess  0.001400  2.517452e-03  0.833928   2.377173   2.376747
# 5       Low  0.000029  2.681973e-05  0.834044   2.376704   2.376747
# 6     Guess  0.005232  1.945567e-03  3.210430  81.599050  81.593730
# 7       Low  0.000307  3.707267e-05  3.210405  81.592883  81.593730
# 8     Guess  0.002450  3.641096e-03  1.357665  10.758028  10.758002
# 9       Low  0.000110  3.625734e-05  1.357710  10.758217  10.758002
# 10    Guess  0.005755  1.404499e-03  1.486974  15.030872  15.030438
# 11      Low  0.000097  1.744576e-05  1.487291  15.030311  15.030438
# 12    Guess  0.007848  2.446823e-03  1.557715  14.652568  14.642223
# 13      Low  0.000033  2.344514e-05  1.556277  14.642158  14.642223
# 14    Guess  0.006361  4.506709e-03  2.021109  28.683426  28.700184
# 15      Low  0.000246  3.003014e-05  2.021737  28.688582  28.700184
# 16    Guess  0.003991  2.937311e-03  1.875622  24.533153  24.532474
# 17      Low  0.000210  3.692571e-05  1.875485  24.534452  24.532474
# 18    Guess  0.005029  4.532660e-03  1.495874  14.468058  14.466840
# 19      Low  0.000328  1.905609e-05  1.496479  14.467105  14.466840
# 0     Guess  0.002095  1.732760e-03  0.747541   1.322094   1.322234
# 1       Low  0.000022  1.641076e-05  0.747959   1.322221   1.322234
# 2      High  0.000002  2.209361e-07  0.747969   1.322235   1.322234
# 3     Guess  0.001246  2.191168e-03  0.833944   2.376968   2.376747
# 4       Low  0.000036  3.115714e-05  0.834059   2.376754   2.376747
# 5      High  0.000003  4.632557e-07  0.834047   2.376746   2.376747
# 6     Guess  0.005248  1.933465e-03  3.210426  81.599169  81.593730
# 7       Low  0.000307  3.915862e-05  3.210429  81.592962  81.593730
# 8      High  0.000012  1.055243e-07  3.210433  81.593199  81.593730
# 9     Guess  0.002397  3.159356e-03  1.357668  10.758155  10.758002
# 10      Low  0.000127  4.933645e-05  1.357700  10.757983  10.758002
# 11     High  0.000005  4.313908e-07  1.357698  10.757994  10.758002
# 12    Guess  0.004148  4.843529e-03  1.487531  15.026879  15.030438
# 13      Low  0.000173  3.114087e-05  1.487284  15.029903  15.030438
# 14     High  0.000006  3.686640e-07  1.487315  15.030294  15.030438
# 15    Guess  0.007850  2.459047e-03  1.557726  14.652746  14.642223
# 16      Low  0.000033  4.296877e-05  1.556286  14.642359  14.642223
# 17     High  0.000005  2.945258e-07  1.556312  14.642715  14.642223
# 18    Guess  0.002863  2.816991e-03  2.021656  28.696372  28.700184
# 19      Low  0.000285  2.461649e-05  2.022149  28.700564  28.700184
# 20     High  0.000012  2.061663e-07  2.022139  28.700400  28.700184
# 21    Guess  0.004021  2.975561e-03  1.875596  24.531284  24.532474
# 22      Low  0.000188  3.881086e-05  1.875461  24.532618  24.532474
# 23     High  0.000012  2.688214e-07  1.875451  24.532460  24.532474
# 24    Guess  0.005036  4.552811e-03  1.495913  14.468055  14.466840
# 25      Low  0.000306  1.440484e-05  1.496491  14.466618  14.466840
# 26     High  0.000008  4.307446e-07  1.496510  14.466762  14.466840
#
#     Percent Error  Absolute Percent Error  Absolute Residual Z Molecule
# 0       -0.008358                0.008358             0.001565       He  \
# 1        0.001212                0.001212             0.000016       He
# 2        0.010498                0.010498             0.005222       Be
# 3        0.004289                0.004289             0.000781       Be
# 4        0.017922                0.017922             0.001168       Ne
# 5       -0.001791                0.001791             0.000024       Ne
# 6        0.006520                0.006520             0.016797       Mg
# 7       -0.001038                0.001038             0.000985       Mg
# 8        0.000248                0.000248             0.003326       Ar
# 9        0.002003                0.002003             0.000149       Ar
# 10       0.002886                0.002886             0.008558       N2
# 11      -0.000844                0.000844             0.000144       N2
# 12       0.070652                0.070652             0.012225       F2
# 13      -0.000447                0.000447             0.000052       F2
# 14      -0.058388                0.058388             0.012856     NaCl
# 15      -0.040424                0.040424             0.000497     NaCl
# 16       0.002767                0.002767             0.007486     LiCl
# 17       0.008065                0.008065             0.000394     LiCl
# 18       0.008416                0.008416             0.007523       CO
# 19       0.001832                0.001832             0.000490       CO
# 0       -0.010567                0.010567             0.001566       He
# 1       -0.000996                0.000996             0.000016       He
# 2        0.000101                0.000101             0.000001       He
# 3        0.009316                0.009316             0.001039       Ne
# 4        0.000308                0.000308             0.000030       Ne
# 5       -0.000027                0.000027             0.000003       Ne
# 6        0.006665                0.006665             0.016848       Mg
# 7       -0.000941                0.000941             0.000986       Mg
# 8       -0.000651                0.000651             0.000038       Mg
# 9        0.001422                0.001422             0.003255       Ar
# 10      -0.000171                0.000171             0.000173       Ar
# 11      -0.000073                0.000073             0.000007       Ar
# 12      -0.023681                0.023681             0.006170       N2
# 13      -0.003560                0.003560             0.000257       N2
# 14      -0.000958                0.000958             0.000009       N2
# 15       0.071861                0.071861             0.012228       F2
# 16       0.000926                0.000926             0.000052       F2
# 17       0.003356                0.003356             0.000007       F2
# 18      -0.013282                0.013282             0.005788     NaCl
# 19       0.001325                0.001325             0.000576     NaCl
# 20       0.000754                0.000754             0.000024     NaCl
# 21      -0.004849                0.004849             0.007541     LiCl
# 22       0.000589                0.000589             0.000353     LiCl
# 23      -0.000057                0.000057             0.000023     LiCl
# 24       0.008399                0.008399             0.007533       CO
# 25      -0.001533                0.001533             0.000459       CO
# 26      -0.000540                0.000540             0.000012       CO
#
#    Ground Protocol Response Protocol
# 0              Low             Guess
# 1              Low               Low
# 2              Low             Guess
# 3              Low               Low
# 4              Low             Guess
# 5              Low               Low
# 6              Low             Guess
# 7              Low               Low
# 8              Low             Guess
# 9              Low               Low
# 10             Low             Guess
# 11             Low               Low
# 12             Low             Guess
# 13             Low               Low
# 14             Low             Guess
# 15             Low               Low
# 16             Low             Guess
# 17             Low               Low
# 18             Low             Guess
# 19             Low               Low
# 0             High             Guess
# 1             High               Low
# 2             High              High
# 3             High             Guess
# 4             High               Low
# 5             High              High
# 6             High             Guess
# 7             High               Low
# 8             High              High
# 9             High             Guess
# 10            High               Low
# 11            High              High
# 12            High             Guess
# 13            High               Low
# 14            High              High
# 15            High             Guess
# 16            High               Low
# 17            High              High
# 18            High             Guess
# 19            High               Low
# 20            High              High
# 21            High             Guess
# 22            High               Low
# 23            High              High
# 24            High             Guess
# 25            High               Low
# 26            High              High

# %%
data = fd_compare_data
data = november_absolute_data

sns.set_context("paper", font_scale=1.50)
sns.set_style("darkgrid")
sns.set_palette("colorblind")
style = 'Molecule'
hue = 'Response Protocol'
hue_order = ['Low', 'High']
data= data.query('Protocol.isin(@hue_order)')
# colormap is colorblind staring with index 1
colors = sns.color_palette("colorblind", 3)
# grab second and third colors in list
colors = [colors[1], colors[2]]
# create palette from colors
palette = sns.color_palette(colors)
s = 200
x = 'dz'
x = 'Absolute Residual Z'
g = sns.relplot(x=x, y='Absolute Percent Error', data=data, style=style, hue=hue, s=s,hue_order=hue_order,
                col='Ground Protocol',palette=colors )
# set the subplot titles to Ground Protocol = H or M
g.set_titles(col_template="Ground Protocol : {col_name}")
# increase the font of the legend

for ax in g.axes.flat:
    #ax.plot([1e-6,1e-2],[1e-6,1e-2], ls='--', color='black')
    ax.set_xscale('log')
    ax.set_yscale('log')
    # write an annotation indicating the green line is .005
    # only on first left plot
    if ax == g.axes.flat[0]:
        ax.axhline(.02, ls='--', color='orange')
        ax.annotate('0.02%', xy=(1e-4, .02), xytext=(1e-4, .022))
    else:
        ax.axhline(5e-3, ls='--', color='green')
        ax.annotate('0.005%', xy=(1e-4, .005), xytext=(1e-4, .006))
        
# Draw a y=x line on each plot
for ax in g.axes.flat:
    if x=='dz':
        ax.set_xlabel(r'$\Delta \rho_{z}(x)$')
    else:
        ax.set_xlabel('||f(x)-x||')
    # y label is percent error of static polarizability
    ax.set_title('{}'.format(ax.get_title()))

g.fig.gca().invert_xaxis()
# Change the marker size in the legend to be larger and more legible
for lh in g.legend.legend_handles: 
    lh._sizes = [100]
# save a high res version
#g.savefig(paper_path.joinpath('mra_convergence.png'),dpi=600)

# %%
data=november_absolute_data
# first rename Ground Protocol  and Response Protocol to GP and RP
data.rename(columns={'Ground Protocol':'GP','Response Protocol':'RP'},inplace=True)

low_data=data.query('GP=="Low"').query('RP=="Low"')
high_data=data.query('GP=="High"').query('RP=="High"')


data=pd.concat([low_data,high_data])
data
# Out:
#    Protocol        rz            dz     znorm        MRA         FD
# 1       Low  0.000022  1.634942e-05  0.747965   1.322250   1.322234  \
# 3       Low  0.000296  7.492834e-06  2.637670  45.618338  45.616381
# 5       Low  0.000029  2.681973e-05  0.834044   2.376704   2.376747
# 7       Low  0.000307  3.707267e-05  3.210405  81.592883  81.593730
# 9       Low  0.000110  3.625734e-05  1.357710  10.758217  10.758002
# 11      Low  0.000097  1.744576e-05  1.487291  15.030311  15.030438
# 13      Low  0.000033  2.344514e-05  1.556277  14.642158  14.642223
# 15      Low  0.000246  3.003014e-05  2.021737  28.688582  28.700184
# 17      Low  0.000210  3.692571e-05  1.875485  24.534452  24.532474
# 19      Low  0.000328  1.905609e-05  1.496479  14.467105  14.466840
# 2      High  0.000002  2.209361e-07  0.747969   1.322235   1.322234
# 5      High  0.000003  4.632557e-07  0.834047   2.376746   2.376747
# 8      High  0.000012  1.055243e-07  3.210433  81.593199  81.593730
# 11     High  0.000005  4.313908e-07  1.357698  10.757994  10.758002
# 14     High  0.000006  3.686640e-07  1.487315  15.030294  15.030438
# 17     High  0.000005  2.945258e-07  1.556312  14.642715  14.642223
# 20     High  0.000012  2.061663e-07  2.022139  28.700400  28.700184
# 23     High  0.000012  2.688214e-07  1.875451  24.532460  24.532474
# 26     High  0.000008  4.307446e-07  1.496510  14.466762  14.466840
#
#     Percent Error  Absolute Percent Error  Absolute Residual Z Molecule    GP
# 1        0.001212                0.001212             0.000016       He   Low  \
# 3        0.004289                0.004289             0.000781       Be   Low
# 5       -0.001791                0.001791             0.000024       Ne   Low
# 7       -0.001038                0.001038             0.000985       Mg   Low
# 9        0.002003                0.002003             0.000149       Ar   Low
# 11      -0.000844                0.000844             0.000144       N2   Low
# 13      -0.000447                0.000447             0.000052       F2   Low
# 15      -0.040424                0.040424             0.000497     NaCl   Low
# 17       0.008065                0.008065             0.000394     LiCl   Low
# 19       0.001832                0.001832             0.000490       CO   Low
# 2        0.000101                0.000101             0.000001       He  High
# 5       -0.000027                0.000027             0.000003       Ne  High
# 8       -0.000651                0.000651             0.000038       Mg  High
# 11      -0.000073                0.000073             0.000007       Ar  High
# 14      -0.000958                0.000958             0.000009       N2  High
# 17       0.003356                0.003356             0.000007       F2  High
# 20       0.000754                0.000754             0.000024     NaCl  High
# 23      -0.000057                0.000057             0.000023     LiCl  High
# 26      -0.000540                0.000540             0.000012       CO  High
#
#       RP
# 1    Low
# 3    Low
# 5    Low
# 7    Low
# 9    Low
# 11   Low
# 13   Low
# 15   Low
# 17   Low
# 19   Low
# 2   High
# 5   High
# 8   High
# 11  High
# 14  High
# 17  High
# 20  High
# 23  High
# 26  High

# %%
# violin plot strip plot

sns.set_context("paper", font_scale=1.50)
sns.set_style("darkgrid")
sns.set_palette("colorblind")
style = 'Molecule'
hue = 'Molecule'
kind='strip'
jitter=False
height=3
aspect_ratio=1.0


with sns.plotting_context('paper', font_scale=1.00):
    facet_kws = {'margin_titles': True, 'despine': False}
    g = sns.catplot(x='Protocol', y='Absolute Percent Error', hue='Molecule',
                    data=data,
                    kind=kind, dodge=jitter, jitter=jitter,
                    height=height, aspect=aspect_ratio, sharey=True,
                    facet_kws=facet_kws, alpha=0.9,
                    )
    ax=g.axes.flat[0]
    ax.axhline(.02, ls='--', color='orange')
    ax.axhline(.005, ls='--', color='green')
    ax.set_yscale('log', )
    # adjust legend
    g._legend.set_title('System')


g.savefig(paper_path.joinpath('mra_convergence.png'),dpi=600)

# %%
with sns.plotting_context('paper', font_scale=1.00):
    facet_kws = {'margin_titles': True, 'despine': False}
    g = sns.catplot(x='Protocol', y='Percent Error', hue='Molecule',
                    data=data,
                    kind=kind, dodge=jitter, jitter=jitter,
                    height=height, aspect=aspect_ratio, sharey=True,
                    facet_kws=facet_kws, alpha=0.9,
                    )
    ax=g.axes.flat[0]
    ax.axhline(.05, ls='--', color='orange')
    ax.axhline(.005, ls='--', color='green')
    ax.axhline(-.05, ls='--', color='orange')
    ax.axhline(-.005, ls='--', color='green')
    #ax.set_yscale('log', )

# %%
data = fd_compare_data
data = november_absolute_data

sns.set_context("paper", font_scale=1.50)
sns.set_style("darkgrid")
sns.set_palette("colorblind")
style = 'Molecule'
hue = 'Response Protocol'
s = 200
x = 'dz'
g = sns.relplot(x=x, y='Percent Error', data=data, style=style, hue=hue, s=s,
                col='Ground Protocol')
# set the subplot titles to Ground Protocol = H or M
g.set_titles(col_template="Ground Protocol : {col_name}")
# increase the font of the legend

for ax in g.axes.flat:
    ax.set_xscale('log')
    ax.set_yscale('symlog', linthresh=1e-4)
    # write an annotation indicating the green line is .005
    # only on first left plot
    if ax == g.axes.flat[0]:
        ax.axhline(.05, ls='--', color='orange')
        ax.axhline(-.05, ls='--', color='orange')
        ax.annotate('0.02%', xy=(1e-4, .02), xytext=(1e-4, .022))
        ax.annotate('-0.02%', xy=(1e-4, -.02), xytext=(1e-4, -.022))
    else:
        ax.axhline(.005, ls='--', color='green')
        ax.axhline(-.005, ls='--', color='green')
        ax.annotate('0.005%', xy=(1e-4, .005), xytext=(1e-4, .006))
        ax.annotate('-0.005%', xy=(1e-4, -.005), xytext=(1e-4, -.006))

# Draw a y=x line on each plot
for ax in g.axes.flat:
    ax.set_xlabel(r'$\Delta \rho_{z}(x)$')
    # y label is percent error of static polarizability

g.fig.gca().invert_xaxis()
# Change the marker size in the legend to be larger and more legible
for lh in g.legend.legend_handles:
    lh._sizes = [100]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 11
#       9 s = 200
#      10 x = 'dz'
# ---> 11 g = sns.relplot(x=x, y='Percent Error', data=data, style=style, hue=hue, s=s,
#      12                 col='Ground Protocol')
#      13 # set the subplot titles to Ground Protocol = H or M
#      14 g.set_titles(col_template="Ground Protocol : {col_name}")
#
# File ~/projects/QuantumResponsePro/venv/lib/python3.10/site-packages/seaborn/relational.py:862, in relplot(data, x, y, hue, size, style, units, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     859     kwargs.pop("ax")
#     861 # Use the full dataset to map the semantics
# --> 862 p = plotter(
#     863     data=data,
#     864     variables=plotter.get_semantics(locals()),
#     865     legend=legend,
#     866 )
#     867 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     868 p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~/projects/QuantumResponsePro/venv/lib/python3.10/site-packages/seaborn/relational.py:538, in _ScatterPlotter.__init__(self, data, variables, legend)
#     529 def __init__(self, *, data=None, variables={}, legend=None):
#     530
#     531     # TODO this is messy, we want the mapping to be agnostic about
#     532     # the kind of plot to draw, but for the time being we need to set
#     533     # this information so the SizeMapping can use it
#     534     self._default_size_range = (
#     535         np.r_[.5, 2] * np.square(mpl.rcParams["lines.markersize"])
#     536     )
# --> 538     super().__init__(data=data, variables=variables)
#     540     self.legend = legend
#
# File ~/projects/QuantumResponsePro/venv/lib/python3.10/site-packages/seaborn/_oldcore.py:640, in VectorPlotter.__init__(self, data, variables)
#     635 # var_ordered is relevant only for categorical axis variables, and may
#     636 # be better handled by an internal axis information object that tracks
#     637 # such information and is set up by the scale_* methods. The analogous
#     638 # information for numeric axes would be information about log scales.
#     639 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 640 self.assign_variables(data, variables)
#     642 for var, cls in self._semantic_mappings.items():
#     643
#     644     # Create the mapping function
#     645     map_func = partial(cls.map, plotter=self)
#
# File ~/projects/QuantumResponsePro/venv/lib/python3.10/site-packages/seaborn/_oldcore.py:701, in VectorPlotter.assign_variables(self, data, variables)
#     699 else:
#     700     self.input_format = "long"
# --> 701     plot_data, variables = self._assign_variables_longform(
#     702         data, **variables,
#     703     )
#     705 self.plot_data = plot_data
#     706 self.variables = variables
#
# File ~/projects/QuantumResponsePro/venv/lib/python3.10/site-packages/seaborn/_oldcore.py:938, in VectorPlotter._assign_variables_longform(self, data, **kwargs)
#     933 elif isinstance(val, (str, bytes)):
#     934
#     935     # This looks like a column name but we don't know what it means!
#     937     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 938     raise ValueError(err)
#     940 else:
#     941
#     942     # Otherwise, assume the value is itself data
#     943
#     944     # Raise when data object is present and a vector can't matched
#     945     if isinstance(data, pd.DataFrame) and not isinstance(val, pd.Series):
#
# ValueError: Could not interpret value `Response Protocol` for parameter `hue`

# %%
MadnessResponse('NaCl','hf','dipole',november_absolute_path.joinpath('low-low')).plot_residuals()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 MadnessResponse('NaCl','hf','dipole',november_absolute_path.joinpath('low-low')).plot_residuals()
#
# File ~/projects/QuantumResponsePro/src/quantumresponsepro/madness/madness_reader_v2.py:312, in MadnessResponse.__init__(self, mol, xc, operator, data_dir)
#     309 self.operator = operator
#     310 self.moldir = self.data_dir.joinpath(self.xc).joinpath(self.mol)
# --> 312 mad_reader = MadnessReader(self.data_dir)
#     313 (
#     314     self.ground_params,
#     315     self.ground_scf_data,
#     316     self.ground_timing,
#     317     self.ground_info,
#     318 ) = mad_reader.get_ground_scf_data(mol, xc)
#     319 e_name_list = ["e_coulomb", "e_kinetic", "e_local", "e_nrep", "e_tot"]
#
# File ~/projects/QuantumResponsePro/src/quantumresponsepro/madness/madness_reader_v2.py:22, in MadnessReader.__init__(self, data_dir)
#      20 self.molecule_dir = data_dir.joinpath('molecules')
#      21 # TODO: Need to make this json_data/frequency.json
# ---> 22 with open(self.data_dir.joinpath('json_data/frequency.json')) as \
#      23         json_file:
#      24     self.freq_json = json.loads(json_file.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/json_data/frequency.json'

# %%
data.query('Protocol=="Medium" and Molecule=="NaCl"')
# Out:
#    Protocol        rz        dz     znorm        MRA         FD
# 15   Medium  0.000246  0.000030  2.021737  28.688582  28.700184  \
# 22   Medium  0.000285  0.000025  2.022149  28.700564  28.700184
#
#     Percent Error  Absolute Percent Error  Absolute Residual Z Molecule
# 15      -0.040424                0.040424             0.000497     NaCl  \
# 22       0.001325                0.001325             0.000576     NaCl
#
#    Ground Protocol Response Protocol
# 15          Medium            Medium
# 22            High            Medium

# %%
sns.set_context("paper", font_scale=1)
sns.set_style("whitegrid")
sns.set_palette("colorblind")
style = 'Molecule'
hue = 'Protocol'
s = 200
x = 'dz'
y = 'Absolute Residual Z'

g = sns.relplot(x=y, y=x, data=data, hue=hue,style=style, s=s,
                col='Ground Protocol')

for ax in g.axes.flat:
    ax.set_yscale('log')
    ax.set_xscale('log')
# Change the marker size in the legend to be larger and more legible
for lh in g.legend.legend_handles:
    lh._sizes = [100]
    
# draw a y=x line on each plot

for ax in g.axes.flat:
    ax.plot([1e-6,1e-2],[1e-6,1e-2], ls='--', color='black')
    ax.set_xlabel('||f(x)-x||')
    ax.set_ylabel(r'$\Delta \rho_{z}(x)$')
    ax.set_title('{}'.format(ax.get_title()))

g.fig.gca().invert_xaxis()

# %%
mols=data.Molecule.unique().tolist()

# %%
from DataAnalysisClass import *
single = ['aug-cc-pVDZ', 'aug-cc-pVTZ', 'aug-cc-pVQZ', 'aug-cc-pV5Z', 'aug-cc-pV6Z']
single_polarized = ['aug-cc-pCVDZ', 'aug-cc-pCVTZ', 'aug-cc-pCVQZ']
double = ['d-aug-cc-pVDZ', 'd-aug-cc-pVTZ', 'd-aug-cc-pVQZ', 'd-aug-cc-pV5Z', 'd-aug-cc-pV6Z']
double_polarized = ['d-aug-cc-pCVDZ', 'd-aug-cc-pCVTZ', 'd-aug-cc-pCVQZ']
all_basis_sets = single + single_polarized+ double  + double_polarized

# %%
low_data=PolarizabilityData(mols,'hf','dipole',all_basis_sets,november_absolute_path.joinpath
('low-low'),overwrite=True)
high_data=PolarizabilityData(mols,'hf','dipole',all_basis_sets,november_absolute_path
                                .joinpath
('high-high'),overwrite=True)
# Out:
# He /mnt/data/madness_data/november_absolute_kain/low-low/hf/He/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/He/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/He/beta.json'
# Be /mnt/data/madness_data/november_absolute_kain/low-low/hf/Be/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/Be/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/Be/beta.json'
# Ne /mnt/data/madness_data/november_absolute_kain/low-low/hf/Ne/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/Ne/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/Ne/beta.json'
# Mg /mnt/data/madness_data/november_absolute_kain/low-low/hf/Mg/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/Mg/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/Mg/beta.json'
# Ar /mnt/data/madness_data/november_absolute_kain/low-low/hf/Ar/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/Ar/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/Ar/beta.json'
# N2 /mnt/data/madness_data/november_absolute_kain/low-low/hf/N2/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/N2/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/N2/beta.json'
# F2 /mnt/data/madness_data/november_absolute_kain/low-low/hf/F2/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/F2/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/F2/beta.json'
# NaCl /mnt/data/madness_data/november_absolute_kain/low-low/hf/NaCl/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/NaCl/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/NaCl/beta.json'
# LiCl /mnt/data/madness_data/november_absolute_kain/low-low/hf/LiCl/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/LiCl/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/LiCl/beta.json'
# CO /mnt/data/madness_data/november_absolute_kain/low-low/hf/CO/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/CO/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/CO/beta.json'
# DaltonRunner base_dir:  /mnt/data/madness_data/november_absolute_kain/low-low
# DaltonRunner dal_dir:  /mnt/data/madness_data/november_absolute_kain/low-low/dalton
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# None None
# KeyError:  'energyCalculation'
# freq_Be-aug-cc-pV5Z  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/Be/dipole  did not run correctly
# most likely the basis set is not available
# Be aug-cc-pV5Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# None None
# KeyError:  'energyCalculation'
# freq_Mg-aug-cc-pV5Z  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/Mg/dipole  did not run correctly
# most likely the basis set is not available
# Mg aug-cc-pV5Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# None None
# KeyError:  'energyCalculation'
# freq_NaCl-aug-cc-pV5Z  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/NaCl/dipole  did not run correctly
# most likely the basis set is not available
# NaCl aug-cc-pV5Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# None None
# KeyError:  'energyCalculation'
# freq_LiCl-aug-cc-pV5Z  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/LiCl/dipole  did not run correctly
# most likely the basis set is not available
# LiCl aug-cc-pV5Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# Did not find  aug-cc-pV6Z  data for He and dalton is not set to run
# He aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# Did not find  aug-cc-pV6Z  data for Be and dalton is not set to run
# Be aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# Did not find  aug-cc-pV6Z  data for Ne and dalton is not set to run
# Ne aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# Did not find  aug-cc-pV6Z  data for Mg and dalton is not set to run
# Mg aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# Did not find  aug-cc-pV6Z  data for Ar and dalton is not set to run
# Ar aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# Did not find  aug-cc-pV6Z  data for N2 and dalton is not set to run
# N2 aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# Did not find  aug-cc-pV6Z  data for F2 and dalton is not set to run
# F2 aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# Did not find  aug-cc-pV6Z  data for NaCl and dalton is not set to run
# NaCl aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# Did not find  aug-cc-pV6Z  data for LiCl and dalton is not set to run
# LiCl aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# Did not find  aug-cc-pV6Z  data for CO and dalton is not set to run
# CO aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# None None
# KeyError:  'energyCalculation'
# freq_Ne-aug-cc-pCVDZ  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/Ne/dipole  did not run correctly
# most likely the basis set is not available
# Ne aug-cc-pCVDZ
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# None None
# KeyError:  'energyCalculation'
# freq_Be-d-aug-cc-pV5Z  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/Be/dipole  did not run correctly
# most likely the basis set is not available
# Be d-aug-cc-pV5Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# None None
# KeyError:  'energyCalculation'
# freq_Mg-d-aug-cc-pV5Z  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/Mg/dipole  did not run correctly
# most likely the basis set is not available
# Mg d-aug-cc-pV5Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# None None
# KeyError:  'energyCalculation'
# freq_NaCl-d-aug-cc-pV5Z  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/NaCl/dipole  did not run correctly
# most likely the basis set is not available
# NaCl d-aug-cc-pV5Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# None None
# KeyError:  'energyCalculation'
# freq_LiCl-d-aug-cc-pV5Z  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/LiCl/dipole  did not run correctly
# most likely the basis set is not available
# LiCl d-aug-cc-pV5Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# Did not find  d-aug-cc-pV6Z  data for He and dalton is not set to run
# He d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# Did not find  d-aug-cc-pV6Z  data for Be and dalton is not set to run
# Be d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# Did not find  d-aug-cc-pV6Z  data for Ne and dalton is not set to run
# Ne d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# Did not find  d-aug-cc-pV6Z  data for Mg and dalton is not set to run
# Mg d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# Did not find  d-aug-cc-pV6Z  data for Ar and dalton is not set to run
# Ar d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# Did not find  d-aug-cc-pV6Z  data for N2 and dalton is not set to run
# N2 d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# Did not find  d-aug-cc-pV6Z  data for F2 and dalton is not set to run
# F2 d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# Did not find  d-aug-cc-pV6Z  data for NaCl and dalton is not set to run
# NaCl d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# Did not find  d-aug-cc-pV6Z  data for LiCl and dalton is not set to run
# LiCl d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# Did not find  d-aug-cc-pV6Z  data for CO and dalton is not set to run
# CO d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# None None
# KeyError:  'energyCalculation'
# freq_Ne-d-aug-cc-pCVDZ  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/Ne/dipole  did not run correctly
# most likely the basis set is not available
# Ne d-aug-cc-pCVDZ
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# He /mnt/data/madness_data/november_absolute_kain/low-low/hf/He/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/He/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/He/beta.json'
# Be /mnt/data/madness_data/november_absolute_kain/low-low/hf/Be/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/Be/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/Be/beta.json'
# Ne /mnt/data/madness_data/november_absolute_kain/low-low/hf/Ne/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/Ne/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/Ne/beta.json'
# Mg /mnt/data/madness_data/november_absolute_kain/low-low/hf/Mg/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/Mg/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/Mg/beta.json'
# Ar /mnt/data/madness_data/november_absolute_kain/low-low/hf/Ar/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/Ar/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/Ar/beta.json'
# N2 /mnt/data/madness_data/november_absolute_kain/low-low/hf/N2/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/N2/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/N2/beta.json'
# F2 /mnt/data/madness_data/november_absolute_kain/low-low/hf/F2/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/F2/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/F2/beta.json'
# NaCl /mnt/data/madness_data/november_absolute_kain/low-low/hf/NaCl/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/NaCl/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/NaCl/beta.json'
# LiCl /mnt/data/madness_data/november_absolute_kain/low-low/hf/LiCl/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/LiCl/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/LiCl/beta.json'
# CO /mnt/data/madness_data/november_absolute_kain/low-low/hf/CO/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/CO/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/CO/beta.json'
# DaltonRunner base_dir:  /mnt/data/madness_data/november_absolute_kain/low-low
# DaltonRunner dal_dir:  /mnt/data/madness_data/november_absolute_kain/low-low/dalton
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# None None
# KeyError:  'energyCalculation'
# freq_Be-aug-cc-pV5Z  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/Be/dipole  did not run correctly
# most likely the basis set is not available
# Be aug-cc-pV5Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# None None
# KeyError:  'energyCalculation'
# freq_Mg-aug-cc-pV5Z  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/Mg/dipole  did not run correctly
# most likely the basis set is not available
# Mg aug-cc-pV5Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# None None
# KeyError:  'energyCalculation'
# freq_NaCl-aug-cc-pV5Z  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/NaCl/dipole  did not run correctly
# most likely the basis set is not available
# NaCl aug-cc-pV5Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# None None
# KeyError:  'energyCalculation'
# freq_LiCl-aug-cc-pV5Z  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/LiCl/dipole  did not run correctly
# most likely the basis set is not available
# LiCl aug-cc-pV5Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# Did not find  aug-cc-pV6Z  data for He and dalton is not set to run
# He aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# Did not find  aug-cc-pV6Z  data for Be and dalton is not set to run
# Be aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# Did not find  aug-cc-pV6Z  data for Ne and dalton is not set to run
# Ne aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# Did not find  aug-cc-pV6Z  data for Mg and dalton is not set to run
# Mg aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# Did not find  aug-cc-pV6Z  data for Ar and dalton is not set to run
# Ar aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# Did not find  aug-cc-pV6Z  data for N2 and dalton is not set to run
# N2 aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# Did not find  aug-cc-pV6Z  data for F2 and dalton is not set to run
# F2 aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# Did not find  aug-cc-pV6Z  data for NaCl and dalton is not set to run
# NaCl aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# Did not find  aug-cc-pV6Z  data for LiCl and dalton is not set to run
# LiCl aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# Did not find  aug-cc-pV6Z  data for CO and dalton is not set to run
# CO aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# None None
# KeyError:  'energyCalculation'
# freq_Ne-aug-cc-pCVDZ  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/Ne/dipole  did not run correctly
# most likely the basis set is not available
# Ne aug-cc-pCVDZ
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# None None
# KeyError:  'energyCalculation'
# freq_Be-d-aug-cc-pV5Z  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/Be/dipole  did not run correctly
# most likely the basis set is not available
# Be d-aug-cc-pV5Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# None None
# KeyError:  'energyCalculation'
# freq_Mg-d-aug-cc-pV5Z  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/Mg/dipole  did not run correctly
# most likely the basis set is not available
# Mg d-aug-cc-pV5Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# None None
# KeyError:  'energyCalculation'
# freq_NaCl-d-aug-cc-pV5Z  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/NaCl/dipole  did not run correctly
# most likely the basis set is not available
# NaCl d-aug-cc-pV5Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# None None
# KeyError:  'energyCalculation'
# freq_LiCl-d-aug-cc-pV5Z  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/LiCl/dipole  did not run correctly
# most likely the basis set is not available
# LiCl d-aug-cc-pV5Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# Did not find  d-aug-cc-pV6Z  data for He and dalton is not set to run
# He d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# Did not find  d-aug-cc-pV6Z  data for Be and dalton is not set to run
# Be d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# Did not find  d-aug-cc-pV6Z  data for Ne and dalton is not set to run
# Ne d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# Did not find  d-aug-cc-pV6Z  data for Mg and dalton is not set to run
# Mg d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# Did not find  d-aug-cc-pV6Z  data for Ar and dalton is not set to run
# Ar d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# Did not find  d-aug-cc-pV6Z  data for N2 and dalton is not set to run
# N2 d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# Did not find  d-aug-cc-pV6Z  data for F2 and dalton is not set to run
# F2 d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# Did not find  d-aug-cc-pV6Z  data for NaCl and dalton is not set to run
# NaCl d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# Did not find  d-aug-cc-pV6Z  data for LiCl and dalton is not set to run
# LiCl d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# Did not find  d-aug-cc-pV6Z  data for CO and dalton is not set to run
# CO d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# None None
# KeyError:  'energyCalculation'
# freq_Ne-d-aug-cc-pCVDZ  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/Ne/dipole  did not run correctly
# most likely the basis set is not available
# Ne d-aug-cc-pCVDZ
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ar.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/N2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/F2.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/NaCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/LiCl.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/CO.mol
# molecule
# He      0.005975
# Be      0.000643
# Ne      0.050747
# Mg      0.006295
# Ar      0.016538
# N2      0.032521
# F2      0.074641
# NaCl    0.022187
# LiCl    0.018517
# CO      0.036203
# Name: error, dtype: float64
# molecule
# He      0.000496
# Be      0.000147
# Ne      0.013824
# Mg      0.001284
# Ar      0.004158
# N2      0.008473
# F2      0.018653
# NaCl    0.005902
# LiCl    0.004090
# CO      0.009457
# Name: error, dtype: float64
# molecule
# He      0.000157
# Be      0.000053
# Ne      0.003341
# Mg      0.000401
# Ar      0.000705
# N2      0.001613
# F2      0.004439
# NaCl    0.001810
# LiCl    0.000794
# CO      0.001853
# Name: error, dtype: float64
# molecule
# Ar      0.000163
# Be           NaN
# CO      0.000231
# F2      0.000433
# He      0.000052
# LiCl         NaN
# Mg           NaN
# N2      0.000212
# NaCl         NaN
# Ne      0.000311
# Name: error, dtype: float64
# molecule
# Ar      0.016529
# Be      0.000643
# CO      0.035560
# F2      0.074300
# He      0.005975
# LiCl    0.018117
# Mg      0.006293
# N2      0.031811
# NaCl    0.021629
# Ne           NaN
# Name: error, dtype: float64
# molecule
# He      0.000496
# Be      0.000147
# Ne      0.013706
# Mg      0.001284
# Ar      0.004155
# N2      0.007488
# F2      0.018285
# NaCl    0.004976
# LiCl    0.003852
# CO      0.008810
# Name: error, dtype: float64
# molecule
# He      0.000157
# Be      0.000053
# Ne      0.003244
# Mg      0.000401
# Ar      0.000705
# N2      0.001412
# F2      0.004252
# NaCl    0.000932
# LiCl    0.000665
# CO      0.001617
# Name: error, dtype: float64
# molecule
# He      0.005970
# Be      0.000636
# Ne      0.050732
# Mg      0.006282
# Ar      0.016494
# N2      0.032298
# F2      0.073784
# NaCl    0.022037
# LiCl    0.017453
# CO      0.035830
# Name: error, dtype: float64
# molecule
# He      0.000495
# Be      0.000146
# Ne      0.013808
# Mg      0.001283
# Ar      0.004141
# N2      0.008396
# F2      0.018010
# NaCl    0.005796
# LiCl    0.004010
# CO      0.009214
# Name: error, dtype: float64
# molecule
# He      0.000157
# Be      0.000053
# Ne      0.003329
# Mg      0.000400
# Ar      0.000700
# N2      0.001591
# F2      0.004222
# NaCl    0.001765
# LiCl    0.000781
# CO      0.001789
# Name: error, dtype: float64
# molecule
# Ar      0.000161
# Be           NaN
# CO      0.000223
# F2      0.000414
# He      0.000052
# LiCl         NaN
# Mg           NaN
# N2      0.000206
# NaCl         NaN
# Ne      0.000308
# Name: error, dtype: float64
# molecule
# Ar      0.016485
# Be      0.000636
# CO      0.035182
# F2      0.073409
# He      0.005970
# LiCl    0.017100
# Mg      0.006280
# N2      0.031592
# NaCl    0.021546
# Ne           NaN
# Name: error, dtype: float64
# molecule
# He      0.000495
# Be      0.000146
# Ne      0.013692
# Mg      0.001283
# Ar      0.004139
# N2      0.007439
# F2      0.017677
# NaCl    0.004883
# LiCl    0.003794
# CO      0.008673
# Name: error, dtype: float64
# molecule
# He      0.000157
# Be      0.000053
# Ne      0.003232
# Mg      0.000400
# Ar      0.000699
# N2      0.001391
# F2      0.004028
# NaCl    0.000914
# LiCl    0.000653
# CO      0.001559
# Name: error, dtype: float64
# He /mnt/data/madness_data/november_absolute_kain/low-low/hf/He/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/He/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/He/beta.json'
# Be /mnt/data/madness_data/november_absolute_kain/low-low/hf/Be/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/Be/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/Be/beta.json'
# Ne /mnt/data/madness_data/november_absolute_kain/low-low/hf/Ne/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/Ne/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/Ne/beta.json'
# Mg /mnt/data/madness_data/november_absolute_kain/low-low/hf/Mg/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/Mg/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/Mg/beta.json'
# Ar /mnt/data/madness_data/november_absolute_kain/low-low/hf/Ar/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/Ar/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/Ar/beta.json'
# N2 /mnt/data/madness_data/november_absolute_kain/low-low/hf/N2/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/N2/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/N2/beta.json'
# F2 /mnt/data/madness_data/november_absolute_kain/low-low/hf/F2/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/F2/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/F2/beta.json'
# NaCl /mnt/data/madness_data/november_absolute_kain/low-low/hf/NaCl/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/NaCl/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/NaCl/beta.json'
# LiCl /mnt/data/madness_data/november_absolute_kain/low-low/hf/LiCl/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/LiCl/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/LiCl/beta.json'
# CO /mnt/data/madness_data/november_absolute_kain/low-low/hf/CO/dipole_hf_0-000000/response_base.json
# /mnt/data/madness_data/november_absolute_kain/low-low/hf/CO/beta.json
# [Errno 2] No such file or directory: '/mnt/data/madness_data/november_absolute_kain/low-low/hf/CO/beta.json'
# /mnt/data/madness_data/november_absolute_kain/low-low
# DaltonRunner base_dir:  /mnt/data/madness_data/november_absolute_kain/low-low
# DaltonRunner dal_dir:  /mnt/data/madness_data/november_absolute_kain/low-low/dalton
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# Did not find  aug-cc-pV6Z  data for He and dalton is not set to run
# He aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# Did not find  d-aug-cc-pV6Z  data for He and dalton is not set to run
# He d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/He.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# None None
# KeyError:  'energyCalculation'
# freq_Be-aug-cc-pV5Z  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/Be/dipole  did not run correctly
# most likely the basis set is not available
# Be aug-cc-pV5Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# Did not find  aug-cc-pV6Z  data for Be and dalton is not set to run
# Be aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# None None
# KeyError:  'energyCalculation'
# freq_Be-d-aug-cc-pV5Z  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/Be/dipole  did not run correctly
# most likely the basis set is not available
# Be d-aug-cc-pV5Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# Did not find  d-aug-cc-pV6Z  data for Be and dalton is not set to run
# Be d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Be.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# Did not find  aug-cc-pV6Z  data for Ne and dalton is not set to run
# Ne aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# None None
# KeyError:  'energyCalculation'
# freq_Ne-aug-cc-pCVDZ  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/Ne/dipole  did not run correctly
# most likely the basis set is not available
# Ne aug-cc-pCVDZ
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# Did not find  d-aug-cc-pV6Z  data for Ne and dalton is not set to run
# Ne d-aug-cc-pV6Z
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# None None
# KeyError:  'energyCalculation'
# freq_Ne-d-aug-cc-pCVDZ  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/Ne/dipole  did not run correctly
# most likely the basis set is not available
# Ne d-aug-cc-pCVDZ
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Ne.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# /mnt/data/madness_data/november_absolute_kain/low-low/molecules/Mg.mol
# None None
# KeyError:  'energyCalculation'
# freq_Mg-aug-cc-pV5Z  in  /mnt/data/madness_data/november_absolute_kain/low-low/dalton/hf/Mg/dipole  did not run correctly
# most likely the basis set is not available
# ...
# 8        CO  aug-cc-pCVDZ  zz      8  15.611266
#
# [81 rows x 5 columns],    molecule         basis  ij  omega      alpha
# 0        CO  aug-cc-pCVTZ  xx      0  11.227806
# 1        CO  aug-cc-pCVTZ  xx      1  11.244718
# 2        CO  aug-cc-pCVTZ  xx      2  11.296011
# 3        CO  aug-cc-pCVTZ  xx      3  11.383419
# 4        CO  aug-cc-pCVTZ  xx      4  11.510043
# ..      ...           ...  ..    ...        ...
# 4        CO  aug-cc-pCVTZ  zz      4  14.759370
# 5        CO  aug-cc-pCVTZ  zz      5  14.919357
# 6        CO  aug-cc-pCVTZ  zz      6  15.120893
# 7        CO  aug-cc-pCVTZ  zz      7  15.368067
# 8        CO  aug-cc-pCVTZ  zz      8  15.666224
#
# [81 rows x 5 columns],    molecule         basis  ij  omega      alpha
# 0        CO  aug-cc-pCVQZ  xx      0  11.269824
# 1        CO  aug-cc-pCVQZ  xx      1  11.286903
# 2        CO  aug-cc-pCVQZ  xx      2  11.338702
# 3        CO  aug-cc-pCVQZ  xx      3  11.426968
# 4        CO  aug-cc-pCVQZ  xx      4  11.554827
# ..      ...           ...  ..    ...        ...
# 4        CO  aug-cc-pCVQZ  zz      4  14.752410
# 5        CO  aug-cc-pCVQZ  zz      5  14.913064
# 6        CO  aug-cc-pCVQZ  zz      6  15.115449
# 7        CO  aug-cc-pCVQZ  zz      7  15.363675
# 8        CO  aug-cc-pCVQZ  zz      8  15.663119
#
# [81 rows x 5 columns],    molecule          basis  ij  omega      alpha
# 0        CO  d-aug-cc-pVDZ  xx      0  11.245942
# 1        CO  d-aug-cc-pVDZ  xx      1  11.262954
# 2        CO  d-aug-cc-pVDZ  xx      2  11.314550
# 3        CO  d-aug-cc-pVDZ  xx      3  11.402469
# 4        CO  d-aug-cc-pVDZ  xx      4  11.529819
# ..      ...            ...  ..    ...        ...
# 4        CO  d-aug-cc-pVDZ  zz      4  14.750966
# 5        CO  d-aug-cc-pVDZ  zz      5  14.910464
# 6        CO  d-aug-cc-pVDZ  zz      6  15.111378
# 7        CO  d-aug-cc-pVDZ  zz      7  15.357780
# 8        CO  d-aug-cc-pVDZ  zz      8  15.654992
#
# [81 rows x 5 columns],    molecule          basis  ij  omega      alpha
# 0        CO  d-aug-cc-pVTZ  xx      0  11.272644
# 1        CO  d-aug-cc-pVTZ  xx      1  11.289739
# 2        CO  d-aug-cc-pVTZ  xx      2  11.341586
# 3        CO  d-aug-cc-pVTZ  xx      3  11.429933
# 4        CO  d-aug-cc-pVTZ  xx      4  11.557906
# ..      ...            ...  ..    ...        ...
# 4        CO  d-aug-cc-pVTZ  zz      4  14.764165
# 5        CO  d-aug-cc-pVTZ  zz      5  14.925033
# 6        CO  d-aug-cc-pVTZ  zz      6  15.127695
# 7        CO  d-aug-cc-pVTZ  zz      7  15.376271
# 8        CO  d-aug-cc-pVTZ  zz      8  15.676150
#
# [81 rows x 5 columns],    molecule          basis  ij  omega      alpha
# 0        CO  d-aug-cc-pVQZ  xx      0  11.272999
# 1        CO  d-aug-cc-pVQZ  xx      1  11.290125
# 2        CO  d-aug-cc-pVQZ  xx      2  11.342068
# 3        CO  d-aug-cc-pVQZ  xx      3  11.430579
# 4        CO  d-aug-cc-pVQZ  xx      4  11.558794
# ..      ...            ...  ..    ...        ...
# 4        CO  d-aug-cc-pVQZ  zz      4  14.744578
# 5        CO  d-aug-cc-pVQZ  zz      5  14.905330
# 6        CO  d-aug-cc-pVQZ  zz      6  15.107852
# 7        CO  d-aug-cc-pVQZ  zz      7  15.356264
# 8        CO  d-aug-cc-pVQZ  zz      8  15.655957
#
# [81 rows x 5 columns],    molecule          basis  ij  omega      alpha
# 0        CO  d-aug-cc-pV5Z  xx      0  11.272519
# 1        CO  d-aug-cc-pV5Z  xx      1  11.289649
# 2        CO  d-aug-cc-pV5Z  xx      2  11.341604
# 3        CO  d-aug-cc-pV5Z  xx      3  11.430136
# 4        CO  d-aug-cc-pV5Z  xx      4  11.558385
# ..      ...            ...  ..    ...        ...
# 4        CO  d-aug-cc-pV5Z  zz      4  14.742039
# 5        CO  d-aug-cc-pV5Z  zz      5  14.902752
# 6        CO  d-aug-cc-pV5Z  zz      6  15.105224
# 7        CO  d-aug-cc-pV5Z  zz      7  15.353574
# 8        CO  d-aug-cc-pV5Z  zz      8  15.653191
#
# [81 rows x 5 columns],    molecule           basis  ij  omega      alpha
# 0        CO  d-aug-cc-pCVDZ  xx      0  11.241681
# 1        CO  d-aug-cc-pCVDZ  xx      1  11.258696
# 2        CO  d-aug-cc-pCVDZ  xx      2  11.310301
# 3        CO  d-aug-cc-pCVDZ  xx      3  11.398236
# 4        CO  d-aug-cc-pCVDZ  xx      4  11.525612
# ..      ...             ...  ..    ...        ...
# 4        CO  d-aug-cc-pCVDZ  zz      4  14.764180
# 5        CO  d-aug-cc-pCVDZ  zz      5  14.923733
# 6        CO  d-aug-cc-pCVDZ  zz      6  15.124716
# 7        CO  d-aug-cc-pCVDZ  zz      7  15.371197
# 8        CO  d-aug-cc-pCVDZ  zz      8  15.668501
#
# [81 rows x 5 columns],    molecule           basis  ij  omega      alpha
# 0        CO  d-aug-cc-pCVTZ  xx      0  11.271893
# 1        CO  d-aug-cc-pCVTZ  xx      1  11.288988
# 2        CO  d-aug-cc-pCVTZ  xx      2  11.340835
# 3        CO  d-aug-cc-pCVTZ  xx      3  11.429181
# 4        CO  d-aug-cc-pCVTZ  xx      4  11.557154
# ..      ...             ...  ..    ...        ...
# 4        CO  d-aug-cc-pCVTZ  zz      4  14.762804
# 5        CO  d-aug-cc-pCVTZ  zz      5  14.923663
# 6        CO  d-aug-cc-pCVTZ  zz      6  15.126315
# 7        CO  d-aug-cc-pCVTZ  zz      7  15.374879
# 8        CO  d-aug-cc-pCVTZ  zz      8  15.674746
#
# [81 rows x 5 columns],    molecule           basis  ij  omega      alpha
# 0        CO  d-aug-cc-pCVQZ  xx      0  11.272801
# 1        CO  d-aug-cc-pCVQZ  xx      1  11.289925
# 2        CO  d-aug-cc-pCVQZ  xx      2  11.341862
# 3        CO  d-aug-cc-pCVQZ  xx      3  11.430363
# 4        CO  d-aug-cc-pCVQZ  xx      4  11.558563
# ..      ...             ...  ..    ...        ...
# 4        CO  d-aug-cc-pCVQZ  zz      4  14.744223
# 5        CO  d-aug-cc-pCVQZ  zz      5  14.904970
# 6        CO  d-aug-cc-pCVQZ  zz      6  15.107484
# 7        CO  d-aug-cc-pCVQZ  zz      7  15.355886
# 8        CO  d-aug-cc-pCVQZ  zz      8  15.655565
#
# [81 rows x 5 columns]]
# cannot reshape array of size 0 into shape (3,3) He MRA
# cannot reshape array of size 0 into shape (3,3) He MRA
# cannot reshape array of size 0 into shape (3,3) He MRA
# cannot reshape array of size 0 into shape (3,3) He MRA
# cannot reshape array of size 0 into shape (3,3) He MRA
# cannot reshape array of size 0 into shape (3,3) He MRA
# cannot reshape array of size 0 into shape (3,3) He MRA
# cannot reshape array of size 0 into shape (3,3) He MRA
# cannot reshape array of size 0 into shape (3,3) Be MRA
# cannot reshape array of size 0 into shape (3,3) Be MRA
# cannot reshape array of size 0 into shape (3,3) Be MRA
# cannot reshape array of size 0 into shape (3,3) Be MRA
# cannot reshape array of size 0 into shape (3,3) Be MRA
# cannot reshape array of size 0 into shape (3,3) Be MRA
# cannot reshape array of size 0 into shape (3,3) Be MRA
# cannot reshape array of size 0 into shape (3,3) Be MRA
# cannot reshape array of size 0 into shape (3,3) Be aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Be aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Be aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Be aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Be aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Be aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Be aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Be aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Be aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Be d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Be d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Be d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Be d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Be d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Be d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Be d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Be d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Be d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Ne MRA
# cannot reshape array of size 0 into shape (3,3) Ne MRA
# cannot reshape array of size 0 into shape (3,3) Ne MRA
# cannot reshape array of size 0 into shape (3,3) Ne MRA
# cannot reshape array of size 0 into shape (3,3) Ne MRA
# cannot reshape array of size 0 into shape (3,3) Ne MRA
# cannot reshape array of size 0 into shape (3,3) Ne MRA
# cannot reshape array of size 0 into shape (3,3) Ne MRA
# cannot reshape array of size 0 into shape (3,3) Ne aug-cc-pCVDZ
# cannot reshape array of size 0 into shape (3,3) Ne aug-cc-pCVDZ
# cannot reshape array of size 0 into shape (3,3) Ne aug-cc-pCVDZ
# cannot reshape array of size 0 into shape (3,3) Ne aug-cc-pCVDZ
# cannot reshape array of size 0 into shape (3,3) Ne aug-cc-pCVDZ
# cannot reshape array of size 0 into shape (3,3) Ne aug-cc-pCVDZ
# cannot reshape array of size 0 into shape (3,3) Ne aug-cc-pCVDZ
# cannot reshape array of size 0 into shape (3,3) Ne aug-cc-pCVDZ
# cannot reshape array of size 0 into shape (3,3) Ne aug-cc-pCVDZ
# cannot reshape array of size 0 into shape (3,3) Ne d-aug-cc-pCVDZ
# cannot reshape array of size 0 into shape (3,3) Ne d-aug-cc-pCVDZ
# cannot reshape array of size 0 into shape (3,3) Ne d-aug-cc-pCVDZ
# cannot reshape array of size 0 into shape (3,3) Ne d-aug-cc-pCVDZ
# cannot reshape array of size 0 into shape (3,3) Ne d-aug-cc-pCVDZ
# cannot reshape array of size 0 into shape (3,3) Ne d-aug-cc-pCVDZ
# cannot reshape array of size 0 into shape (3,3) Ne d-aug-cc-pCVDZ
# cannot reshape array of size 0 into shape (3,3) Ne d-aug-cc-pCVDZ
# cannot reshape array of size 0 into shape (3,3) Ne d-aug-cc-pCVDZ
# cannot reshape array of size 0 into shape (3,3) Mg MRA
# cannot reshape array of size 0 into shape (3,3) Mg MRA
# cannot reshape array of size 0 into shape (3,3) Mg MRA
# cannot reshape array of size 0 into shape (3,3) Mg MRA
# cannot reshape array of size 0 into shape (3,3) Mg MRA
# cannot reshape array of size 0 into shape (3,3) Mg MRA
# cannot reshape array of size 0 into shape (3,3) Mg MRA
# cannot reshape array of size 0 into shape (3,3) Mg MRA
# cannot reshape array of size 0 into shape (3,3) Mg aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Mg aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Mg aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Mg aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Mg aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Mg aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Mg aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Mg aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Mg aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Mg d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Mg d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Mg d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Mg d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Mg d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Mg d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Mg d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Mg d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Mg d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) Ar MRA
# cannot reshape array of size 0 into shape (3,3) Ar MRA
# cannot reshape array of size 0 into shape (3,3) Ar MRA
# cannot reshape array of size 0 into shape (3,3) Ar MRA
# cannot reshape array of size 0 into shape (3,3) Ar MRA
# cannot reshape array of size 0 into shape (3,3) Ar MRA
# cannot reshape array of size 0 into shape (3,3) Ar MRA
# cannot reshape array of size 0 into shape (3,3) Ar MRA
# cannot reshape array of size 0 into shape (3,3) N2 MRA
# cannot reshape array of size 0 into shape (3,3) N2 MRA
# cannot reshape array of size 0 into shape (3,3) N2 MRA
# cannot reshape array of size 0 into shape (3,3) N2 MRA
# cannot reshape array of size 0 into shape (3,3) N2 MRA
# cannot reshape array of size 0 into shape (3,3) N2 MRA
# cannot reshape array of size 0 into shape (3,3) N2 MRA
# cannot reshape array of size 0 into shape (3,3) N2 MRA
# cannot reshape array of size 0 into shape (3,3) F2 MRA
# cannot reshape array of size 0 into shape (3,3) F2 MRA
# cannot reshape array of size 0 into shape (3,3) F2 MRA
# cannot reshape array of size 0 into shape (3,3) F2 MRA
# cannot reshape array of size 0 into shape (3,3) F2 MRA
# cannot reshape array of size 0 into shape (3,3) F2 MRA
# cannot reshape array of size 0 into shape (3,3) F2 MRA
# cannot reshape array of size 0 into shape (3,3) F2 MRA
# cannot reshape array of size 0 into shape (3,3) NaCl MRA
# cannot reshape array of size 0 into shape (3,3) NaCl MRA
# cannot reshape array of size 0 into shape (3,3) NaCl MRA
# cannot reshape array of size 0 into shape (3,3) NaCl MRA
# cannot reshape array of size 0 into shape (3,3) NaCl MRA
# cannot reshape array of size 0 into shape (3,3) NaCl MRA
# cannot reshape array of size 0 into shape (3,3) NaCl MRA
# cannot reshape array of size 0 into shape (3,3) NaCl MRA
# cannot reshape array of size 0 into shape (3,3) NaCl aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) NaCl aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) NaCl aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) NaCl aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) NaCl aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) NaCl aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) NaCl aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) NaCl aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) NaCl aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) NaCl d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) NaCl d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) NaCl d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) NaCl d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) NaCl d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) NaCl d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) NaCl d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) NaCl d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) NaCl d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiCl MRA
# cannot reshape array of size 0 into shape (3,3) LiCl MRA
# cannot reshape array of size 0 into shape (3,3) LiCl MRA
# cannot reshape array of size 0 into shape (3,3) LiCl MRA
# cannot reshape array of size 0 into shape (3,3) LiCl MRA
# cannot reshape array of size 0 into shape (3,3) LiCl MRA
# cannot reshape array of size 0 into shape (3,3) LiCl MRA
# cannot reshape array of size 0 into shape (3,3) LiCl MRA
# cannot reshape array of size 0 into shape (3,3) LiCl aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiCl aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiCl aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiCl aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiCl aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiCl aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiCl aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiCl aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiCl aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiCl d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiCl d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiCl d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiCl d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiCl d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiCl d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiCl d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiCl d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) LiCl d-aug-cc-pV5Z
# cannot reshape array of size 0 into shape (3,3) CO MRA
# cannot reshape array of size 0 into shape (3,3) CO MRA
# cannot reshape array of size 0 into shape (3,3) CO MRA
# cannot reshape array of size 0 into shape (3,3) CO MRA
# cannot reshape array of size 0 into shape (3,3) CO MRA
# cannot reshape array of size 0 into shape (3,3) CO MRA
# cannot reshape array of size 0 into shape (3,3) CO MRA
# cannot reshape array of size 0 into shape (3,3) CO MRA
# Length mismatch: Expected axis has 42 elements, new values have 378 elements
# Could not initialize eigen_diff

# %%
low_data.save_dfs()
high_data.save_dfs()
# Out:
# 'NoneType' object has no attribute 'copy'
# Could not save eigen_diff
# 'NoneType' object has no attribute 'copy'
# Could not save eigen_diff

# %%
low_z_data=create_z_data(low_data)
# create Protocol column
low_z_data['Protocol']='Medium'
high_z_data=create_z_data(high_data)
high_z_data['Protocol']='High'
z_data=pd.concat([low_z_data,high_z_data])
z_data
# Out:
#       molecule           basis  ij  omega      alpha         FD
# 8           He             MRA  zz      0   1.322250   1.322234  \
# 17          Be             MRA  zz      0  45.618340  45.616381
# 26          Ne             MRA  zz      0   2.376704   2.376747
# 35          Mg             MRA  zz      0  81.592880  81.593730
# 44          Ar             MRA  zz      0  10.758220  10.758002
# ...        ...             ...  ..    ...        ...        ...
# 10287       CO   d-aug-cc-pVQZ  zz      0  14.469156  14.466840
# 10368       CO   d-aug-cc-pV5Z  zz      0  14.466686  14.466840
# 10449       CO  d-aug-cc-pCVDZ  zz      0  14.490765  14.466840
# 10530       CO  d-aug-cc-pCVTZ  zz      0  14.487193  14.466840
# 10611       CO  d-aug-cc-pCVQZ  zz      0  14.468812  14.466840
#
#        Percent Error  MRA Percent Error  Absolute Percent Error    MRA
# 8           0.001230           0.001230                0.001230    MRA  \
# 17          0.004295           0.004295                0.004295    MRA
# 26         -0.001795          -0.001795                0.001795    MRA
# 35         -0.001042          -0.001042                0.001042    MRA
# 44          0.002030           0.002030                0.002030    MRA
# ...              ...                ...                     ...    ...
# 10287       0.016012          -0.000553                0.016012  Other
# 10368      -0.001065          -0.000553                0.001065  Other
# 10449       0.165376          -0.000553                0.165376  Other
# 10530       0.140685          -0.000553                0.140685  Other
# 10611       0.013630          -0.000553                0.013630  Other
#
#       Protocol
# 8       Medium
# 17      Medium
# 26      Medium
# 35      Medium
# 44      Medium
# ...        ...
# 10287     High
# 10368     High
# 10449     High
# 10530     High
# 10611     High
#
# [280 rows x 11 columns]

# %%
z_abs_error_plot=compare_z_to_basis_set(z_data,y='Absolute Percent Error')
#z_error_plot=compare_z_to_basis_set(z_data,y='Percent Error')
z_abs_error_plot.fig.savefig(paper_path.joinpath('z_abs_error.png'),dpi=600)
# Out:
# ['D', 'T', 'Q', '5']

# %%
z_data.query('basis=="MRA"').sort_values('molecule')
