# %%
import numpy as np

from DataAnalysisClass import *
from clustering_work import *

single = ['aug-cc-pVDZ', 'aug-cc-pVTZ', 'aug-cc-pVQZ', 'aug-cc-pV5Z', 'aug-cc-pV6Z']
single_polarized = ['aug-cc-pCVDZ', 'aug-cc-pCVTZ', 'aug-cc-pCVQZ']
double = ['d-aug-cc-pVDZ', 'd-aug-cc-pVTZ', 'd-aug-cc-pVQZ', 'd-aug-cc-pV5Z', 'd-aug-cc-pV6Z']
double_polarized = ['d-aug-cc-pCVDZ', 'd-aug-cc-pCVTZ', 'd-aug-cc-pCVQZ']
all_basis_sets = single + single_polarized + double + double_polarized

# %%
database_path = Path('/home/ahurta92/data/august')
paper_path = Path('response_paper_figures')

# %%
import glob

# glob for .mol files in august molecules directory
mols = glob.glob('/home/ahurta92/data/august/molecules/*.mol')
mols = [mol.split('/')[-1].split('.')[0] for mol in mols]
mols.remove('LiH_s')
mols
# Out:
# ['NH2Cl',
#  'NaLi',
#  'F2',
#  'HNS',
#  'N2',
#  'HCHO',
#  'SF2',
#  'LiH',
#  'Na2',
#  'SiO',
#  'Mg',
#  'BH2Cl',
#  'SH2',
#  'P2',
#  'HOCl',
#  'N2H4',
#  'NaCl',
#  'HCCCl',
#  'SiH3F',
#  'HCl',
#  'P2H4',
#  'HCN',
#  'H2',
#  'Mg2',
#  'CSO',
#  'PH3O',
#  'FNO',
#  'S2H2',
#  'CH3OH',
#  'NH3O',
#  'BF',
#  'OCl2',
#  'HBS',
#  'C2H2',
#  'HF',
#  'SO2',
#  'Cl2',
#  'Ar',
#  'PH3',
#  'NH3',
#  'CH2BH',
#  'HCCF',
#  'CH2NH',
#  'SCl2',
#  'CH3SH',
#  'CH3Cl',
#  'BeH2',
#  'LiCl',
#  'HCHS',
#  'NaH',
#  'Ne',
#  'BH3',
#  'C2H4',
#  'ClCN',
#  'OF2',
#  'CH4',
#  'BH2F',
#  'HCONH2',
#  'LiCN',
#  'Be',
#  'CH3BH2',
#  'NOCl',
#  'CS',
#  'He',
#  'SiH4',
#  'CO',
#  'O3',
#  'BHF2',
#  'NaCN',
#  'CH3F',
#  'C6H6',
#  'Li2',
#  'FCN',
#  'CH3NH2',
#  'SiH3Cl',
#  'NH2F',
#  'CO2',
#  'HCP',
#  'NH2OH',
#  'N2H2',
#  'HNO',
#  'ClF',
#  'LiBH4',
#  'HNC',
#  'H2O',
#  'HCOOH',
#  'HOF',
#  'HBO',
#  'HOOH']

# %%
august_database = PolarizabilityData(mols, 'hf', 'dipole', all_basis_sets, database_path, overwrite=False)
# Out:
# energy_df
# Could not initialize energy_df
# energy_diff_df
# Could not initialize energy_diff_df
# polar_data
# Could not initialize polar_data
# alpha_eigen
# Could not initialize alpha_eigen
# eigen_diff
# cannot handle a non-unique multi-index!
# Could not initialize eigen_diff
# iso_data
# Could not initialize iso_data

# %%
august_database.save_dfs()
# Out:
# 'NoneType' object has no attribute 'copy'
# Could not save eigen_diff

# %%
polar_data = august_database.iso_data.copy()

# %%
eigen_data = MRAComparedBasisDF(august_database.alpha_eigen, ['molecule', 'omega', 'ij'], ['alpha'], True)
eigen_data.set_index(['molecule', 'omega', 'ij', 'basis'], inplace=True)
eigen_data = eigen_data['alphaE']
eigen_data = eigen_data.reset_index()
eigen_data
# Out:
# ['D', 'T', 'Q', '5', '6']
#       molecule  omega  ij          basis    alphaE
# 0        NH2Cl      0  xx    aug-cc-pVDZ -6.029056
# 1        NH2Cl      0  yy    aug-cc-pVDZ -5.974476
# 2        NH2Cl      0  zz    aug-cc-pVDZ -2.630619
# 3        NH2Cl      1  xx    aug-cc-pVDZ -6.036499
# 4        NH2Cl      1  yy    aug-cc-pVDZ -5.981679
# ...        ...    ...  ..            ...       ...
# 33502     HOOH      7  yy  d-aug-cc-pV6Z -0.006091
# 33503     HOOH      7  zz  d-aug-cc-pV6Z -0.061921
# 33504     HOOH      8  xx  d-aug-cc-pV6Z -0.002638
# 33505     HOOH      8  yy  d-aug-cc-pV6Z -0.005209
# 33506     HOOH      8  zz  d-aug-cc-pV6Z -0.064413
#
# [33507 rows x 5 columns]

# %%
mol_datas = []
for mol in eigen_data.molecule.unique():
    mol_data = eigen_data.query('molecule==@mol and omega==0 and ij.isin(["xx", "yy", "zz"])')
    mol_data.set_index(['basis', 'ij'], inplace=True)
    mol_data = pd.Series(mol_data['alphaE'], name=mol)
    mol_datas.append(mol_data)

mol_data = pd.concat(mol_datas, axis=1)
eigen_data = mol_data.T.dropna()
eigen_data
# Out:
# basis aug-cc-pVDZ                       aug-cc-pVTZ                      \
# ij             xx         yy         zz          xx        yy        zz
# N2      -3.240022  -3.240189  -1.057930   -0.422607 -0.422777 -0.004998
# H2      -4.537832  -4.537832   1.212129    0.426367  0.426367 -0.061940
# BF      -0.765500  -2.193975  -2.194216    0.094876 -0.428906 -0.429150
# NH3     -2.109549  -2.110349  -3.258989   -0.245801 -0.246613 -1.171783
# Ne     -22.920411 -22.920732 -22.920883   -7.687900 -7.688284 -7.688465
# OF2     -8.387155  -5.473135  -2.556075   -1.753520 -1.370229 -0.618542
# He      -1.383108  -1.383108  -1.383108   -0.472310 -0.472310 -0.472310
# CO      -2.825846  -2.827152  -0.321091   -0.430935 -0.432273  0.152000
# O3      -7.367993  -5.943749  -2.354336   -1.981321 -1.499232 -0.604045
# H2O     -7.320683  -5.580369  -1.605538   -2.277455 -1.666730 -0.224067
# HOOH    -4.638314  -3.258417  -2.309989   -1.156963 -0.729842 -0.670830
#
# basis aug-cc-pVQZ                     aug-cc-pV5Z  ... d-aug-cc-pCVTZ  \
# ij             xx        yy        zz          xx  ...             zz
# N2       0.001173  0.001001  0.000668   -0.001197  ...       0.097883
# H2       0.024806  0.024806 -0.022314   -0.170960  ...       0.103969
# BF       0.028725 -0.053440 -0.053685   -0.003099  ...      -0.113403
# NH3     -0.060836 -0.061607 -0.450953   -0.053554  ...       0.042357
# Ne      -2.005710 -2.006118 -2.006310   -0.568677  ...       0.037161
# OF2     -0.138300 -0.297589 -0.098027   -0.126979  ...       0.025133
# He      -0.050127 -0.050127 -0.050127   -0.074162  ...       0.119318
# CO      -0.036078 -0.037421  0.075240   -0.030926  ...       0.134684
# O3      -0.317517 -0.338156 -0.210339   -0.169678  ...      -0.096954
# H2O     -0.708973 -0.516339 -0.012542   -0.286771  ...       0.036651
# HOOH    -0.236011 -0.140320 -0.235430   -0.121637  ...      -0.019217
#
# basis d-aug-cc-pCVQZ                     aug-cc-pV6Z                      \
# ij                xx        yy        zz          xx        yy        zz
# N2          0.027847  0.027674  0.037613   -0.009827 -0.010000 -0.008252
# H2         -0.095789 -0.095789  0.022381   -0.175937 -0.175937 -0.003235
# BF          0.038709 -0.002672 -0.002917    0.005368  0.003650  0.003404
# NH3         0.001447  0.000656 -0.038767   -0.031534 -0.032306 -0.109802
# Ne          0.129243  0.128826  0.128630   -0.289308 -0.289723 -0.289919
# OF2         0.080698 -0.010661  0.015029   -0.068639 -0.107510 -0.020701
# He          0.005475  0.005475  0.005475   -0.059096 -0.059096 -0.059096
# CO         -0.006119 -0.007463  0.007639   -0.015596 -0.016939 -0.007224
# O3          0.089366  0.039680 -0.097236   -0.102798 -0.051879 -0.101501
# H2O         0.014212 -0.002252  0.041462   -0.131490 -0.109973  0.003729
# HOOH        0.040870  0.016445 -0.058392   -0.063394 -0.037900 -0.090583
#
# basis d-aug-cc-pV6Z
# ij               xx        yy        zz
# N2        -0.009839 -0.010012 -0.002787
# H2        -0.138244 -0.138244  0.000071
# BF         0.012466  0.009329  0.009083
# NH3       -0.009881 -0.010677 -0.061659
# Ne        -0.009830 -0.010246 -0.010442
# OF2        0.004249 -0.063712 -0.003753
# He        -0.065427 -0.065427 -0.065427
# CO        -0.005202 -0.006546 -0.007413
# O3        -0.010234  0.005584 -0.078966
# H2O       -0.024028 -0.015180  0.021887
# HOOH      -0.005125 -0.006483 -0.062514
#
# [11 rows x 48 columns]

# %%
basis_data = MRAComparedBasisDF(polar_data, ['molecule', 'omega'], ['alpha', 'gamma'], True)


def get_basis_data(basis_data, omega=8):
    df = basis_data.query('omega==@omega')
    alphab = {}
    gammab = {}
    for b in basis_data.basis.unique():
        bdata = df.query('basis==@b')
        alphab[b] = bdata.set_index('molecule').alphaE
        gammab[b] = bdata.set_index('molecule').gammaE
    alpha_df = pd.DataFrame(alphab)
    gamma_df = pd.DataFrame(gammab)
    return alpha_df, gamma_df


data = get_basis_data(basis_data, 0)[0]
data.drop(['aug-cc-pV5Z', 'aug-cc-pV6Z', 'd-aug-cc-pV5Z', 'd-aug-cc-pV6Z'], axis=1, inplace=True)
data.dropna(inplace=True)
# Out:
# ['D', 'T', 'Q', '5', '6']

# %%
data
# Out:
#           aug-cc-pVDZ  aug-cc-pVTZ  aug-cc-pVQZ  aug-cc-pCVDZ  aug-cc-pCVTZ  \
# molecule
# NH2Cl       -4.534652    -1.126342    -0.216574     -4.509245     -0.971046
# NaLi         0.516477     0.349046     0.311599      0.335229      0.038116
# F2          -7.572162    -1.978107    -0.287794     -7.523872     -1.972307
# HNS         -4.346559    -0.951496    -0.219287     -4.292811     -0.830132
# N2          -2.294844    -0.241758     0.000905     -2.274195     -0.240628
# ...               ...          ...          ...           ...           ...
# H2O         -4.691596    -1.337698    -0.395071     -4.726778     -1.347078
# HCOOH       -2.031282    -0.478206    -0.098475     -2.063957     -0.482947
# HOF         -5.202670    -1.381061    -0.290065     -5.197167     -1.385698
# HBO         -1.530212    -0.401612    -0.063265     -1.597689     -0.387540
# HOOH        -3.159287    -0.809815    -0.209344     -3.190677     -0.823221
#
#           aug-cc-pCVQZ  d-aug-cc-pVDZ  d-aug-cc-pVTZ  d-aug-cc-pVQZ  \
# molecule
# NH2Cl        -0.100441      -0.567717      -0.140390      -0.089588
# NaLi          0.008665       0.710595       0.363595       0.308348
# F2           -0.282383      -0.357376       0.097390       0.067585
# HNS          -0.133282      -0.607659      -0.110600      -0.075698
# N2            0.010551      -0.413253       0.049461       0.025902
# ...                ...            ...            ...            ...
# H2O          -0.395348      -0.238304       0.028540       0.020835
# HCOOH        -0.101117       0.019683       0.079608       0.024843
# HOF          -0.288098      -0.379711       0.092254       0.044606
# HBO          -0.067317      -0.069291       0.016003       0.028775
# HOOH         -0.209414      -0.186275       0.043908      -0.012088
#
#           d-aug-cc-pCVDZ  d-aug-cc-pCVTZ  d-aug-cc-pCVQZ
# molecule
# NH2Cl          -0.537416        0.021372        0.022927
# NaLi            0.377586        0.054975        0.013227
# F2             -0.329077        0.104903        0.070550
# HNS            -0.551852        0.017656        0.007657
# N2             -0.389182        0.062433        0.032028
# ...                  ...             ...             ...
# H2O            -0.283014        0.020212        0.018503
# HCOOH          -0.021357        0.072467        0.022556
# HOF            -0.389347        0.087285        0.045032
# HBO            -0.112434        0.018098        0.023480
# HOOH           -0.224260        0.032234       -0.012695
#
# [89 rows x 12 columns]

# %%
def cluster_basis_data(data, n_clusters=8):
    scaler = StandardScaler()
    X = data.to_numpy()
    data_scaled = scaler.fit_transform(X)
    # Create an AgglomerativeClustering instance with n_clusters
    agglo = AgglomerativeClustering(n_clusters=n_clusters)
    # Fit the model to your data and get the cluster assignments in one step
    labels = agglo.fit_predict(data_scaled)
    data['cluster'] = labels

    return data


def inv_symlog(y, linthresh):
    """Inverse of symmetric log transformation."""
    return np.sign(y) * linthresh * (np.exp(np.abs(y)) - 1)


def symlog(x, linthresh):
    """Symmetric log transformation."""

    copy_x = x.copy()
    copy_x[np.abs(x) < linthresh] = 0
    #return np.log(np.abs(copy_x/linthresh))
    #return np.sign(copy_x) * np.log1p(np.abs(copy_x / linthresh))
    return np.sign(copy_x) * np.log1p(np.abs(copy_x / linthresh))

# %%
from sklearn import preprocessing

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.mixture import GaussianMixture
# plot data_matrix for each column
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = get_basis_data(basis_data, 0)[0]
#data= mol_data.T
data.drop(['aug-cc-pV5Z', 'aug-cc-pV6Z', 'd-aug-cc-pV5Z', 'd-aug-cc-pV6Z'], axis=1, inplace=True)
# drop DZ basis sets
#data.drop(['aug-cc-pVDZ', 'd-aug-cc-pVDZ','aug-cc-pCVDZ','d-aug-cc-pCVDZ'], axis=1, inplace=True)
#data.drop(['aug-cc-pVTZ', 'd-aug-cc-pVTZ','aug-cc-pCVTZ','d-aug-cc-pCVTZ'], axis=1, inplace=True)
data.dropna(inplace=True)
data
# Out:
#           aug-cc-pVDZ  aug-cc-pVTZ  aug-cc-pVQZ  aug-cc-pCVDZ  aug-cc-pCVTZ  \
# molecule
# NH2Cl       -4.534652    -1.126342    -0.216574     -4.509245     -0.971046
# NaLi         0.516477     0.349046     0.311599      0.335229      0.038116
# F2          -7.572162    -1.978107    -0.287794     -7.523872     -1.972307
# HNS         -4.346559    -0.951496    -0.219287     -4.292811     -0.830132
# N2          -2.294844    -0.241758     0.000905     -2.274195     -0.240628
# ...               ...          ...          ...           ...           ...
# H2O         -4.691596    -1.337698    -0.395071     -4.726778     -1.347078
# HCOOH       -2.031282    -0.478206    -0.098475     -2.063957     -0.482947
# HOF         -5.202670    -1.381061    -0.290065     -5.197167     -1.385698
# HBO         -1.530212    -0.401612    -0.063265     -1.597689     -0.387540
# HOOH        -3.159287    -0.809815    -0.209344     -3.190677     -0.823221
#
#           aug-cc-pCVQZ  d-aug-cc-pVDZ  d-aug-cc-pVTZ  d-aug-cc-pVQZ  \
# molecule
# NH2Cl        -0.100441      -0.567717      -0.140390      -0.089588
# NaLi          0.008665       0.710595       0.363595       0.308348
# F2           -0.282383      -0.357376       0.097390       0.067585
# HNS          -0.133282      -0.607659      -0.110600      -0.075698
# N2            0.010551      -0.413253       0.049461       0.025902
# ...                ...            ...            ...            ...
# H2O          -0.395348      -0.238304       0.028540       0.020835
# HCOOH        -0.101117       0.019683       0.079608       0.024843
# HOF          -0.288098      -0.379711       0.092254       0.044606
# HBO          -0.067317      -0.069291       0.016003       0.028775
# HOOH         -0.209414      -0.186275       0.043908      -0.012088
#
#           d-aug-cc-pCVDZ  d-aug-cc-pCVTZ  d-aug-cc-pCVQZ
# molecule
# NH2Cl          -0.537416        0.021372        0.022927
# NaLi            0.377586        0.054975        0.013227
# F2             -0.329077        0.104903        0.070550
# HNS            -0.551852        0.017656        0.007657
# N2             -0.389182        0.062433        0.032028
# ...                  ...             ...             ...
# H2O            -0.283014        0.020212        0.018503
# HCOOH          -0.021357        0.072467        0.022556
# HOF            -0.389347        0.087285        0.045032
# HBO            -0.112434        0.018098        0.023480
# HOOH           -0.224260        0.032234       -0.012695
#
# [89 rows x 12 columns]

# %%
threshold = 5e-2  # threshold for symlog transformation           

quantile = preprocessing.QuantileTransformer(n_quantiles=10)
robust = preprocessing.RobustScaler()
normalizer = preprocessing.Normalizer()
standard = preprocessing.StandardScaler()

data_matrix = data.to_numpy()
# normalize all values to be between +1 and -1 
#data_matrix/=np.max(np.abs(data_matrix))


data_matrix = symlog(data_matrix, threshold)
#data_matrix = quantile.fit_transform(data_matrix)
#data_matrix=standard.fit_transform(data_matrix)
data_matrix = normalizer.fit_transform(data_matrix)

fig, axes = plt.subplots(4, 3, figsize=(18, 6), sharex=True, sharey=True)
for i, ax in enumerate(axes.flat):
    sns.histplot(data_matrix[:, i], ax=ax, kde=False, bins=10)
    ax.set_title(data.columns[i])


def gmm_bic_score(estimator, X):
    return -estimator.bic(X)

# %%
param_grid = {
    'n_components': range(1, 16),
    'init_params': ['kmeans', 'random_from_data'],  #
    'covariance_type': ['spherical']
}

grid_search = GridSearchCV(GaussianMixture(tol=1e-9, n_init=100, max_iter=2000),
                           param_grid=param_grid, scoring=gmm_bic_score, verbose=3, )
model = grid_search

X = data_matrix
#grid_search.fit(X)
model.fit(X)

df = pd.DataFrame(grid_search.cv_results_)[
    ["param_n_components", "param_covariance_type", "mean_test_score"]
]
df["mean_test_score"] = -df["mean_test_score"]
df = df.rename(
    columns={
        "param_n_components": "Number of components",
        "param_covariance_type": "Type of covariance",
        "mean_test_score": "BIC score",
    }
)

print(grid_search.best_params_)
df.sort_values(by="BIC score").head()

# plot the BIC score for each model
fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=df, x="Number of components", y="BIC score", hue="Type of covariance", ax=ax)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV 1/5] END covariance_type=spherical, init_params=kmeans, n_components=1;, score=34.684 total time=   0.2s
# [CV 2/5] END covariance_type=spherical, init_params=kmeans, n_components=1;, score=85.221 total time=   0.3s
# [CV 3/5] END covariance_type=spherical, init_params=kmeans, n_components=1;, score=-2.865 total time=   0.2s
# [CV 4/5] END covariance_type=spherical, init_params=kmeans, n_components=1;, score=-18.322 total time=   0.2s
# [CV 5/5] END covariance_type=spherical, init_params=kmeans, n_components=1;, score=110.662 total time=   0.2s
# [CV 1/5] END covariance_type=spherical, init_params=kmeans, n_components=2;, score=194.972 total time=   0.2s
# [CV 2/5] END covariance_type=spherical, init_params=kmeans, n_components=2;, score=63.745 total time=   0.3s
# [CV 3/5] END covariance_type=spherical, init_params=kmeans, n_components=2;, score=225.136 total time=   0.7s
# [CV 4/5] END covariance_type=spherical, init_params=kmeans, n_components=2;, score=106.860 total time=   0.3s
# [CV 5/5] END covariance_type=spherical, init_params=kmeans, n_components=2;, score=240.126 total time=   0.6s
# [CV 1/5] END covariance_type=spherical, init_params=kmeans, n_components=3;, score=298.423 total time=   0.2s
# [CV 2/5] END covariance_type=spherical, init_params=kmeans, n_components=3;, score=122.858 total time=   0.2s
# [CV 3/5] END covariance_type=spherical, init_params=kmeans, n_components=3;, score=357.242 total time=   0.2s
# [CV 4/5] END covariance_type=spherical, init_params=kmeans, n_components=3;, score=162.810 total time=   0.1s
# [CV 5/5] END covariance_type=spherical, init_params=kmeans, n_components=3;, score=248.591 total time=   0.2s
# [CV 1/5] END covariance_type=spherical, init_params=kmeans, n_components=4;, score=344.153 total time=   0.2s
# [CV 2/5] END covariance_type=spherical, init_params=kmeans, n_components=4;, score=106.561 total time=   0.4s
# [CV 3/5] END covariance_type=spherical, init_params=kmeans, n_components=4;, score=367.732 total time=   0.2s
# [CV 4/5] END covariance_type=spherical, init_params=kmeans, n_components=4;, score=149.101 total time=   0.2s
# [CV 5/5] END covariance_type=spherical, init_params=kmeans, n_components=4;, score=319.529 total time=   0.2s
# [CV 1/5] END covariance_type=spherical, init_params=kmeans, n_components=5;, score=368.215 total time=   0.3s
# [CV 2/5] END covariance_type=spherical, init_params=kmeans, n_components=5;, score=114.087 total time=   0.4s
# [CV 3/5] END covariance_type=spherical, init_params=kmeans, n_components=5;, score=375.415 total time=   0.3s
# [CV 4/5] END covariance_type=spherical, init_params=kmeans, n_components=5;, score=138.598 total time=   0.5s
# [CV 5/5] END covariance_type=spherical, init_params=kmeans, n_components=5;, score=278.138 total time=   0.4s
# [CV 1/5] END covariance_type=spherical, init_params=kmeans, n_components=6;, score=266.435 total time=   0.3s
# [CV 2/5] END covariance_type=spherical, init_params=kmeans, n_components=6;, score=52.545 total time=   0.3s
# [CV 3/5] END covariance_type=spherical, init_params=kmeans, n_components=6;, score=306.507 total time=   0.6s
# [CV 4/5] END covariance_type=spherical, init_params=kmeans, n_components=6;, score=134.943 total time=   1.0s
# [CV 5/5] END covariance_type=spherical, init_params=kmeans, n_components=6;, score=269.267 total time=   0.5s
# [CV 1/5] END covariance_type=spherical, init_params=kmeans, n_components=7;, score=293.234 total time=   1.4s
# [CV 2/5] END covariance_type=spherical, init_params=kmeans, n_components=7;, score=-8.642 total time=   0.6s
# [CV 3/5] END covariance_type=spherical, init_params=kmeans, n_components=7;, score=289.639 total time=   1.5s
# [CV 4/5] END covariance_type=spherical, init_params=kmeans, n_components=7;, score=22.869 total time=   0.4s
# [CV 5/5] END covariance_type=spherical, init_params=kmeans, n_components=7;, score=209.628 total time=   0.5s
# [CV 1/5] END covariance_type=spherical, init_params=kmeans, n_components=8;, score=161.151 total time=   0.7s
# [CV 2/5] END covariance_type=spherical, init_params=kmeans, n_components=8;, score=-108.342 total time=   0.4s
# [CV 3/5] END covariance_type=spherical, init_params=kmeans, n_components=8;, score=266.841 total time=   0.5s
# [CV 4/5] END covariance_type=spherical, init_params=kmeans, n_components=8;, score=-25.889 total time=   0.3s
# [CV 5/5] END covariance_type=spherical, init_params=kmeans, n_components=8;, score=231.172 total time=   0.3s
# [CV 1/5] END covariance_type=spherical, init_params=kmeans, n_components=9;, score=162.307 total time=   0.7s
# [CV 2/5] END covariance_type=spherical, init_params=kmeans, n_components=9;, score=-220.688 total time=   0.5s
# [CV 3/5] END covariance_type=spherical, init_params=kmeans, n_components=9;, score=197.043 total time=   1.4s
# [CV 4/5] END covariance_type=spherical, init_params=kmeans, n_components=9;, score=-52.561 total time=   0.4s
# [CV 5/5] END covariance_type=spherical, init_params=kmeans, n_components=9;, score=191.131 total time=   0.3s
# [CV 1/5] END covariance_type=spherical, init_params=kmeans, n_components=10;, score=127.797 total time=   0.3s
# [CV 2/5] END covariance_type=spherical, init_params=kmeans, n_components=10;, score=-211.762 total time=   0.4s
# [CV 3/5] END covariance_type=spherical, init_params=kmeans, n_components=10;, score=137.706 total time=   0.5s
# [CV 4/5] END covariance_type=spherical, init_params=kmeans, n_components=10;, score=-190.871 total time=   0.3s
# [CV 5/5] END covariance_type=spherical, init_params=kmeans, n_components=10;, score=89.223 total time=   0.4s
# [CV 1/5] END covariance_type=spherical, init_params=kmeans, n_components=11;, score=119.084 total time=   0.4s
# [CV 2/5] END covariance_type=spherical, init_params=kmeans, n_components=11;, score=-353.460 total time=   1.5s
# [CV 3/5] END covariance_type=spherical, init_params=kmeans, n_components=11;, score=102.301 total time=   1.3s
# [CV 4/5] END covariance_type=spherical, init_params=kmeans, n_components=11;, score=-160.246 total time=   0.7s
# [CV 5/5] END covariance_type=spherical, init_params=kmeans, n_components=11;, score=57.573 total time=   1.1s
# [CV 1/5] END covariance_type=spherical, init_params=kmeans, n_components=12;, score=81.193 total time=   1.0s
# [CV 2/5] END covariance_type=spherical, init_params=kmeans, n_components=12;, score=-412.852 total time=   1.2s
# [CV 3/5] END covariance_type=spherical, init_params=kmeans, n_components=12;, score=99.306 total time=   2.0s
# [CV 4/5] END covariance_type=spherical, init_params=kmeans, n_components=12;, score=-271.802 total time=   1.2s
# [CV 5/5] END covariance_type=spherical, init_params=kmeans, n_components=12;, score=70.854 total time=   1.2s
# [CV 1/5] END covariance_type=spherical, init_params=kmeans, n_components=13;, score=-94.789 total time=   0.7s
# [CV 2/5] END covariance_type=spherical, init_params=kmeans, n_components=13;, score=-557.159 total time=   1.5s
# [CV 3/5] END covariance_type=spherical, init_params=kmeans, n_components=13;, score=29.474 total time=   1.8s
# [CV 4/5] END covariance_type=spherical, init_params=kmeans, n_components=13;, score=-374.776 total time=   0.5s
# [CV 5/5] END covariance_type=spherical, init_params=kmeans, n_components=13;, score=15.797 total time=   1.0s
# [CV 1/5] END covariance_type=spherical, init_params=kmeans, n_components=14;, score=-87.186 total time=   0.6s
# [CV 2/5] END covariance_type=spherical, init_params=kmeans, n_components=14;, score=-486.435 total time=   0.9s
# [CV 3/5] END covariance_type=spherical, init_params=kmeans, n_components=14;, score=-21.437 total time=   1.7s
# [CV 4/5] END covariance_type=spherical, init_params=kmeans, n_components=14;, score=-325.848 total time=   0.8s
# [CV 5/5] END covariance_type=spherical, init_params=kmeans, n_components=14;, score=15.681 total time=   0.7s
# [CV 1/5] END covariance_type=spherical, init_params=kmeans, n_components=15;, score=-89.423 total time=   0.4s
# [CV 2/5] END covariance_type=spherical, init_params=kmeans, n_components=15;, score=-591.601 total time=   0.4s
# [CV 3/5] END covariance_type=spherical, init_params=kmeans, n_components=15;, score=-260.231 total time=   0.9s
# [CV 4/5] END covariance_type=spherical, init_params=kmeans, n_components=15;, score=-688.043 total time=   1.1s
# [CV 5/5] END covariance_type=spherical, init_params=kmeans, n_components=15;, score=-12.204 total time=   1.3s
# [CV 1/5] END covariance_type=spherical, init_params=random_from_data, n_components=1;, score=34.684 total time=   0.1s
# [CV 2/5] END covariance_type=spherical, init_params=random_from_data, n_components=1;, score=85.221 total time=   0.1s
# [CV 3/5] END covariance_type=spherical, init_params=random_from_data, n_components=1;, score=-2.865 total time=   0.0s
# [CV 4/5] END covariance_type=spherical, init_params=random_from_data, n_components=1;, score=-18.322 total time=   0.0s
# [CV 5/5] END covariance_type=spherical, init_params=random_from_data, n_components=1;, score=110.662 total time=   0.0s
# [CV 1/5] END covariance_type=spherical, init_params=random_from_data, n_components=2;, score=254.757 total time=   0.3s
# [CV 2/5] END covariance_type=spherical, init_params=random_from_data, n_components=2;, score=209.114 total time=   0.2s
# [CV 3/5] END covariance_type=spherical, init_params=random_from_data, n_components=2;, score=225.136 total time=   0.2s
# [CV 4/5] END covariance_type=spherical, init_params=random_from_data, n_components=2;, score=106.860 total time=   0.2s
# [CV 5/5] END covariance_type=spherical, init_params=random_from_data, n_components=2;, score=217.747 total time=   0.3s
# [CV 1/5] END covariance_type=spherical, init_params=random_from_data, n_components=3;, score=319.824 total time=   0.1s
# [CV 2/5] END covariance_type=spherical, init_params=random_from_data, n_components=3;, score=150.686 total time=   0.1s
# [CV 3/5] END covariance_type=spherical, init_params=random_from_data, n_components=3;, score=318.834 total time=   0.2s
# [CV 4/5] END covariance_type=spherical, init_params=random_from_data, n_components=3;, score=99.094 total time=   0.1s
# [CV 5/5] END covariance_type=spherical, init_params=random_from_data, n_components=3;, score=254.557 total time=   0.3s
# [CV 1/5] END covariance_type=spherical, init_params=random_from_data, n_components=4;, score=316.554 total time=   0.3s
# [CV 2/5] END covariance_type=spherical, init_params=random_from_data, n_components=4;, score=111.492 total time=   0.3s
# [CV 3/5] END covariance_type=spherical, init_params=random_from_data, n_components=4;, score=298.987 total time=   0.2s
# [CV 4/5] END covariance_type=spherical, init_params=random_from_data, n_components=4;, score=153.115 total time=   0.2s
# [CV 5/5] END covariance_type=spherical, init_params=random_from_data, n_components=4;, score=226.860 total time=   0.2s
# [CV 1/5] END covariance_type=spherical, init_params=random_from_data, n_components=5;, score=370.491 total time=   0.2s
# [CV 2/5] END covariance_type=spherical, init_params=random_from_data, n_components=5;, score=105.731 total time=   0.2s
# [CV 3/5] END covariance_type=spherical, init_params=random_from_data, n_components=5;, score=344.578 total time=   0.2s
# [CV 4/5] END covariance_type=spherical, init_params=random_from_data, n_components=5;, score=98.243 total time=   0.4s
# [CV 5/5] END covariance_type=spherical, init_params=random_from_data, n_components=5;, score=284.836 total time=   0.4s
# [CV 1/5] END covariance_type=spherical, init_params=random_from_data, n_components=6;, score=308.271 total time=   0.4s
# [CV 2/5] END covariance_type=spherical, init_params=random_from_data, n_components=6;, score=108.447 total time=   0.4s
# [CV 3/5] END covariance_type=spherical, init_params=random_from_data, n_components=6;, score=304.462 total time=   0.4s
# [CV 4/5] END covariance_type=spherical, init_params=random_from_data, n_components=6;, score=58.314 total time=   0.2s
# [CV 5/5] END covariance_type=spherical, init_params=random_from_data, n_components=6;, score=253.607 total time=   0.2s
# [CV 1/5] END covariance_type=spherical, init_params=random_from_data, n_components=7;, score=284.999 total time=   0.5s
# [CV 2/5] END covariance_type=spherical, init_params=random_from_data, n_components=7;, score=77.637 total time=   0.4s
# [CV 3/5] END covariance_type=spherical, init_params=random_from_data, n_components=7;, score=284.606 total time=   0.5s
# [CV 4/5] END covariance_type=spherical, init_params=random_from_data, n_components=7;, score=38.193 total time=   0.3s
# [CV 5/5] END covariance_type=spherical, init_params=random_from_data, n_components=7;, score=247.883 total time=   0.4s
# [CV 1/5] END covariance_type=spherical, init_params=random_from_data, n_components=8;, score=84.859 total time=   0.2s
# [CV 2/5] END covariance_type=spherical, init_params=random_from_data, n_components=8;, score=24.300 total time=   0.2s
# [CV 3/5] END covariance_type=spherical, init_params=random_from_data, n_components=8;, score=240.860 total time=   0.3s
# [CV 4/5] END covariance_type=spherical, init_params=random_from_data, n_components=8;, score=-101.514 total time=   0.4s
# [CV 5/5] END covariance_type=spherical, init_params=random_from_data, n_components=8;, score=195.662 total time=   0.3s
# [CV 1/5] END covariance_type=spherical, init_params=random_from_data, n_components=9;, score=278.703 total time=   0.2s
# [CV 2/5] END covariance_type=spherical, init_params=random_from_data, n_components=9;, score=-0.905 total time=   0.4s
# [CV 3/5] END covariance_type=spherical, init_params=random_from_data, n_components=9;, score=215.801 total time=   0.4s
# [CV 4/5] END covariance_type=spherical, init_params=random_from_data, n_components=9;, score=-127.101 total time=   0.4s
# [CV 5/5] END covariance_type=spherical, init_params=random_from_data, n_components=9;, score=144.286 total time=   0.3s
# [CV 1/5] END covariance_type=spherical, init_params=random_from_data, n_components=10;, score=227.558 total time=   0.3s
# [CV 2/5] END covariance_type=spherical, init_params=random_from_data, n_components=10;, score=-110.465 total time=   0.2s
# [CV 3/5] END covariance_type=spherical, init_params=random_from_data, n_components=10;, score=168.177 total time=   0.2s
# [CV 4/5] END covariance_type=spherical, init_params=random_from_data, n_components=10;, score=-79.216 total time=   0.2s
# [CV 5/5] END covariance_type=spherical, init_params=random_from_data, n_components=10;, score=160.296 total time=   0.2s
# [CV 1/5] END covariance_type=spherical, init_params=random_from_data, n_components=11;, score=170.458 total time=   0.2s
# [CV 2/5] END covariance_type=spherical, init_params=random_from_data, n_components=11;, score=-134.891 total time=   0.2s
# [CV 3/5] END covariance_type=spherical, init_params=random_from_data, n_components=11;, score=129.596 total time=   0.2s
# [CV 4/5] END covariance_type=spherical, init_params=random_from_data, n_components=11;, score=-200.392 total time=   0.2s
# [CV 5/5] END covariance_type=spherical, init_params=random_from_data, n_components=11;, score=105.418 total time=   0.2s
# [CV 1/5] END covariance_type=spherical, init_params=random_from_data, n_components=12;, score=134.537 total time=   0.2s
# [CV 2/5] END covariance_type=spherical, init_params=random_from_data, n_components=12;, score=-297.609 total time=   0.3s
# [CV 3/5] END covariance_type=spherical, init_params=random_from_data, n_components=12;, score=80.804 total time=   0.2s
# [CV 4/5] END covariance_type=spherical, init_params=random_from_data, n_components=12;, score=-335.412 total time=   0.2s
# [CV 5/5] END covariance_type=spherical, init_params=random_from_data, n_components=12;, score=80.087 total time=   0.2s
# [CV 1/5] END covariance_type=spherical, init_params=random_from_data, n_components=13;, score=94.687 total time=   0.2s
# [CV 2/5] END covariance_type=spherical, init_params=random_from_data, n_components=13;, score=-483.458 total time=   0.2s
# [CV 3/5] END covariance_type=spherical, init_params=random_from_data, n_components=13;, score=53.221 total time=   0.4s
# [CV 4/5] END covariance_type=spherical, init_params=random_from_data, n_components=13;, score=-458.265 total time=   0.4s
# [CV 5/5] END covariance_type=spherical, init_params=random_from_data, n_components=13;, score=36.008 total time=   0.2s
# [CV 1/5] END covariance_type=spherical, init_params=random_from_data, n_components=14;, score=41.125 total time=   0.2s
# [CV 2/5] END covariance_type=spherical, init_params=random_from_data, n_components=14;, score=-359.905 total time=   0.2s
# [CV 3/5] END covariance_type=spherical, init_params=random_from_data, n_components=14;, score=-58.922 total time=   0.2s
# [CV 4/5] END covariance_type=spherical, init_params=random_from_data, n_components=14;, score=-359.452 total time=   0.2s
# [CV 5/5] END covariance_type=spherical, init_params=random_from_data, n_components=14;, score=-11.098 total time=   0.2s
# [CV 1/5] END covariance_type=spherical, init_params=random_from_data, n_components=15;, score=-231.333 total time=   0.2s
# [CV 2/5] END covariance_type=spherical, init_params=random_from_data, n_components=15;, score=-316.565 total time=   0.2s
# [CV 3/5] END covariance_type=spherical, init_params=random_from_data, n_components=15;, score=-41.697 total time=   0.2s
# [CV 4/5] END covariance_type=spherical, init_params=random_from_data, n_components=15;, score=-451.143 total time=   0.2s
# [CV 5/5] END covariance_type=spherical, init_params=random_from_data, n_components=15;, score=-56.802 total time=   0.2s
# {'covariance_type': 'spherical', 'init_params': 'kmeans', 'n_components': 4}
# <Axes: xlabel='Number of components', ylabel='BIC score'>

# %%
threshold = 5e-2  # threshold for symlog transformation           

data = get_basis_data(basis_data, 0)[0]
#data= mol_data.T
data.drop(['aug-cc-pV5Z', 'aug-cc-pV6Z', 'd-aug-cc-pV5Z', 'd-aug-cc-pV6Z'], axis=1, inplace=True)
data.drop(['aug-cc-pVDZ', 'd-aug-cc-pVDZ', 'aug-cc-pCVDZ', 'd-aug-cc-pCVDZ'], axis=1, inplace=True)
data.drop(['aug-cc-pVTZ', 'd-aug-cc-pVTZ', 'aug-cc-pCVTZ', 'd-aug-cc-pCVTZ'], axis=1, inplace=True)
data.dropna(inplace=True)
normalizer = preprocessing.Normalizer()
standard = preprocessing.StandardScaler()

data_matrix = symlog(data_matrix, threshold)
data_matrix = normalizer.fit_transform(data_matrix)

num_clusters = 4

model = GaussianMixture(n_components=num_clusters, covariance_type='spherical', tol=1e-8, n_init=100, max_iter=2000,
                        init_params='kmeans', )
model.fit(data_matrix)

labels = model.predict(data_matrix)

color_iter = sns.color_palette("tab10", 2)[::-1]
#labels = gmm.predict(data_matrix)
score = silhouette_score(data_matrix, labels, metric='euclidean')
data['cluster'] = labels
print("silhouette score", score)

average_vectors = []
std_vectors = []
for i in range(num_clusters):
    cluster_points = data_matrix[labels == i]
    average_vector = np.mean(cluster_points, axis=0)
    std_vector = np.std(cluster_points, axis=0)
    average_vectors.append(average_vector)
    std_vectors.append(std_vector)

avg_df = pd.DataFrame(average_vectors, )
avg_df['mean'] = avg_df.mean(axis=1)
avg_df = avg_df.sort_values('mean', ascending=False)
avg_df.drop('mean', axis=1, inplace=True)

std_df = pd.DataFrame(std_vectors, )

sorted_index = avg_df.index
std_df = std_df.reindex(sorted_index)
std_df.sort_index(inplace=True)

cluster_map = {sorted_index[i]: i for i in range(len(sorted_index))}
avg_df = avg_df.reset_index(drop=True)
# avg_df = avg_df.apply(lambda x: inv_symlog(x, threshold))
# avg_df = pd.DataFrame(scaler.inverse_transform(avg_df), columns=avg_df.columns,
#                      index=avg_df.index)
print(cluster_map)
data['cluster'] = data['cluster'].map(cluster_map)

iso_diff = basis_data.copy()
iso_diff['cluster'] = iso_diff['molecule'].map(data['cluster'])
iso_diff['cluster'] = iso_diff['cluster'] + 1
iso_diff['cluster'] = iso_diff['cluster'].astype('category')

iso_diff.dropna(inplace=True)
# Out:
# silhouette score 0.39738985493238144
# {0: 0, 2: 1, 3: 2, 1: 3}

# %%
plot_data = iso_diff.query('omega==0')

basis_labels = ['aug-pVDZ', 'aug-pVTZ', 'aug-pVQZ', 'aug-pCVDZ', 'aug-pCVTZ', 'aug-pCVQZ', 'd-aug-pVDZ', 'd-aug-pVTZ',
                'd-aug-pVQZ', 'd-aug-pCVDZ',
                'd-aug-pCVTZ', 'd-aug-pCVQZ']
basis_order = ['aug-cc-pVDZ', 'aug-cc-pCVDZ', 'aug-cc-pVTZ', 'aug-cc-pCVTZ', 'aug-cc-pVQZ', 'aug-cc-pCVQZ',
               'd-aug-cc-pVDZ', 'd-aug-cc-pCVDZ', 'd-aug-cc-pVTZ',
               'd-aug-cc-pCVTZ', 'd-aug-cc-pVQZ', 'd-aug-cc-pCVQZ']
basis_order = ['aug-cc-pVDZ', 'aug-cc-pVTZ', 'aug-cc-pVQZ', 'aug-cc-pCVDZ', 'aug-cc-pCVTZ', 'aug-cc-pCVQZ',
               'd-aug-cc-pVDZ', 'd-aug-cc-pVTZ', 'd-aug-cc-pVQZ',
               'd-aug-cc-pCVDZ', 'd-aug-cc-pCVTZ', 'd-aug-cc-pCVQZ']
basis_labels = ['s-D', 's-T', 's-Q', 's-CD', 's-CT', 's-CQ', 'd-D', 'd-T', 'd-Q', 'd-CD', 'd-CT', 'd-CQ']
#basis_labels = ['s-D','s-CD', 's-T', 's-CT', 's-Q', 's-CQ', 'd-D', 'd-CD', 'd-T', 'd-CT', 'd-Q', 'd-CQ']

plot_data = plot_data.query(
    'basis!="aug-cc-pV5Z" and basis!="aug-cc-pV6Z" and basis!="d-aug-cc-pV5Z" and basis!="d-aug-cc-pV6Z"')
plot_data['basis'] = plot_data['basis'].astype('category')
plot_data['basis'] = plot_data['basis'].cat.reorder_categories(basis_order)
plot_data
# Out:
#       molecule  omega           basis      alpha      gamma   alphaMRA  \
# 0        NH2Cl      0     aug-cc-pVDZ  24.800048  12.340561  25.978063
# 9        NH2Cl      0     aug-cc-pVTZ  25.685461  12.023459  25.978063
# 18       NH2Cl      0     aug-cc-pVQZ  25.921802  11.933137  25.978063
# 36       NH2Cl      0    aug-cc-pCVDZ  24.806649  12.313024  25.978063
# 45       NH2Cl      0    aug-cc-pCVTZ  25.725804  11.990660  25.978063
# ...        ...    ...             ...        ...        ...        ...
# 12744     HOOH      0   d-aug-cc-pVTZ  14.430967   9.018769  14.424633
# 12753     HOOH      0   d-aug-cc-pVQZ  14.422890   9.013531  14.424633
# 12771     HOOH      0  d-aug-cc-pCVDZ  14.392285   9.048696  14.424633
# 12780     HOOH      0  d-aug-cc-pCVTZ  14.429283   9.015749  14.424633
# 12789     HOOH      0  d-aug-cc-pCVQZ  14.422802   9.013452  14.424633
#
#          alphaE   gammaMRA    gammaE augmentation polarization  mol_system  \
# 0     -4.534652  11.913106  3.588107          aug            V  Second-row
# 9     -1.126342  11.913106  0.926323          aug            V  Second-row
# 18    -0.216574  11.913106  0.168143          aug            V  Second-row
# 36    -4.509245  11.913106  3.356963          aug           CV  Second-row
# 45    -0.971046  11.913106  0.651001          aug           CV  Second-row
# ...         ...        ...       ...          ...          ...         ...
# 12744  0.043908   9.028671 -0.109672        d-aug            V   First-row
# 12753 -0.012088   9.028671 -0.167680        d-aug            V   First-row
# 12771 -0.224260   9.028671  0.221800        d-aug           CV   First-row
# 12780  0.032234   9.028671 -0.143119        d-aug           CV   First-row
# 12789 -0.012695   9.028671 -0.168560        d-aug           CV   First-row
#
#       valence            Type cluster
# 0           D     aug-cc-pVnZ       4
# 9           T     aug-cc-pVnZ       4
# 18          Q     aug-cc-pVnZ       4
# 36          D    aug-cc-pCVnZ       4
# 45          T    aug-cc-pCVnZ       4
# ...       ...             ...     ...
# 12744       T   d-aug-cc-pVnZ       3
# 12753       Q   d-aug-cc-pVnZ       3
# 12771       D  d-aug-cc-pCVnZ       3
# 12780       T  d-aug-cc-pCVnZ       3
# 12789       Q  d-aug-cc-pCVnZ       3
#
# [1068 rows x 15 columns]

# %%
from matplotlib.ticker import ScalarFormatter

sharey=False
if sharey:
    ci=0:
else:
    ci = 95

g = sns.FacetGrid(plot_data, col='cluster', col_wrap=2, sharey=sharey, sharex=True, height=3, aspect=1.5)

g.map_dataframe(sns.lineplot,x='basis',y='alphaE', hue='Type', size=10, alpha=.75,palette=['k'],errorbar=('ci',ci), 
                legend=False)
g.map_dataframe(sns.stripplot,x='basis',y='alphaE', hue='mol_system', size=5, alpha=.75, dodge=False, palette='colorblind',
      legend=True)
g.set_ylabels(r'$\alpha$ Percent Error')

for i,ax in enumerate(g.axes.flat):
    j=i+1
    cluster_size = plot_data.query('cluster==@j').molecule.unique().size
    ax.set_title(f'Cluster {j} ({cluster_size}/ {plot_data.molecule.unique().size})')
    
    ax.axhline(y=threshold, linestyle='dashdot', color='red', linewidth=.50)
    ax.axhline(y=-threshold, linestyle='dashdot', color='red', linewidth=.50)
    ax.axhline(y=.00, linestyle='--', color='red', linewidth=.35)
    if sharey:
        ax.set_yscale('symlog', linthresh=.1)
        ax.yaxis.set_major_formatter(ScalarFormatter())
    ax.set_xticks(range(0, 12))
    ax.set_xticklabels(basis_labels, rotation=45)
    ax.axvline(x=2.5, linestyle='dotted', color='black', linewidth=.15)
    ax.axvline(x=5.5, linestyle='dotted', color='black', linewidth=.15)
    ax.axvline(x=8.5, linestyle='dotted', color='black', linewidth=.15)
    ax.set_xlabel('')

handles, labels = ax.get_legend_handles_labels()
# add a legened
g.fig.legend(handles, labels, loc='center', bbox_to_anchor=(0.5, 0.00), ncol=3, fancybox=True, fontsize=10)

g.fig.tight_layout()
g.fig.savefig(paper_path.joinpath('alpha_convergence.png'), dpi=600, bbox_inches='tight')
# Out:
# /home/ahurta92/miniforge3/envs/QRP/lib/python3.12/site-packages/seaborn/axisgrid.py:854: UserWarning:
# The palette list has fewer values (1) than needed (4) and will cycle, which may produce an uninterpretable plot.
#   func(*plot_args, **plot_kwargs)
# /home/ahurta92/miniforge3/envs/QRP/lib/python3.12/site-packages/seaborn/axisgrid.py:854: UserWarning:
# The palette list has fewer values (1) than needed (4) and will cycle, which may produce an uninterpretable plot.
#   func(*plot_args, **plot_kwargs)
# /home/ahurta92/miniforge3/envs/QRP/lib/python3.12/site-packages/seaborn/axisgrid.py:854: UserWarning:
# The palette list has fewer values (1) than needed (4) and will cycle, which may produce an uninterpretable plot.
#   func(*plot_args, **plot_kwargs)
# /home/ahurta92/miniforge3/envs/QRP/lib/python3.12/site-packages/seaborn/axisgrid.py:854: UserWarning:
# The palette list has fewer values (1) than needed (4) and will cycle, which may produce an uninterpretable plot.
#   func(*plot_args, **plot_kwargs)

# %%
cdata = iso_diff.dropna().query('omega==0 and basis=="aug-cc-pVDZ"')
cluster_table = cdata[['molecule', 'cluster', 'mol_system']].drop_duplicates().sort_values('mol_system')
mol_table = pd.DataFrame()
#mol_table.columns = [f'Cluster {i}' for i in range(1, len(cluster_table['cluster'].unique()))]

cluster_data = []
for cluster_id, group in cluster_table.groupby('cluster'):
    print(cluster_id)
    cs = pd.Series(group['molecule'])
    cs.name = f'Cluster {int(cluster_id)}'
    cs.reset_index(drop=True, inplace=True)
    cluster_data.append(cs)

mol_table = pd.concat(cluster_data, axis=1)
# sort the values of each column alphabetically
mol_table = mol_table.fillna('-')
mol_table = mol_table.applymap(lambda x: '\\ce{' + str(x) + '}', na_action='ignore')
# reverse the order to the table rowwise
mol_table = mol_table.iloc[::-1]
# map colorblind colormap to the columns
mol_only = cluster_table['molecule']
# make mol only into a table 9 x 10 

# surround the values with \ce{} to make them chemical formulas
ms = mol_only.apply(lambda x: r'\ce{' + str(x) + '}')
# make a dictionary of the colors
mol_dict = dict(zip(ms, cluster_table.mol_system))

pal = sns.color_palette('muted', n_colors=3)
colormap = dict(zip(cluster_table.mol_system.unique(), pal.as_hex()))
mol_color = {mol: colormap[mol_dict[mol]] for mol in ms}
# add white to \ce{-} to make it white
mol_color = {mol: colormap[mol_dict[mol]] for mol in ms}

mol_color['\\ce{-}'] = 'white'
# apply the colors to the dataframe based on mol_color dictionary

#mol_df = mol_df.applymap(lambda x: '\\ce{' + str(x) + '}')
mol_df = mol_table.style.apply(lambda x: [f'background-color: {mol_color[v]}' for v in x],
                               axis=1)
# before printing surround the values with \ce{} to make them chemical formulas
# adjust column names to be Cluster 1, Cluster 2, etc.
# write the dataframe to a latex table
mol_df.to_latex(paper_path.joinpath('cluster_molecule_table.tex'),
                multicol_align='|c|',
                hrules=True,
                convert_css=True,
                )

mol_df
# Out:
# 1
# 2
# 3
# 4
# /tmp/ipykernel_20466/300501626.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for cluster_id, group in cluster_table.groupby('cluster'):
# /tmp/ipykernel_20466/300501626.py:17: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   mol_table = mol_table.applymap(lambda x: '\\ce{' + str(x) + '}', na_action='ignore')
# <style type="text/css">
# #T_bc15d_row0_col0, #T_bc15d_row0_col1, #T_bc15d_row0_col2, #T_bc15d_row1_col0, #T_bc15d_row1_col1, #T_bc15d_row1_col2, #T_bc15d_row2_col0, #T_bc15d_row2_col1, #T_bc15d_row2_col2, #T_bc15d_row3_col0, #T_bc15d_row3_col1, #T_bc15d_row4_col0, #T_bc15d_row4_col1, #T_bc15d_row5_col0, #T_bc15d_row5_col1, #T_bc15d_row6_col0, #T_bc15d_row6_col1, #T_bc15d_row7_col0, #T_bc15d_row7_col1, #T_bc15d_row8_col0, #T_bc15d_row8_col1, #T_bc15d_row9_col0, #T_bc15d_row9_col1, #T_bc15d_row10_col0, #T_bc15d_row11_col0, #T_bc15d_row12_col0, #T_bc15d_row13_col0, #T_bc15d_row14_col0, #T_bc15d_row15_col0, #T_bc15d_row16_col0, #T_bc15d_row17_col0, #T_bc15d_row18_col0, #T_bc15d_row19_col0, #T_bc15d_row20_col0, #T_bc15d_row21_col0 {
#   background-color: white;
# }
# #T_bc15d_row0_col3, #T_bc15d_row1_col3, #T_bc15d_row2_col3, #T_bc15d_row3_col3, #T_bc15d_row4_col3, #T_bc15d_row5_col3, #T_bc15d_row6_col3, #T_bc15d_row7_col3, #T_bc15d_row8_col3, #T_bc15d_row9_col3, #T_bc15d_row10_col1, #T_bc15d_row10_col3, #T_bc15d_row11_col1, #T_bc15d_row11_col3, #T_bc15d_row12_col1, #T_bc15d_row12_col3, #T_bc15d_row13_col1, #T_bc15d_row13_col3, #T_bc15d_row14_col1, #T_bc15d_row14_col3, #T_bc15d_row15_col1, #T_bc15d_row15_col3, #T_bc15d_row16_col3, #T_bc15d_row17_col3, #T_bc15d_row18_col3, #T_bc15d_row19_col3, #T_bc15d_row20_col3, #T_bc15d_row21_col3, #T_bc15d_row22_col0, #T_bc15d_row22_col3, #T_bc15d_row23_col0, #T_bc15d_row23_col3, #T_bc15d_row24_col0, #T_bc15d_row24_col3, #T_bc15d_row25_col0, #T_bc15d_row25_col3, #T_bc15d_row26_col3, #T_bc15d_row27_col3, #T_bc15d_row28_col3, #T_bc15d_row29_col3 {
#   background-color: #6acc64;
# }
# #T_bc15d_row3_col2, #T_bc15d_row4_col2, #T_bc15d_row5_col2, #T_bc15d_row6_col2, #T_bc15d_row7_col2, #T_bc15d_row8_col2, #T_bc15d_row9_col2, #T_bc15d_row10_col2, #T_bc15d_row11_col2, #T_bc15d_row12_col2, #T_bc15d_row13_col2, #T_bc15d_row14_col2 {
#   background-color: #ee854a;
# }
# #T_bc15d_row15_col2, #T_bc15d_row16_col1, #T_bc15d_row16_col2, #T_bc15d_row17_col1, #T_bc15d_row17_col2, #T_bc15d_row18_col1, #T_bc15d_row18_col2, #T_bc15d_row19_col1, #T_bc15d_row19_col2, #T_bc15d_row20_col1, #T_bc15d_row20_col2, #T_bc15d_row21_col1, #T_bc15d_row21_col2, #T_bc15d_row22_col1, #T_bc15d_row22_col2, #T_bc15d_row23_col1, #T_bc15d_row23_col2, #T_bc15d_row24_col1, #T_bc15d_row24_col2, #T_bc15d_row25_col1, #T_bc15d_row25_col2, #T_bc15d_row26_col0, #T_bc15d_row26_col1, #T_bc15d_row26_col2, #T_bc15d_row27_col0, #T_bc15d_row27_col1, #T_bc15d_row27_col2, #T_bc15d_row28_col0, #T_bc15d_row28_col1, #T_bc15d_row28_col2, #T_bc15d_row29_col0, #T_bc15d_row29_col1, #T_bc15d_row29_col2, #T_bc15d_row30_col0, #T_bc15d_row30_col1, #T_bc15d_row30_col2, #T_bc15d_row30_col3 {
#   background-color: #4878d0;
# }
# </style>
# <table id="T_bc15d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc15d_level0_col0" class="col_heading level0 col0" >Cluster 1</th>
#       <th id="T_bc15d_level0_col1" class="col_heading level0 col1" >Cluster 2</th>
#       <th id="T_bc15d_level0_col2" class="col_heading level0 col2" >Cluster 3</th>
#       <th id="T_bc15d_level0_col3" class="col_heading level0 col3" >Cluster 4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc15d_level0_row0" class="row_heading level0 row0" >30</th>
#       <td id="T_bc15d_row0_col0" class="data row0 col0" >\ce{-}</td>
#       <td id="T_bc15d_row0_col1" class="data row0 col1" >\ce{-}</td>
#       <td id="T_bc15d_row0_col2" class="data row0 col2" >\ce{-}</td>
#       <td id="T_bc15d_row0_col3" class="data row0 col3" >\ce{CH3SH}</td>
#     </tr>
#     <tr>
#       <th id="T_bc15d_level0_row1" class="row_heading level0 row1" >29</th>
#       <td id="T_bc15d_row1_col0" class="data row1 col0" >\ce{-}</td>
#       <td id="T_bc15d_row1_col1" class="data row1 col1" >\ce{-}</td>
#       <td id="T_bc15d_row1_col2" class="data row1 col2" >\ce{-}</td>
#       <td id="T_bc15d_row1_col3" class="data row1 col3" >\ce{ClCN}</td>
#     </tr>
#     <tr>
#       <th id="T_bc15d_level0_row2" class="row_heading level0 row2" >28</th>
#       <td id="T_bc15d_row2_col0" class="data row2 col0" >\ce{-}</td>
#       <td id="T_bc15d_row2_col1" class="data row2 col1" >\ce{-}</td>
#       <td id="T_bc15d_row2_col2" class="data row2 col2" >\ce{-}</td>
#       <td id="T_bc15d_row2_col3" class="data row2 col3" >\ce{HCHS}</td>
#     </tr>
#     <tr>
#       <th id="T_bc15d_level0_row3" class="row_heading level0 row3" >27</th>
#       <td id="T_bc15d_row3_col0" class="data row3 col0" >\ce{-}</td>
#       <td id="T_bc15d_row3_col1" class="data row3 col1" >\ce{-}</td>
#       <td id="T_bc15d_row3_col2" class="data row3 col2" >\ce{CH3F}</td>
#       <td id="T_bc15d_row3_col3" class="data row3 col3" >\ce{LiCl}</td>
#     </tr>
#     <tr>
#       <th id="T_bc15d_level0_row4" class="row_heading level0 row4" >26</th>
#       <td id="T_bc15d_row4_col0" class="data row4 col0" >\ce{-}</td>
#       <td id="T_bc15d_row4_col1" class="data row4 col1" >\ce{-}</td>
#       <td id="T_bc15d_row4_col2" class="data row4 col2" >\ce{FNO}</td>
#       <td id="T_bc15d_row4_col3" class="data row4 col3" >\ce{CH3Cl}</td>
#     </tr>
#     <tr>
#       <th id="T_bc15d_level0_row5" class="row_heading level0 row5" >25</th>
#       <td id="T_bc15d_row5_col0" class="data row5 col0" >\ce{-}</td>
#       <td id="T_bc15d_row5_col1" class="data row5 col1" >\ce{-}</td>
#       <td id="T_bc15d_row5_col2" class="data row5 col2" >\ce{OF2}</td>
#       <td id="T_bc15d_row5_col3" class="data row5 col3" >\ce{SCl2}</td>
#     </tr>
#     <tr>
#       <th id="T_bc15d_level0_row6" class="row_heading level0 row6" >24</th>
#       <td id="T_bc15d_row6_col0" class="data row6 col0" >\ce{-}</td>
#       <td id="T_bc15d_row6_col1" class="data row6 col1" >\ce{-}</td>
#       <td id="T_bc15d_row6_col2" class="data row6 col2" >\ce{NH2F}</td>
#       <td id="T_bc15d_row6_col3" class="data row6 col3" >\ce{Ar}</td>
#     </tr>
#     <tr>
#       <th id="T_bc15d_level0_row7" class="row_heading level0 row7" >23</th>
#       <td id="T_bc15d_row7_col0" class="data row7 col0" >\ce{-}</td>
#       <td id="T_bc15d_row7_col1" class="data row7 col1" >\ce{-}</td>
#       <td id="T_bc15d_row7_col2" class="data row7 col2" >\ce{BF}</td>
#       <td id="T_bc15d_row7_col3" class="data row7 col3" >\ce{Cl2}</td>
#     </tr>
#     <tr>
#       <th id="T_bc15d_level0_row8" class="row_heading level0 row8" >22</th>
#       <td id="T_bc15d_row8_col0" class="data row8 col0" >\ce{-}</td>
#       <td id="T_bc15d_row8_col1" class="data row8 col1" >\ce{-}</td>
#       <td id="T_bc15d_row8_col2" class="data row8 col2" >\ce{BHF2}</td>
#       <td id="T_bc15d_row8_col3" class="data row8 col3" >\ce{HBS}</td>
#     </tr>
#     <tr>
#       <th id="T_bc15d_level0_row9" class="row_heading level0 row9" >21</th>
#       <td id="T_bc15d_row9_col0" class="data row9 col0" >\ce{-}</td>
#       <td id="T_bc15d_row9_col1" class="data row9 col1" >\ce{-}</td>
#       <td id="T_bc15d_row9_col2" class="data row9 col2" >\ce{HF}</td>
#       <td id="T_bc15d_row9_col3" class="data row9 col3" >\ce{OCl2}</td>
#     </tr>
#     <tr>
#       <th id="T_bc15d_level0_row10" class="row_heading level0 row10" >20</th>
#       <td id="T_bc15d_row10_col0" class="data row10 col0" >\ce{-}</td>
#       <td id="T_bc15d_row10_col1" class="data row10 col1" >\ce{PH3}</td>
#       <td id="T_bc15d_row10_col2" class="data row10 col2" >\ce{FCN}</td>
#       <td id="T_bc15d_row10_col3" class="data row10 col3" >\ce{S2H2}</td>
#     </tr>
#     <tr>
#       <th id="T_bc15d_level0_row11" class="row_heading level0 row11" >19</th>
#       <td id="T_bc15d_row11_col0" class="data row11 col0" >\ce{-}</td>
#       <td id="T_bc15d_row11_col1" class="data row11 col1" >\ce{SO2}</td>
#       <td id="T_bc15d_row11_col2" class="data row11 col2" >\ce{HCCF}</td>
#       <td id="T_bc15d_row11_col3" class="data row11 col3" >\ce{CSO}</td>
#     </tr>
#     <tr>
#       <th id="T_bc15d_level0_row12" class="row_heading level0 row12" >18</th>
#       <td id="T_bc15d_row12_col0" class="data row12 col0" >\ce{-}</td>
#       <td id="T_bc15d_row12_col1" class="data row12 col1" >\ce{PH3O}</td>
#       <td id="T_bc15d_row12_col2" class="data row12 col2" >\ce{BH2F}<
